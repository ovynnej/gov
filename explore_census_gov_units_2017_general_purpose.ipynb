# %% [markdown]
# # Objective
#
# First look at the Govt_Units_2017_Final_General_Purpose sheet from the 2017 Census of Government (happens every 5 years). According to the documentation, this sheet contains data for all independent government units - specifically, general purpose governments.
#
# Source: https://www.census.gov/data/datasets/2017/econ/gus/public-use-files.html

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
path = 'Govt_Units_2017_Final_General_Purpose.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#        CENSUS_ID               NAME   UNIT_TYPE                 TITLE  \
# 0  1100100100000  COUNTY OF AUTAUGA  1 - COUNTY          ADMINSTRATOR
# 1  1100200200000  COUNTY OF BALDWIN  1 - COUNTY  COUNTY ADMINISTRATOR
# 2  1100300300000  COUNTY OF BARBOUR  1 - COUNTY              CHAIRMAN
# 3  1100400400000     COUNTY OF BIBB  1 - COUNTY         ADMINISTRATOR
# 4  1100500500000   COUNTY OF BLOUNT  1 - COUNTY  COUNTY ADMINISTRATOR
#
#              ADDRESS1 ADDRESS2         CITY STATE_AB      ZIP    ZIP4  \
# 0      135 N COURT ST    STE B   PRATTVILLE       AL  36067.0  3049.0
# 1   312 COURTHOUSE SQ   STE 12  BAY MINETTE       AL  36507.0  4809.0
# 2          PO BOX 398      NaN      CLAYTON       AL  36016.0   398.0
# 3  157 SW DAVIDSON DR      NaN  CENTREVILLE       AL  35042.0  2277.0
# 4       220 2ND AVE E  STE 106      ONEONTA       AL  35121.0  1702.0
#
#                       WEB_ADDRESS POPULATION  POPULATION_YEAR  FIPS_STATE  \
# ...

# %%
df.columns
# Out:
# Index(['CENSUS_ID', 'NAME', 'UNIT_TYPE', 'TITLE', 'ADDRESS1', 'ADDRESS2',
#        'CITY', 'STATE_AB', 'ZIP', 'ZIP4', 'WEB_ADDRESS', 'POPULATION',
#        'POPULATION_YEAR', 'FIPS_STATE', 'FIPS_COUNTY', 'FIPS_PLACE',
#        'COUNTY_AREA_NAME'],
#       dtype='object')

# %%
len(df)
# Out:
# 38779

# %%
len(np.unique(df.CITY))
# Out:
# 13639

# %%
len(np.unique(df.NAME))
# Out:
# 25367

# %%
len(np.unique(df.COUNTY_AREA_NAME))
# Out:
# 1848

# %%
unique_titles = list(np.unique(df.TITLE))
len(unique_titles)
# Out:
# 4468

# %%
unique_titles
# Out:
# [' ADMINISTRATOR',
#  ' AUDITOR',
#  ' CHAIRMAN',
#  ' CITY ADMINISTRATOR',
#  ' CLERK',
#  ' CLERK THERESA TOWNSHIP',
#  ' COUNTY AUDITOR TREAS',
#  ' DEPUTY COMMISSIONER OF PLANNING',
#  ' FINANCE DIRECTOR',
#  ' FINANCE OFFICER',
#  ' FIRST SELECTMAN',
#  ' FISCAL OFFICER',
#  ' SUPERVISER CHAIR',
#  ' SUPERVISOR',
#  ' TOWNSHIP CLERK',
#  ' TREASURER',
#  '-FISCAL OFFICER',
#  '-TOWNSHIP TRUSTEE',
#  '1ST ASSESSOR',
#  'ABBY WALOWEN, SECRETARY/TREASURER',
#  'ABOITE TOWNSHIP TRUSTEE',
#  'ABOROUGH CLERK',
#  'ACCESSING CLERK',
#  'ACCESSOR',
#  'ACCESSOR AIDE',
#  'ACCOUNT CLERK',
#  'ACCOUNT PAYABLE',
#  'ACCOUNT TAX',
#  'ACCOUNTANT',
#  'ACCOUNTANT VILLAGE OF LAKE BARRINGTON',
#  'ACCOUNTANT, DIVISION OF REVENUE',
#  'ACCOUNTANT- IGNACE MATTHAIS',
#  'ACCOUNTANT/TOWN CLERK',
#  'ACCOUNTANT/TREASURER',
#  'ACCOUNTANTS',
#  'ACCOUNTING',
#  'ACCOUNTING & FINANCE COORDINATOR',
#  'ACCOUNTING ADMINISTRATOR',
#  'ACCOUNTING ASSISTANT',
#  'ACCOUNTING CLERK',
# ...
