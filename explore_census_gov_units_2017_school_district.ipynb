# %% [markdown]
# # Objective
#
# First look at the Govt_Units_2017_Final_School_District sheet from the 2017 Census of Government (happens every 5 years). According to the documentation, this sheet contains data for all school district governments.
#
# Source: https://www.census.gov/data/datasets/2017/econ/gus/public-use-files.html

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
path = 'Govt_Units_2017_Final_School_District.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#        CENSUS_ID                            NAME    TITLE  \
# 0  1500100100000  AUTAUGA COUNTY SCHOOL DISTRICT  FINANCE
# 1  1500200100000  BALDWIN COUNTY SCHOOL DISTRICT     SUPT
# 2  1500300100000  BARBOUR COUNTY SCHOOL DISTRICT     SUPT
# 3  1500300200000    EUFAULA CITY SCHOOL DISTRICT     SUPT
# 4  1500400100000     BIBB COUNTY SCHOOL DISTRICT     SUPT
#
#               ADDRESS1 ADDRESS2         CITY STATE_AB    ZIP    ZIP4  \
# 0         153 W 4TH ST      NaN   PRATTVILLE       AL  36067  3011.0
# 1  2600-AN HAND AVENUE      NaN  BAY MINETTE       AL  36507     NaN
# 2           PO BOX 429      NaN      CLAYTON       AL  36016   429.0
# 3      420 SANFORD AVE      NaN      EUFAULA       AL  36027  1450.0
# 4   157 SW DAVIDSON DR      NaN  CENTREVILLE       AL  35042  2277.0
#
#                            WEB_ADDRESS ENROLLMENT  ENROLLMENT_YEAR  \
# 0  http://www.autaugacountyschool.org/      9,609             2016
# ...

# %%
df.columns
# Out:
# Index(['CENSUS_ID', 'NAME', 'TITLE', 'ADDRESS1', 'ADDRESS2', 'CITY',
#        'STATE_AB', 'ZIP', 'ZIP4', 'WEB_ADDRESS', 'ENROLLMENT',
#        'ENROLLMENT_YEAR', 'SCHOOL_LEVEL_DESCRIPTION', 'FIPS_STATE',
#        'FIPS_COUNTY', 'COUNTY_AREA_NAME'],
#       dtype='object')

# %%
len(df)
# Out:
# 12754

# %%
len(np.unique(df.CITY))
# Out:
# 7571

# %%
len(np.unique(df.NAME))
# Out:
# 12576

# %%
len(np.unique(df.COUNTY_AREA_NAME))
# Out:
# 1630

# %%
unique_titles = list(np.unique(df.TITLE))
len(unique_titles)
# Out:
# 606

# %%
unique_titles
# Out:
# ['ACADEMIC AFFAIRS',
#  'ACCOUNTANT',
#  'ACCOUNTING',
#  'ACCTG',
#  'ACTING PRINCIPAL',
#  'ACTING SUPERINTENDENT',
#  'ADDISON NORTHEAST DISTRICT',
#  'ADEL ELEMENTARY SCHOOL',
#  'ADIM OFFICES',
#  'ADM',
#  'ADM ASST',
#  'ADM SUPT',
#  'ADM/SUPT.',
#  'ADMIN',
#  'ADMIN ASSISTANT',
#  'ADMIN ASST',
#  'ADMIN BOOKKEEPER',
#  'ADMIN SUPT.',
#  'ADMINISTRATION',
#  'ADMINISTRATION (FINANCE)',
#  'ADMINISTRATION BLDG.',
#  'ADMINISTRATION BUILDING',
#  'ADMINISTRATION CENTER',
#  'ADMINISTRATION OF BUSINESS SERV',
#  'ADMINISTRATION OFFICE',
#  'ADMINISTRATIVE',
#  'ADMINISTRATIVE ASSISTANT',
#  'ADMINISTRATIVE ASST',
#  'ADMINISTRATIVE CENTER',
#  'ADMINISTRATIVE OFC.',
#  'ADMINISTRATIVE OFFICE',
#  'ADMINISTRATIVE OFFICES',
#  'ADMINISTRATIVE PRINCIPAL',
#  'ADMINISTRATIVE SECRETARY',
#  'ADMINISTRATIVE SERVICES',
#  'ADMINISTRATOR',
#  'ADMINISTRTOR',
#  'ADMINSTRATION',
#  'ADMINSTRATIVE OFFICE',
#  'ADMNISTRATIVE ASST',
#  'AKIN GRADE SCHOOL',
#  'ALPHA BOARD OF EDUCATION',
# ...
