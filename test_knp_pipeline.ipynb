# %% [markdown]
# # Contents
#
# 1. Publish files to the knowledge graph.
# 2. Download files to the knowledge graph.
# 3. Union the downloaded files and save the result.
# 4. Publish the result to the knowledge graph.
# 5. Download the result and analyze it.
#
# I think we can imagine a different researcher (analyst or journalist) doing each of the following chunks of steps: (1), (2-4), (5)

# %% [markdown]
# # 1. Publish files
#
# Publish `Govt_Units_2017_Final_General_Purpose.csv` and `Govt_Units_2017_Final_Special_District.csv` to the knowledge graph.

# %%
import kgpl_client as kgpl

# %%
path1 = '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_General_Purpose.csv'
file = kgpl.File(path1)
value = kgpl.value(cdds,"General_Purpose", "Jenny")
kgpl.variable(file,"General_Purpose from Jenny", "Jenny")

path2 = '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_Special_District.csv'
file = kgpl.File(path2)
value = kgpl.value(cdds,"Special_District", "Jenny")
kgpl.variable(file,"Special_District from Jenny", "Jenny")

# %% [markdown]
# ### Success!
#
# Command line ouput:
# ```
# (env) jennyvo@lasagna:~/KNP/client$ python3 pub.py
# Created: KGPLValue with ID http://lasagna.eecs.umich.edu:8080/val/0
# Created: KGPLVariable with ID http://lasagna.eecs.umich.edu:8080/var/0
# Created: KGPLValue with ID http://lasagna.eecs.umich.edu:8080/val/1
# Created: KGPLVariable with ID http://lasagna.eecs.umich.edu:8080/var/1
# ```
#
# <img src="./screenshots/visualization_var0_var1.png"/>

# %% [markdown]
# # Step 2. Download files
#
# Download files from the knowledge graph.

# %%
VAR_ID_GIVEN_BY_USER1 = 'http://lasagna.eecs.umich.edu:8080/var/0'

needed_var_id = kgpl.load_var(VAR_ID_GIVEN_BY_USER1)
val_kgpl = kgpl.load_val(needed_var_id.val_id)
data_source = val_kgpl.val

# %%
data_source

# %%
path_to_var0 = data_source.filename
path_to_var0
# Out:
# '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_General_Purpose.csv'

# %%
VAR_ID_GIVEN_BY_USER1 = 'http://lasagna.eecs.umich.edu:8080/var/1'

needed_var_id = kgpl.load_var(VAR_ID_GIVEN_BY_USER1)
val_kgpl = kgpl.load_val(needed_var_id.val_id)
data_source = val_kgpl.val
path_to_var1 = data_source.filename
path_to_var1
# Out:
# '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_Special_District.csv'

# %% [markdown]
# # Step 3. Union downloaded files
#
# 1. Load the dataframes.
#     - Govt_Units_2017_Final_General_Purpose.csv
#     - Govt_Units_2017_Final_Special_District.csv
# 2. Add a column with the name of the source file to each dataframe.
# 3. Combine the dataframes.
# 4. Save the resultant dataframe.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Load dataframes

# %%
df_general = pd.read_csv(path_to_var0)
df_special = pd.read_csv(path_to_var1, encoding="ISO-8859-1")

# %% [markdown]
# ### 2. Add a column with the name of the source file to each dataframe

# %%
files_general = [path_to_var0 for _ in range(len(df_general))]
df_general['ORIGIN_FILE'] = files_general

files_special = [path_to_var1 for _ in range(len(df_special))]
df_special['ORIGIN_FILE'] = files_special

# %%
df_general.head()
# Out:
#        CENSUS_ID               NAME   UNIT_TYPE                 TITLE  \
# 0  1100100100000  COUNTY OF AUTAUGA  1 - COUNTY          ADMINSTRATOR
# 1  1100200200000  COUNTY OF BALDWIN  1 - COUNTY  COUNTY ADMINISTRATOR
# 2  1100300300000  COUNTY OF BARBOUR  1 - COUNTY              CHAIRMAN
# 3  1100400400000     COUNTY OF BIBB  1 - COUNTY         ADMINISTRATOR
# 4  1100500500000   COUNTY OF BLOUNT  1 - COUNTY  COUNTY ADMINISTRATOR
#
#              ADDRESS1 ADDRESS2         CITY STATE_AB      ZIP    ZIP4  \
# 0      135 N COURT ST    STE B   PRATTVILLE       AL  36067.0  3049.0
# 1   312 COURTHOUSE SQ   STE 12  BAY MINETTE       AL  36507.0  4809.0
# 2          PO BOX 398      NaN      CLAYTON       AL  36016.0   398.0
# 3  157 SW DAVIDSON DR      NaN  CENTREVILLE       AL  35042.0  2277.0
# 4       220 2ND AVE E  STE 106      ONEONTA       AL  35121.0  1702.0
#
#                       WEB_ADDRESS POPULATION  POPULATION_YEAR  FIPS_STATE  \
# 0        http://www.autaugaco.org     55,504             2017           1
# 1  http://www.baldwincountyal.gov    212,628             2017           1
# 2                             NaN     25,270             2017           1
# 3                             NaN     22,668             2017           1
# 4     http://www.co.blount.al.us/     58,013             2017           1
#
#    FIPS_COUNTY  FIPS_PLACE COUNTY_AREA_NAME  \
# 0            1     99001.0          AUTAUGA
# 1            3     99003.0          BALDWIN
# 2            5     99005.0          BARBOUR
# 3            7     99007.0             BIBB
# 4            9     99009.0           BLOUNT
#
#                                          ORIGIN_FILE
# 0  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 1  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 2  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 3  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 4  /home/jennyvo/KNP/files_to_publish/Govt_Units_...

# %%
df_special.head()
# Out:
#        CENSUS_ID                             NAME              FUNCTION_NAME  \
# 0  1400111000000  FIVE STAR WATER SUPPLY DISTRICT  91 - Water Supply Utility
# 1  1400118300000   AUTAUGA COUNTY SEWER AUTHORITY              80 - Sewerage
# 2  1400120100000     PRATTVILLE AIRPORT AUTHORITY    01 - Air Transportation
# 3  1400120300000     WEST AUTAUGA WATER AUTHORITY  91 - Water Supply Utility
# 4  1400120400000     NORTH DALLAS WATER AUTHORITY  91 - Water Supply Utility
#
#                       TITLE              ADDRESS1 ADDRESS2           CITY  \
# 0             ADMINISTRATOR         PO BOX 680870      NaN     PRATTVILLE
# 1  AUTAUGA COUNTY COMMISION    135 N COURT STREET  SUITE B     PRATTVILLE
# 2                  CHAIRMAN     1450 AVIATION WAY      NaN     PRATTVILLE
# 3           GENERAL MANAGER            PO BOX 400      NaN   AUTAUGAVILLE
# 4                     CLERK  7590 AL HIGHWAY 22 N      NaN  VALLEY GRANDE
#
#   STATE_AB    ZIP    ZIP4                       WEB_ADDRESS  FIPS_STATE  \
# 0       AL  36068   870.0                               NaN           1
# 1       AL  36067     NaN                               NaN           1
# 2       AL  36067  7336.0  http://prattvilleairport.8k.com/           1
# 3       AL  36003   400.0   http://www.westautaugawater.org           1
# 4       AL  36701  9303.0                               NaN           1
#
#    FIPS_COUNTY COUNTY_AREA_NAME  \
# 0            1          AUTAUGA
# 1            1          AUTAUGA
# 2            1          AUTAUGA
# 3            1          AUTAUGA
# 4            1          AUTAUGA
#
#                                          ORIGIN_FILE
# 0  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 1  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 2  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 3  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 4  /home/jennyvo/KNP/files_to_publish/Govt_Units_...

# %% [markdown]
# ### 3. Combine the dataframes

# %%
df_general.columns
# Out:
# Index(['CENSUS_ID', 'NAME', 'UNIT_TYPE', 'TITLE', 'ADDRESS1', 'ADDRESS2',
#        'CITY', 'STATE_AB', 'ZIP', 'ZIP4', 'WEB_ADDRESS', 'POPULATION',
#        'POPULATION_YEAR', 'FIPS_STATE', 'FIPS_COUNTY', 'FIPS_PLACE',
#        'COUNTY_AREA_NAME', 'ORIGIN_FILE'],
#       dtype='object')

# %%
df_special.columns
# Out:
# Index(['CENSUS_ID', 'NAME', 'FUNCTION_NAME', 'TITLE', 'ADDRESS1', 'ADDRESS2',
#        'CITY', 'STATE_AB', 'ZIP', 'ZIP4', 'WEB_ADDRESS', 'FIPS_STATE',
#        'FIPS_COUNTY', 'COUNTY_AREA_NAME', 'ORIGIN_FILE'],
#       dtype='object')

# %%
df_general_special = pd.concat([df_general,df_special], axis=0, ignore_index=True)

# %%
df_general_special
# Out:
#             CENSUS_ID                                               NAME  \
# 0       1100100100000                                  COUNTY OF AUTAUGA
# 1       1100200200000                                  COUNTY OF BALDWIN
# 2       1100300300000                                  COUNTY OF BARBOUR
# 3       1100400400000                                     COUNTY OF BIBB
# 4       1100500500000                                   COUNTY OF BLOUNT
# ...               ...                                                ...
# 77316  51402340100000  CENTRAL WESTON COUNTY SOLID WASTE DISPOSAL DIS...
# 77317  51402340200000           CAMBRIA IMPROVEMENT AND SERVICE DISTRICT
# 77318  51402360100000            WESTON COUNTY NATURAL RESOURCE DISTRICT
# 77319  51402370200000            WESTON COUNTY PREDATORY ANIMAL DISTRICT
# 77320  51402370300000        SWEETWATER IMPROVEMENT AND SERVICE DISTRICT
#
#         UNIT_TYPE                 TITLE              ADDRESS1 ADDRESS2  \
# 0      1 - COUNTY          ADMINSTRATOR        135 N COURT ST    STE B
# 1      1 - COUNTY  COUNTY ADMINISTRATOR     312 COURTHOUSE SQ   STE 12
# 2      1 - COUNTY              CHAIRMAN            PO BOX 398      NaN
# 3      1 - COUNTY         ADMINISTRATOR    157 SW DAVIDSON DR      NaN
# 4      1 - COUNTY  COUNTY ADMINISTRATOR         220 2ND AVE E  STE 106
# ...           ...                   ...                   ...      ...
# 77316         NaN         TREASURER SEC            PO BOX 443      NaN
# 77317         NaN      SHARRON ACKERMAN     806 SALT CREEK RD      NaN
# 77318         NaN      DISTRICT MANAGER  1225 WASHINGTON BLVD    STE 3
# 77319         NaN             SECRETARY            PO BOX 358      NaN
# 77320         NaN                   NaN            PO BOX 879      NaN
#
#               CITY STATE_AB    ZIP    ZIP4                     WEB_ADDRESS  \
# 0       PRATTVILLE       AL  36067  3049.0        http://www.autaugaco.org
# 1      BAY MINETTE       AL  36507  4809.0  http://www.baldwincountyal.gov
# 2          CLAYTON       AL  36016   398.0                             NaN
# 3      CENTREVILLE       AL  35042  2277.0                             NaN
# 4          ONEONTA       AL  35121  1702.0     http://www.co.blount.al.us/
# ...            ...      ...    ...     ...                             ...
# 77316        OSAGE       WY  82723   443.0                             NaN
# 77317    NEWCASTLE       WY  82701     NaN                             NaN
# 77318    NEWCASTLE       WY  82701  2982.0                             NaN
# 77319        UPTON       WY  82730   358.0                             NaN
# 77320    NEWCASTLE       WY  82701     NaN                             NaN
#
#       POPULATION  POPULATION_YEAR  FIPS_STATE  FIPS_COUNTY  FIPS_PLACE  \
# 0         55,504           2017.0           1            1     99001.0
# 1        212,628           2017.0           1            3     99003.0
# 2         25,270           2017.0           1            5     99005.0
# 3         22,668           2017.0           1            7     99007.0
# 4         58,013           2017.0           1            9     99009.0
# ...          ...              ...         ...          ...         ...
# 77316        NaN              NaN          56           45         NaN
# 77317        NaN              NaN          56           45         NaN
# 77318        NaN              NaN          56           45         NaN
# 77319        NaN              NaN          56           45         NaN
# 77320        NaN              NaN          56           45         NaN
#
#       COUNTY_AREA_NAME                                        ORIGIN_FILE  \
# 0              AUTAUGA  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 1              BALDWIN  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 2              BARBOUR  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 3                 BIBB  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 4               BLOUNT  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# ...                ...                                                ...
# 77316           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77317           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77318           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77319           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77320           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
#
#                              FUNCTION_NAME
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 77316          81 - Solid Waste Management
# 77317            91 - Water Supply Utility
# 77318     88 - Soil and Water Conservation
# 77319         59 - Other Natural Resources
# 77320  99 - Other Multi-function Districts
#
# [77321 rows x 19 columns]

# %% [markdown]
# ### 4. Save the resultant dataframe

# %%
path_to_union = '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_Union.csv'
df_general_special.to_csv(path_to_union, sep=',', index=None)

# %% [markdown]
# # 4. Publish the union'ed result to the knowledge graph.

# %%
import kgpl_client as kgpl

# %%
path_to_union = '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_Union.csv'
file = kgpl.File(path_to_union)
value = kgpl.value(file,"General_Special_Union", "Jenny")
kgpl.variable(value, "General_Special_Union from Jenny", "Jenny")
# Out:
# Created: KGPLValue with ID http://lasagna.eecs.umich.edu:8080/val/3
# Created: KGPLVariable with ID http://lasagna.eecs.umich.edu:8080/var/2

# %% [markdown]
# # 5. Download the result and analyze it.

# %% [markdown]
# ### Download the result

# %%
VAR_ID_GIVEN_BY_USER2 = 'http://lasagna.eecs.umich.edu:8080/var/2'

needed_var_id = kgpl.load_var(VAR_ID_GIVEN_BY_USER2)
val_kgpl = kgpl.load_val(needed_var_id.val_id)
data_source = val_kgpl.val
path_to_var2 = data_source.filename
path_to_var2
# Out:
# '/home/jennyvo/KNP/files_to_publish/Govt_Units_2017_Final_Union.csv'

# %%
df_union = pd.read_csv(path_to_var2)
df_union
# Out:
# /home/jennyvo/env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (2,8,11,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             CENSUS_ID                                               NAME  \
# 0       1100100100000                                  COUNTY OF AUTAUGA
# 1       1100200200000                                  COUNTY OF BALDWIN
# 2       1100300300000                                  COUNTY OF BARBOUR
# 3       1100400400000                                     COUNTY OF BIBB
# 4       1100500500000                                   COUNTY OF BLOUNT
# ...               ...                                                ...
# 77316  51402340100000  CENTRAL WESTON COUNTY SOLID WASTE DISPOSAL DIS...
# 77317  51402340200000           CAMBRIA IMPROVEMENT AND SERVICE DISTRICT
# 77318  51402360100000            WESTON COUNTY NATURAL RESOURCE DISTRICT
# 77319  51402370200000            WESTON COUNTY PREDATORY ANIMAL DISTRICT
# 77320  51402370300000        SWEETWATER IMPROVEMENT AND SERVICE DISTRICT
#
#         UNIT_TYPE                 TITLE              ADDRESS1 ADDRESS2  \
# 0      1 - COUNTY          ADMINSTRATOR        135 N COURT ST    STE B
# 1      1 - COUNTY  COUNTY ADMINISTRATOR     312 COURTHOUSE SQ   STE 12
# 2      1 - COUNTY              CHAIRMAN            PO BOX 398      NaN
# 3      1 - COUNTY         ADMINISTRATOR    157 SW DAVIDSON DR      NaN
# 4      1 - COUNTY  COUNTY ADMINISTRATOR         220 2ND AVE E  STE 106
# ...           ...                   ...                   ...      ...
# 77316         NaN         TREASURER SEC            PO BOX 443      NaN
# 77317         NaN      SHARRON ACKERMAN     806 SALT CREEK RD      NaN
# 77318         NaN      DISTRICT MANAGER  1225 WASHINGTON BLVD    STE 3
# 77319         NaN             SECRETARY            PO BOX 358      NaN
# 77320         NaN                   NaN            PO BOX 879      NaN
#
#               CITY STATE_AB    ZIP    ZIP4                     WEB_ADDRESS  \
# 0       PRATTVILLE       AL  36067  3049.0        http://www.autaugaco.org
# 1      BAY MINETTE       AL  36507  4809.0  http://www.baldwincountyal.gov
# 2          CLAYTON       AL  36016   398.0                             NaN
# 3      CENTREVILLE       AL  35042  2277.0                             NaN
# 4          ONEONTA       AL  35121  1702.0     http://www.co.blount.al.us/
# ...            ...      ...    ...     ...                             ...
# 77316        OSAGE       WY  82723   443.0                             NaN
# 77317    NEWCASTLE       WY  82701     NaN                             NaN
# 77318    NEWCASTLE       WY  82701  2982.0                             NaN
# 77319        UPTON       WY  82730   358.0                             NaN
# 77320    NEWCASTLE       WY  82701     NaN                             NaN
#
#       POPULATION  POPULATION_YEAR  FIPS_STATE  FIPS_COUNTY  FIPS_PLACE  \
# 0         55,504           2017.0           1            1     99001.0
# 1        212,628           2017.0           1            3     99003.0
# 2         25,270           2017.0           1            5     99005.0
# 3         22,668           2017.0           1            7     99007.0
# 4         58,013           2017.0           1            9     99009.0
# ...          ...              ...         ...          ...         ...
# 77316        NaN              NaN          56           45         NaN
# 77317        NaN              NaN          56           45         NaN
# 77318        NaN              NaN          56           45         NaN
# 77319        NaN              NaN          56           45         NaN
# 77320        NaN              NaN          56           45         NaN
#
#       COUNTY_AREA_NAME                                        ORIGIN_FILE  \
# 0              AUTAUGA  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 1              BALDWIN  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 2              BARBOUR  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 3                 BIBB  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 4               BLOUNT  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# ...                ...                                                ...
# 77316           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77317           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77318           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77319           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
# 77320           WESTON  /home/jennyvo/KNP/files_to_publish/Govt_Units_...
#
#                              FUNCTION_NAME
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 77316          81 - Solid Waste Management
# 77317            91 - Water Supply Utility
# 77318     88 - Soil and Water Conservation
# 77319         59 - Other Natural Resources
# 77320  99 - Other Multi-function Districts
#
# [77321 rows x 19 columns]

# %% [markdown]
# ### Do whatever analyses with the downloaded data

# %%
from collections import Counter

# %%
titles = list(df_union.TITLE)
x = Counter(titles)

# %%
y = sorted(x.items(), key=lambda item: item[1])
y.reverse()
x_sorted = {k: v for k, v in y}

# %%
x_sorted
# Out:
# {'MAYOR': 5787,
#  'CHAIRMAN': 3121,
#  'CLERK': 2890,
#  'ADMINISTRATOR': 2890,
#  'TREASURER': 2752,
#  'EXECUTIVE DIRECTOR': 2395,
#  'CITY CLERK': 2225,
#  'SUPERVISOR': 2129,
#  'DIRECTOR': 2110,
#  'SECRETARY': 1914,
#  'TRUSTEE': 1658,
#  'PRESIDENT': 1430,
#  'TOWN CLERK': 986,
#  'MANAGER': 973,
#  'OFFICE MANAGER': 917,
#  'FISCAL OFFICER': 898,
#  nan: 842,
#  'CHAIR': 806,
#  'CHAIRPERSON': 792,
#  'DISTRICT MANAGER': 772,
#  'CLERK TREASURER': 702,
#  'TOWNSHIP CHAIRMAN': 676,
#  'FIRE CHIEF': 673,
#  'CITY MANAGER': 638,
#  'SECRETARY TREASURER': 589,
#  'GENERAL MANAGER': 548,
#  'ATTORNEY': 541,
#  'FINANCE DIRECTOR': 538,
#  'CITY ADMINISTRATOR': 524,
#  'TOWNSHIP SUPERVISOR': 522,
#  'BOOKKEEPER': 516,
#  'SECRETARY/TREASURER': 492,
#  'VILLAGE CLERK': 449,
#  'ADMINISTRATIVE ASSISTANT': 420,
#  'ACCOUNTANT': 407,
#  'TOWN SUPERVISOR': 400,
#  'AUDITOR-CONTROLLER': 367,
#  'TOWN MANAGER': 361,
#  'COMMISSIONER': 352,
#  'SEC TREAS': 347,
#  'CITY SECRETARY': 345,
#  'TOWNSHIP TRUSTEE': 333,
#  'COUNTY CLERK': 303,
#  'LIBRARY DIRECTOR': 302,
#  'CLERK/TREASURER': 293,
#  'CHIEF': 292,
#  'BOARD CHAIRPERSON': 286,
#  'FINANCE OFFICER': 286,
#  'TOWNSHIP FISCAL OFFICER': 269,
#  'TOWNSHIP CLERK': 240,
#  'TOWN ADMINISTRATOR': 225,
#  'BOARD MEMBER': 209,
#  'COUNTY JUDGE': 209,
#  'AUDITOR': 205,
#  'CONTROLLER': 202,
#  'DIRECTOR OF FINANCE': 201,
#  'DISTRICT CLERK': 194,
#  'CFO': 183,
#  'DISTRICT SECRETARY': 180,
#  'CITY RECORDER': 174,
#  'VILLAGE PRESIDENT': 174,
#  'BUSINESS MANAGER': 169,
#  'COUNTY ADMINISTRATOR': 166,
#  'ALLEN BOONE HUMPHRIES ROBINSON LLP': 162,
#  'FIRE DISTRICT TREASURER': 160,
#  'TOWNSHIP MANAGER': 149,
#  'FINANCE MANAGER': 148,
#  'CLERK-TREASURER': 148,
#  'CITY AUDITOR': 146,
#  'TOWN CHAIR': 143,
#  'BOROUGH MANAGER': 141,
#  'EXEC DIRECTOR': 133,
#  'CITY CLERK TREASURER': 128,
#  'SECRETARY-TREASURER': 126,
#  'PARALEGAL': 123,
#  'CHIEF FINANCIAL OFFICER': 121,
#  'CPA': 118,
#  'DISTRICT ADMINISTRATOR': 114,
#  'SUPERINTENDENT': 114,
#  'VILLAGE MAYOR': 114,
#  'TOWN CHAIRMAN': 104,
#  'FIRST SELECTMAN': 102,
#  'CITY CLERK/TREASURER': 102,
#  'DEPUTY CLERK': 101,
#  'WHITE BEAR ANKELE TANAKA & WALDRON': 99,
#  'VILLAGE ADMINISTRATOR': 97,
#  'DNREC DIV WATERSHED STEWARDSHIP': 95,
#  'WHITE BEAR & ANKELE, PC': 94,
#  'OUTSOURCING CLIFTON LARSON ALLEN LLP': 94,
#  'COMPTROLLER': 90,
#  'ACCOUNTING MANAGER': 90,
#  'MUNICIPAL CLERK': 87,
#  'COLLINS COCKREL & COLE': 86,
#  'CEO': 84,
#  'CLERK TREAS': 82,
#  'EXECUTIVE ASSISTANT': 81,
#  'LIBRARIAN': 76,
#  'TREAS': 76,
#  'COUNTY MANAGER': 76,
#  'SEC': 72,
#  'ADMINISTRATIVE SECRETARY': 65,
#  'OFFICE ADMINISTRATOR': 65,
#  'DISTRICT COORDINATOR': 64,
#  'BOARD CHAIRMAN': 63,
#  'DEPUTY TREASURER': 63,
#  'PDA COORDINATOR PAUL BIDDLE': 62,
#  'BOARD PRESIDENT': 62,
#  'BOARD OF DIRECTORS': 61,
#  'BOROUGH SECRETARY': 61,
#  'EXECUTIVE SECRETARY': 61,
#  'ADMIN ASSISTANT': 60,
#  'SEC TREASURER': 58,
#  'ADMINISTRATIVE COORDINATOR': 58,
#  'PLANNING DIRECTOR': 57,
#  'DIRECTOR OF SPECIAL DISTRICT': 56,
#  'COUNTY AUDITOR': 56,
#  'OFFICE MGR': 54,
#  'ADMIN ASST': 53,
#  'JUDGE EXECUTIVE': 52,
#  'VILLAGE MANAGER': 52,
#  'ATTORNEY AT LAW': 51,
#  'RECORDER': 51,
#  'FULLENKAMP, DOYLE & JOBEUN, ATTYS.': 50,
#  'AIRPORT MANAGER': 50,
#  'DIRECTOR / ADMINISTRATOR': 50,
#  'VILLAGE CLERK TREASURER': 49,
#  'SECRETARY / TREASURER': 48,
#  'ASSISTANT CITY MANAGER': 47,
#  'CITY PLANNER': 47,
#  'MILLER & ASSOCIATES LAW OFFICES LLC': 46,
#  'SCHWARTZ, PAGE & HARDING': 45,
#  'MARCHETTI & WEAVER, LLC': 45,
#  'BOARD CHAIR': 45,
#  'TOWN CLERK TREASURER': 45,
#  'COMMUNITY DEVELOPMENT DIRECTOR': 44,
#  'COORDINATOR': 43,
#  'CITY TREASURER': 43,
#  'PRES': 41,
#  'ADMINISTRATIVE MANAGER': 40,
#  'SOLICITOR': 39,
#  'FINANCE DEPT': 39,
#  'ATTORNEYS': 38,
#  'RECORDER TREASURER': 38,
#  'WHITE BEAR & ANKELE, P.C.': 37,
#  'TREASURE': 37,
#  'VILLAGE TREASURER': 36,
#  'SENIOR PLANNER': 36,
#  'ACCOUNTING SUPERVISOR': 35,
#  'SMITH MURDAUGH LITTLE & BONHAM LLP': 34,
#  'TOWNSHIP SECRETARY': 34,
#  'TWP SUPERVISOR': 34,
#  'COUNCIL PRESIDENT': 34,
#  'COUNTY EXECUTIVE': 33,
#  'EXEC DIR': 32,
#  'DISTRICT TREASURER': 31,
#  'CHAIRMAN OF THE BOARD': 31,
#  'DIRECTOR OF ADMINISTRATION': 31,
#  'ASSISTANT DIRECTOR': 30,
#  'SEC/TREAS': 30,
#  'ADMINISTRATION': 30,
#  'SENIOR ACCOUNTANT': 30,
#  'HUMAN RESOURCES': 30,
#  'COUNTY MAYOR': 29,
#  'CHAIRMAN OF BOARD': 29,
#  'SELECTMAN': 29,
#  'BOARD SECRETARY': 29,
#  'ASSESSOR': 29,
#  'CITY CLERK-TREASURER': 29,
#  'SPENCER FANE LLP': 28,
#  'EX DIRECTOR': 28,
#  'SPECIAL PROJECTS COORDINATOR': 28,
#  'SECY TREAS': 28,
#  'ASSISTANT MANAGER': 28,
#  'SEC TRES': 28,
#  'CHAIR PERSON': 28,
#  'DEPUTY CITY CLERK': 28,
#  'WILLIAM RIZZETTA': 27,
#  'FINANCIAL MANAGER': 27,
#  'SECY': 26,
#  'VILLAGE CLERK/TREASURER': 26,
#  'TOWN CLERK/TREASURER': 26,
#  'SEVERN TRENT-NORTH AMERICA': 25,
#  'BOROUGH ADMINISTRATOR': 25,
#  'ATTORNEY FOR DISTRICT': 24,
#  'TRUSTEE TREASURER': 24,
#  'DECATUR COUNTY CLERK': 24,
#  'DEPUTY AUDITOR': 24,
#  'CHIEF EXECUTIVE OFFICER': 24,
#  'PLANNER': 24,
#  'SOIL CONSERVATIONIST': 23,
#  'ACCOUNTING': 23,
#  'SECRETARY/ TREASURER': 23,
#  'BOROUGH CLERK': 23,
#  'TRUSTEE/TREASURER': 23,
#  'COUNTY COMMISSIONER': 23,
#  'FINANCE DEPARTMENT': 23,
#  'RECORDING SECRETARY': 22,
#  'DISTRICT CONSERVATIONIST': 22,
#  'AGENT': 22,
#  'SEC TREA': 22,
#  'BUSINESS ADMINISTRATOR': 22,
#  'TWP CLERK': 22,
#  'TWP TRUSTEE': 22,
#  'ADMINISTRATIVE OFFICER': 22,
#  'FINANCIAL CLERK': 22,
#  'ADM ASST': 22,
#  'SEC./TREAS.': 21,
#  'ATTORNEY FOR THE DISTRICT': 21,
#  'OPERATOR': 21,
#  'ASSISTANT TREASURER': 21,
#  'CLERK OF THE BOARD': 21,
#  'DIRECTOR OF PLANNING': 21,
#  'CITY CLERK TREAS': 21,
#  'JUDGE': 21,
#  'OPERATIONS MANAGER': 20,
#  'PRESIDING COMMISSIONER': 20,
#  'SECRETARY BOOKKEEPER': 20,
#  'ADMINISTRATIVE ASST': 20,
#  'ASSISTANT FINANCE DIRECTOR': 20,
#  'FINANCIAL OFFICER': 20,
#  'ASSISTANT TO THE CITY MANAGER': 20,
#  'LEGAL ASSISTANT': 19,
#  'AUTHORITY MANAGER': 19,
#  'PARALEGAL / ADMIN ASSISTANT': 19,
#  'DISTRICT ADMINISTRATIVE COORDINATOR': 19,
#  'TOWN CHAIRPERSON': 19,
#  'ADMINISTRATIVE SERVICES MANAGER': 19,
#  'VICE PRESIDENT': 19,
#  'TOWNSHIP CHAIRPERSON': 19,
#  'FINANCIAL ANALYST': 19,
#  'DIRECTOR OF ADMINISTRATIVE SERVICES': 19,
#  'CLERK RECORDER': 19,
#  'FINANCE CLERK': 19,
#  'DRAINAGE CLERK': 18,
#  'HOPPING GREEN & SAMS': 18,
#  'PROPERTY MANAGER': 18,
#  'ICENOGLE SEAVER POGUE PC': 18,
#  'DISTRICT DIRECTOR': 18,
#  'KEENAN & ASSOCIATES SETECH': 18,
#  'SUPERVISOR CHAIRMAN': 18,
#  'TOWNSHIP ADMINISTRATOR': 18,
#  'BUDGET OFFICER': 18,
#  'FIN. OFFICER': 18,
#  'STAFF ACCOUNTANT': 18,
#  'PLANNING DEPARTMENT': 18,
#  'DIRECTOR OF OPERATIONS': 18,
#  'CRAWFORD & JORDON LLP': 17,
#  'DENNIS LYLES': 17,
#  'EX DIR': 17,
#  'PRESIDENT OF BOARD': 17,
#  'AUDITOR / COUNTY CLERK': 17,
#  'RECORDER/TREASURER': 17,
#  'COUNTY TREASURER': 17,
#  'FINANCE': 17,
#  'COMMISSIONERS': 16,
#  'DISTRICT ACCOUNTANT': 16,
#  'ASSISTANT SECRETARY': 16,
#  'ACCOUNTING CLERK': 16,
#  'FINANCIAL DIRECTOR': 16,
#  'CITY MAYOR': 16,
#  'MGR': 16,
#  'BOOK KEEPER': 15,
#  'REGIONAL REPRESENTATIVE': 15,
#  'TREASURER SECRETARY': 15,
#  'FINANCIAL SECRETARY': 15,
#  'PROGRAM MANAGER': 15,
#  'ADMIN': 15,
#  'POLICE JURY PRESIDENT': 15,
#  'DEPUTY CLERK TREASURER': 15,
#  'TOWN TREASURER': 15,
#  'EMERGENCY MANAGEMENT COORDINATOR': 14,
#  'BACON & WALLACE LLP': 14,
#  'REGISTERED AGENT': 14,
#  'CARLA HAWKINS': 14,
#  'SETER & VANDER WALL PC': 14,
#  'GENERAL COUNSEL': 14,
#  'PROGRAM COORDINATOR': 14,
#  'PROJECT MANAGER': 14,
#  'RESOURCE CONSERVATIONIST': 14,
#  'DISTRICT TECHNICIAN': 14,
#  'SECRETARY & TREASURER': 14,
#  'TAX COLLECTOR': 14,
#  'REPUBLIC COUNTY CLERK': 14,
#  'BUDGET DIRECTOR': 14,
#  'CITY ADMIN': 14,
#  'ADMIN ASSIST': 14,
#  'DIRECTOR OF COMMUNITY DEVELOPMENT': 14,
#  'CHIEF ADMINISTRATIVE OFFICER': 14,
#  'SCHWARTZ PAGE & HARDING LLP': 13,
#  'CONSERVATIONIST': 13,
#  'ATTORNEY AND SECRETARY OF DRAINAGE D': 13,
#  'DEPUTY DIRECTOR': 13,
#  'DEPUTY CHIEF': 13,
#  'ATTORNEYS AT LAW': 13,
#  'BOOKKEEPER SECRETARY': 13,
#  'FIRE COMMISSIONER': 13,
#  'GEN MGR': 13,
#  'ADMIN SECRETARY': 13,
#  "COUNTY JUDGE'S OFFICE": 13,
#  'LAWYER': 13,
#  'COUNTY COMMISSION': 13,
#  'ADMINISTRATIVE CLERK': 13,
#  'TOWNSHIP TREASURER': 13,
#  'MEMBER': 13,
#  'HR DIRECTOR': 13,
#  'TOWN PLANNER': 13,
#  'ASSISTANT CITY ADMINISTRATOR': 13,
#  'PROGRAM SPECIALIST II': 12,
#  'COLLABORATIVE COORDINATOR': 12,
#  'AGENT DENNIS LYLES': 12,
#  'SEXTON': 12,
#  'MEGAN HOLBERG': 12,
#  'DIRECTOR OF ACCOUNTING': 12,
#  'SECRETARY - TREASURER': 12,
#  'SECRETARY TREASURE': 12,
#  'ASSISTANT CHIEF': 12,
#  'TOWN COUNCIL PRESIDENT': 12,
#  'DEPUTY COUNTY CLERK': 12,
#  'HUMAN RESOURCES DIRECTOR': 12,
#  'DEPUTY CITY MANAGER': 12,
#  'ASSOCIATE PLANNER': 12,
#  'MANAGEMENT ANALYST': 12,
#  'PUBLIC WORKS DIRECTOR': 12,
#  'PANSING, HOGAN, ERNST & BACHMAN, LLP': 11,
#  'TAX DITCH CLERK': 11,
#  'DISTRICT ADMINISTRATIVE SECRETARY': 11,
#  'AGENT WILLIAM RIZZETTA': 11,
#  'SUPT': 11,
#  'SECRETARY TREAS': 11,
#  'EXECUTIVE': 11,
#  'CLERK/SECRETARY': 11,
#  'BOOKEEPER': 11,
#  'VILLAGE CLERK-TREASURER': 11,
#  'PRESIDENT OF THE BOARD': 11,
#  'SECRETARY CLERK': 11,
#  'CHANCERY CLERK': 11,
#  'SUPERVISOR/CHAIRMAN': 11,
#  'TOWN SECRETARY': 11,
#  'BOARD OF SUPERVISORS': 11,
#  'CONSULTANT': 11,
#  'OFFICE CLERK': 11,
#  'HR MANAGER': 11,
#  'CITY ADMINISTRATOR CLERK': 11,
#  'MULLER LAW GROUP': 10,
#  'CROKER,HUCK,KASHER,DEWITT,ANDERSON,GONDERINGE': 10,
#  'DELORES OTTO': 10,
#  'STATE SECRETARY': 10,
#  'ATTORNEY/DISTRICT SECRETARY': 10,
#  'MERITUS CORP': 10,
#  'OFFICE COORDINATOR': 10,
#  'BUSINESS OFFICE MANAGER': 10,
#  'ICENOGLE SEAVER POGUE, P.C.': 10,
#  'PROGRAM ADMINISTRATOR': 10,
#  'SECRETARY TO THE BOARD': 10,
#  'BOARD CLERK': 10,
#  'GENERAL MGR': 10,
#  'OFFICE SUPERVISOR': 10,
#  'DIRECTOR OF FINANCIAL SERVICES': 10,
#  'OFFICE SECRETARY': 10,
#  'SECRETARY MANAGER': 10,
#  'DIRECTOR OF FINANCE & ADMINISTRATION': 10,
#  'BOROUGH SECRETARY/TREASURER': 10,
#  'ADMINISTRATIVE DIRECTOR': 10,
#  'CHAIRMAN SUPERVISOR': 10,
#  'ASSISTANT CLERK': 10,
#  'MORRIS COUNTY CLERK': 10,
#  'TRUSTEE/ASSESSOR': 10,
#  'CLERK TREASURE': 10,
#  'COUNCIL MEMBER': 10,
#  'SUPERVISER': 10,
#  'FIN. OFFICER/TREAS.': 10,
#  'TREASURER CLERK': 10,
#  'CHIEF OF STAFF': 10,
#  'ASSISTANT TOWN MANAGER': 10,
#  'FINANCE ADMINISTRATOR': 10,
#  'COMMISIONER': 10,
#  'DEPUTY FINANCE DIRECTOR': 10,
#  'PRINCIPAL PLANNER': 10,
#  'PLANNING MANAGER': 10,
#  'DIRECTOR OF PUBLIC WORKS': 10,
#  'ADM ASSISTANT': 10,
#  'PAYROLL CLERK': 10,
#  'ADMINISTRATIVE SERVICES DIRECTOR': 10,
#  'ASSISTANT PLANNER': 10,
#  'ASSISTANT ADMINISTRATOR': 10,
#  'MARY BOTT C/O BOTT & DOUTHITT': 9,
#  'FULBRIGHT & JAWORSKI': 9,
#  'ADM SECRETARY': 9,
#  'TINA SCHLEMME': 9,
#  'SEC TREASURE': 9,
#  'PARALEGAL/ ADMIN ASSISTANT': 9,
#  'SECRETARY/BOOKKEEPER': 9,
#  'BOARDMEMBER': 9,
#  'PAMELA A FORBUS': 9,
#  'ASSISTANT EXECUTIVE DIRECTOR': 9,
#  'AIRPORT DIRECTOR': 9,
#  'SECTY TREAS': 9,
#  'SECT TREAS': 9,
#  'CHIEF CLERK': 9,
#  'TOWN CLERK/FINANCE OFFICER': 9,
#  'CHIEF FISCAL OFFICER': 9,
#  'VICE CHAIRMAN': 9,
#  'TRESURER': 9,
#  'OFFICE ADMIN': 9,
#  'DIRECTOR OF HUMAN RESOURCES': 9,
#  'GIS COORDINATOR': 9,
#  'EXECUTIVE ADMINISTRATOR': 9,
#  'TRES': 9,
#  'ADMINSTRATIVE ASSISTANT': 9,
#  'ZONING ADMINISTRATOR': 9,
#  'CITY MGR': 9,
#  'COUNTY COORDINATOR': 9,
#  'COUNCILMAN': 9,
#  'ADMINSTRATOR': 9,
#  'STRAWN & RICHARDSON PC ATTORNEYS': 8,
#  'COUNTY CLERK & RECORDER': 8,
#  'PORT DIRECTOR': 8,
#  'CONTRACTING OFFICER': 8,
#  'PRESIDENT BOARD OF TRUSTEES': 8,
#  'JAMES COTTRELL ATTORNEY': 8,
#  'PAYROLL': 8,
#  'LEWIS, LONGMAN & WALKER, PA': 8,
#  'GUY JOHNSON': 8,
#  'G M': 8,
#  'EXECUTIVE OFFICER': 8,
#  'PRESIDENT BOARD OF DIRECTORS': 8,
#  'ASSESSOR KAPP': 8,
#  'E D': 8,
#  'HEAD LIBRARIAN': 8,
#  'HOUSING MANAGER': 8,
#  'DISTRICT ADMIN': 8,
#  'EXECUTIVE DIR': 8,
#  'ADMINISTRATIVE ASST.': 8,
#  'FISCAL OFFICE': 8,
#  'ENGINEER': 8,
#  'ADMIN SEC': 8,
#  'FINANCIAL ADMINISTRATOR': 8,
#  'TWP CHAIRMAN': 8,
#  'CHARIMAN': 8,
#  'TOWNSHIP CHAIR': 8,
#  'TOWN ADMIN': 8,
#  'PARISH PRESIDENT': 8,
#  'CLERK ADMINISTRATOR': 8,
#  'ANDERSON COUNTY CLERK': 8,
#  'SUPV': 8,
#  'OFFICE ASSISTANT': 8,
#  'CLERK TRES': 8,
#  'HUMAN RESOURCES MANAGER': 8,
#  'HR': 8,
#  'FINANCE OFFICE': 8,
#  'CITY CLERK ADMINISTRATOR': 8,
#  'ASST TREASURER': 8,
#  'ASSISTANT COUNTY ADMINISTRATOR': 8,
#  'MARKS, RICHARDSON P.C.': 7,
#  'NORTON ROSE FULBRIGHT': 7,
#  'DISTRICT PROGRAM ADMINISTRATOR': 7,
#  'FIRE DISTRICT SECRETARY/TREASURER': 7,
#  'FIRE DISTRICT SECRETARY': 7,
#  'MAYORDOMO': 7,
#  'FULLENKAMP DOYLE': 7,
#  'EXE DIRECTOR': 7,
#  'WABASH CO TREASURER': 7,
#  'COMMISSIONER TREASURER': 7,
#  'SUPERINTENDENT OF FINANCE': 7,
#  'DRAINAGE COMMISSIONER': 7,
#  'OFFICE MANGER': 7,
#  'FINANCE ASSOCIATE': 7,
#  'SITE MANAGER': 7,
#  'MANAGING AGENT': 7,
#  'SUE GONZALES': 7,
#  'ED': 7,
#  'BOARD DIRECTOR': 7,
#  'ASSISTANT CONTROLLER': 7,
#  'DEPUTY GENERAL MANAGER': 7,
#  'SEC/TREASURER': 7,
#  'DIST MGR': 7,
#  'AUDITOR CONTROLLER': 7,
#  'WILLIAMS & ANDERSON': 7,
#  'CAPTAIN': 7,
#  'ADMINISTRATION MANAGER': 7,
#  'DIRECTOR OF FINANCE AND ADMINISTRATI': 7,
#  'SECY TREASURER': 7,
#  'VILLAGE CLERK TREAS': 7,
#  'BUSINESS MGR': 7,
#  'CLERK/ADMINISTRATOR': 7,
#  'COUNTY JUDGE EXECUTIVE': 7,
#  'DEPUTY CLERK/TREASURER': 7,
#  'CHIEF DEPUTY AUDITOR': 7,
#  'TREASURER/SECRETARY': 7,
#  'TREAS./ADMIN.': 7,
#  'CLERK / TREASURER': 7,
#  'SR ACCOUNTANT': 7,
#  'CITY CLERK / TREASURER': 7,
#  'ASSISTANT DIRECTOR OF FINANCE': 7,
#  'TOWN MGR': 7,
#  'DEVELOPMENT SERVICES DIRECTOR': 7,
#  'YOUNG & BROOKS, ATTORNEYS': 6,
#  'MELISA MONTAGUE': 6,
#  'PORT MANAGER': 6,
#  'OFFICE MANAGER SEDO': 6,
#  'BRINEY WELBORN': 6,
#  'VANMATRE HARRISON HOLLIS TAYLOR & ELLIOTT PC': 6,
#  'ADM SEC': 6,
#  'SUPERINTENDANT': 6,
#  'PROGRAM DIRECTOR': 6,
#  'OFFICE': 6,
#  'INTERIM DIRECTOR': 6,
#  'ATTY': 6,
#  'PRESIDENT, BOARD OF TRUSTEES': 6,
#  'MANAGER ASSOCIATE': 6,
#  'REC SEC': 6,
#  'ACCOUNT MANAGER': 6,
#  'DISTRICT PRESIDENT': 6,
#  'MILLER & ASSOCIATES LAW OFFICES, LLC': 6,
#  'PINNACLE CONSULTING GROUP INC': 6,
#  'ACCOUNTING DEPARTMENT': 6,
#  'INTERIM EXECUTIVE DIRECTOR': 6,
#  'ASSISTANT FIRE CHIEF': 6,
#  'ASSISTANT GENERAL MANAGER': 6,
#  'MANAGER OF FINANCE': 6,
#  'DISTRICT MGR': 6,
#  'DAC': 6,
#  'FISCAL MANAGER': 6,
#  'CITY SEC': 6,
#  'SEC/TRES': 6,
#  'TOWN RECORDER': 6,
#  'BOARD OF TRUSTEES': 6,
#  'TRUSTEE PRESIDENT': 6,
#  'TREA': 6,
#  'TOWNSHIP CLERK/TREASURER': 6,
#  'MUNICIPAL MANAGER': 6,
#  'CLERK SECRETARY': 6,
#  'VILLAGE CHAIRMAN': 6,
#  'TRUSTEE CHAIRMAN': 6,
#  'CHAIRMAN BOARD OF SUPERVISORS': 6,
#  'SUPERVISOR CHAIR': 6,
#  'FINANCE ASSISTANT': 6,
#  'AUDITOR/TREASURER': 6,
#  'CLERK OF BOARD': 6,
#  'TOWNSHIP': 6,
#  'ADMINISTRATOR/CLERK': 6,
#  'CHAIRMAN BOARD OF COMMISSIONERS': 6,
#  'DEPUTY COUNTY ADMINISTRATOR': 6,
#  'TOWN ACCOUNTANT': 6,
#  'FIRST ASSESSOR': 6,
#  'CHAIRMEN': 6,
#  'ADMINISTRATIVE SPECIALIST': 6,
#  'DEPUTY SUPERVISOR': 6,
#  'ALDERMAN': 6,
#  'ASST. TREASURER': 6,
#  'CLERK/TREAS.': 6,
#  'PAYROLL MANAGER': 6,
#  'CHIEF DEPUTY': 6,
#  'BUILDING INSPECTOR': 6,
#  'GIS MANAGER': 6,
#  'ADM': 6,
#  'CLERK OF COUNCIL': 6,
#  'WARDEN': 6,
#  'PUBLIC INFORMATION OFFICER': 6,
#  'CITY CONTROLLER': 6,
#  'COUNTY ADMINISTRATIVE OFFICER': 6,
#  'ASST CITY MANAGER': 6,
#  'CITY ADMINSTRATOR': 6,
#  'ASSISTANT TO THE MAYOR': 6,
#  'COMMISSION CHAIRMAN': 6,
#  'FULBRIGHT AND JAWORSKI': 5,
#  'SCHWARTZ PAGE AND HARDING': 5,
#  'ALLEN BOONE HUMPHRIES LLP': 5,
#  'SECRETARY COMMISSIONER': 5,
#  'DEPUTY CLERK & RECORDER': 5,
#  'HUSCH BLACKWELL LLP': 5,
#  'DALE BESTON': 5,
#  'DISTRICT COUNSEL': 5,
#  'CHANCERY COURT JUDGE': 5,
#  'OPERATIONS DIRECTOR': 5,
#  'FEE ACCOUNTANT': 5,
#  'DISTRICT CHAIRMAN': 5,
#  'EXECTIVE DIRECTOR': 5,
#  'COMMISSIONER SECRETARY': 5,
#  'HOUSING DIRECTOR': 5,
#  'DIST CONSERVATIONIST': 5,
#  'GREG LIETZ ATTORNEY': 5,
#  'SEC-TREAS': 5,
#  'ACTING DIRECTOR': 5,
#  'MGR./DIRECTOR': 5,
#  'DIST TREASURER': 5,
#  'JAMES COTTRELL, ATTORNEY': 5,
#  'PRESIDENT OF TRUSTEES': 5,
#  'DANIEL B HARRELL': 5,
#  'GUNDERSON LLP': 5,
#  'CERTIFIED PUBLIC ACCOUNTANT': 5,
#  'WHITE BEAR ANKELE TANAKA & WALDR': 5,
#  'SPENCER FANE': 5,
#  'TRANSIT MANAGER': 5,
#  'FINANCIAL COORDINATOR': 5,
#  'CHEIF': 5,
#  'DISTRICT MANGER': 5,
#  'TRUSTEES': 5,
#  'ADMIN MGR': 5,
#  'DIRECTOR TREASURER': 5,
#  'LIBRARY MANAGER': 5,
#  'SECRETARY COUNSEL': 5,
#  'ADMIN SPECIALIST': 5,
#  'TECHNICIAN': 5,
#  'RAY OWEN JR ATTORNEY': 5,
#  'LAWYER SECRETARY': 5,
#  'PRESIDENT CEO': 5,
#  'MANAGER OPERATOR': 5,
#  'CHIEF OF DEPARTMENT': 5,
#  'SELECTBOARD CHAIR': 5,
#  'CITY FINANCE OFFICER': 5,
#  'SECRETARY/TREASURE': 5,
#  'SECRETARY TRESURER': 5,
#  'MANAGING DIRECTOR': 5,
#  'SECRETARY ADMINISTRATOR': 5,
#  'ZONING OFFICER': 5,
#  'ADMIN OFFICER': 5,
#  'ZONING INSPECTOR': 5,
#  'CHAIRWOMAN': 5,
#  'FISCAL SUPERVISOR': 5,
#  'TOWNSHIP SUPERVISOR, CHAIRMAN': 5,
#  'CHR': 5,
#  'SEC/TREAS.': 5,
#  'TOWNSHIP CLERK & TREASURER': 5,
#  'HR DEPARTMENT': 5,
#  'TOWN CLERK FINANCE OFFICER': 5,
#  'BOARD OF COMMISSIONERS': 5,
#  'C F O': 5,
#  'PRESIDENT CHAIRMAN': 5,
#  'COMMISSIONER CHAIRMAN': 5,
#  'CLERK AND RECORDER': 5,
#  'TREASURER/TRUSTEE': 5,
#  'CHAIRMAN BOARD OF TRUSTEES': 5,
#  'COO': 5,
#  'SUPERVISOR CLERK': 5,
#  ' CLERK': 5,
#  'EXECUTIVE ASSISTANT TO THE MAYOR': 5,
#  'ADMINISTRATOR CLERK': 5,
#  'TOWNSHIP TRUSTEE/ASSESSOR': 5,
#  'TRUSTEE TOWNSHIP': 5,
#  'BOARD PRES': 5,
#  'COMMISSIONERS SECRETARY': 5,
#  'ROAD COMMISSIONER': 5,
#  'CODE ENFORCEMENT OFFICER': 5,
#  'PRES OF BOARD': 5,
#  'CLERK/TREAS': 5,
#  'FINANCE DIRECTOR/TREASURER': 5,
#  'TERASURER': 5,
#  'BUILDING OFFICIAL': 5,
#  'MAYOR CLERK': 5,
#  'PLANNING COORDINATOR': 5,
#  'CHIEF ACCOUNTANT': 5,
#  'PROJECT COORDINATOR': 5,
#  'DEPUTY TOWN MANAGER': 5,
#  'CITY CLERK/ADMINISTRATOR': 5,
#  'DIRECTOR OF PLANNING AND DEVELOPMENT': 5,
#  'BUDGET MANAGER': 5,
#  'FINANCIAL SERVICES MANAGER': 5,
#  'ACCOUNTING SPECIALIST': 5,
#  'PLANNING TECHNICIAN': 5,
#  'EXECUTIVE ASST': 5,
#  'CITY ATTORNEY': 5,
#  'ASSISTANT CITY CLERK': 5,
#  'ASST CLERK': 5,
#  'TOWN CLERK-TREASURER': 5,
#  'COUNTY ADMIN': 5,
#  'MARQUETTE COUNTY DRAINAGE BOARD': 4,
#  'JOHNSON PETROV LLP': 4,
#  'ALLEN BOONE HUMPHRIES ROBINON LLP': 4,
#  'DISTRICT PROJECT ASSISTANT': 4,
#  'C/O PRECINCT 7 DIRECTOR': 4,
#  'COATS ROSE YALE RYMAN AND LEE PC': 4,
#  'SWCD CLERK': 4,
#  'ALLEN BOONE HUMPHRIES ROBINSON': 4,
#  'TECHNICAL ASSISTANT': 4,
#  'ALLEN DOUTHITT': 4,
#  'BUSINESS SECRETARY': 4,
#  'LIBRARY TREASURER': 4,
#  'CLERK/BOOKKEEPER': 4,
#  'DIEGO JARAMILLO': 4,
#  'PRINCIPAL ACCOUNT CLERK': 4,
#  'FULLENKAMP DOYLE & JOBEUN': 4,
#  'GRANITE CO TREASURER': 4,
#  'SYSTEM MANAGER': 4,
#  'STODDARD COUNTY CLERK': 4,
#  'SECTY/TREAS': 4,
#  'COUNTY FIRE COORDINATOR': 4,
#  'MANAGER OF ACCOUNTING': 4,
#  'HOUSING COORDINATOR': 4,
#  'PRUDENTIAL COMMITTEE': 4,
#  'PLANT MANAGER': 4,
#  'EMS DIRECTOR': 4,
#  "APPRAISER'S OFFICE": 4,
#  'SECRETERY': 4,
#  'BOARD': 4,
#  'REAL ESTATE AND DRAINAGE CLERK': 4,
#  'BUSINESS OFFICE': 4,
#  'DISTRICT SUPERVISOR': 4,
#  'DISTRICT ATTORNEY': 4,
#  'ADMINISTRATIVE COORD': 4,
#  'CEO/ADMINISTRATOR': 4,
#  'ASST DIRECTOR': 4,
#  'CONSERVATION ASSISTANT': 4,
#  'DISTRICT ADMINISTRATION': 4,
#  'WILLIAM J. RIZZETTA': 4,
#  'DISTRICT MANAGEMENT SERVICES': 4,
#  'HOPPING GREEN & SAMS PA': 4,
#  'DNEC DIV WATERSHED STEWARDSHIP': 4,
#  'DMREC DIV WATERSHED STEWARDSHIP': 4,
#  'ADMIN. ASST.': 4,
#  'FOLKESTAD FAZEKAS BARRICK & PATOILE': 4,
#  'CLIFTON LARSON ALLEN LLP': 4,
#  'URBAN FRONTIER': 4,
#  'PARALEGAL /ADMIN ASSISTANT': 4,
#  'FIRE CHEIF': 4,
#  'SECRATARY': 4,
#  'SECRETARY/MANAGER': 4,
#  'ADMIN MANAGER': 4,
#  'GM': 4,
#  'FINANCE COORDINATOR': 4,
#  'CHIEF FINANCE OFFICER': 4,
#  'ADMINISTRATIVE SERVICES OFFICER': 4,
#  'CHAIRMAN BOARD': 4,
#  'C.F.O.': 4,
#  'DISTRICT BOOKKEEPER': 4,
#  'WRIGHT LINDSEY & JENNINGS': 4,
#  'DISTRICT OFFICE MANAGER': 4,
#  'COMMISSONER': 4,
#  'OFF MGR': 4,
#  'BATTALION CHIEF': 4,
#  'OPERATIONS ADMINISTRATOR': 4,
#  'EXECUTIVE MANAGER': 4,
#  'DIR OF ADMIN': 4,
#  'ASST TOWN CLERK': 4,
#  'ACCOUNTING ADMINISTRATOR': 4,
#  'CHAIRMAN, BOARD OF SUPERVISORS': 4,
#  'ASST MGR': 4,
#  'MUNICIPAL SECRETARY': 4,
#  'ASST SECRETARY': 4,
#  'ASSISTANT SECRETARY/TREASURER': 4,
#  'BOROUGH MANAGER SECRETARY': 4,
#  'SEC/TREA': 4,
#  'CHIEF OF POLICE': 4,
#  'CHIEF OPERATING OFFICER': 4,
#  'TREASUER': 4,
#  'OFFICER': 4,
#  'SAFETY SERVICE DIRECTOR': 4,
#  'VILLAGE FISCAL OFFICER': 4,
#  'DEVELOPMENT DIRECTOR': 4,
#  'COUNTY COMMISSIONERS': 4,
#  'CLERK FINANCE OFFICER': 4,
#  'CLERK TO THE BOARD': 4,
#  'BOOKKEEPER/SECRETARY': 4,
#  'CLERK TO SUPERVISOR': 4,
#  'CLERK /TREASURER': 4,
#  'FINANCE DIVISION': 4,
#  'HUMAN RESOURCES ADMINISTRATOR': 4,
#  'FIRE MARSHAL': 4,
#  'TOWNSHIP BOARD MEMBER': 4,
#  'ACCOUNT CLERK': 4,
#  'TOWN CLERK TREAS': 4,
#  'COURT CLERK': 4,
#  'CHAIRMAN OF TRUSTEES': 4,
#  'DIRECTOR OF PLANNING AND ZONING': 4,
#  'CHAIRMAN OF THE BOARD OF SUPERVISORS': 4,
#  'CHAIRMAN/SUPERVISOR': 4,
#  'CHM': 4,
#  'DEPUTY CLERK-TREASURER': 4,
#  'VILLAGE CLERK / TREASURER': 4,
#  'DEPUTY ADMINISTRATOR': 4,
#  'BOARD OF SELECTMEN': 4,
#  'SELECT BOARD CHAIR': 4,
#  'TOWN COORDINATOR': 4,
#  'SELECTMEN': 4,
#  'ADMIN COORDINATOR': 4,
#  'DEP CLERK': 4,
#  'COUNTY APPRAISER': 4,
#  'CITY CLERK - TREASURER': 4,
#  'CITY ACCOUNTANT': 4,
#  'UNION TWP TRUSTEE': 4,
#  'DEPUTY TRUSTEE': 4,
#  'JACKSON TWP TRUSTEE': 4,
#  'JACKSON TOWNSHIP TRUSTEE': 4,
#  'UNION TOWNSHIP TRUSTEE': 4,
#  "MAYOR'S ASSISTANT": 4,
#  'PRESIDENT TOWN COUNCIL': 4,
#  'TOWN BOARD PRESIDENT': 4,
#  'SUPERVISON': 4,
#  'SUP': 4,
#  'SUPER./TREAS.': 4,
#  'CITY HALL': 4,
#  'ACTING AGENT': 4,
#  'DEPUTY VILLAGE CLERK': 4,
#  'TREAS.': 4,
#  'COUNTY BOARD CHAIR': 4,
#  'CHIEF DEPUTY CLERK': 4,
#  'MAYOR PRO TEM': 4,
#  'TOWN ADMINISTRATOR/CLERK': 4,
#  'CLERK & TREASURER': 4,
#  'FISCAL ANALYST': 4,
#  'DIRECTOR OF COMMUNICATIONS': 4,
#  'COUNTY PLANNER': 4,
#  'DIRECTOR OF ECONOMIC DEVELOPMENT': 4,
#  'DEPUTY TOWN CLERK': 4,
#  'GIS SPECIALIST': 4,
#  'ECONOMIC DEVELOPMENT MANAGER': 4,
#  'COMMUNITY DEVELOPMENT': 4,
#  'PLANNING ASSISTANT': 4,
#  'GIS ANALYST': 4,
#  'ACCOUNTING DIRECTOR': 4,
#  'CITY RECORDER/TREASURER': 4,
#  'FINANCE ADMIN': 4,
#  'BOOK-KEEPER': 3,
#  'DANE COUNTY DRAINAGE BOARD': 3,
#  'ADMIN. SUPPORT FOR WHATCOM COUNTY DI': 3,
#  'PORT AUDITOR': 3,
#  'COMMISSIONER/TREASURER': 3,
#  'COWLITZ COUNTY DEPT PUBLIC WORKS': 3,
#  'AUDITING OFFICER': 3,
#  'CEDAR PARK DEVELOPMENT SERVICES': 3,
#  'RADCLIFFE BOBBITT ADAMS POLLEY PLLC': 3,
#  'SCHWARTZ PAGE & HARDING': 3,
#  'ALLEN BOONE & HUMPHRIES LLP': 3,
#  'VINSON & ELKINS, ATTORNEYS': 3,
#  'ALLEN BOONE HUMPHRIES ROBINSON L': 3,
#  'ACTING MANAGER': 3,
#  'CHIEF OPERATOR': 3,
#  'DEPUTY EXECUTIVE DIRECTOR': 3,
#  'TOM MCGRATH': 3,
#  'VIVIAN MOODY': 3,
#  'AIRPORT MGR': 3,
#  'EXCUTIVE DIRECTOR': 3,
#  'PARK BOARD MEMBER': 3,
#  'COMMISSIONER/SECRETARY': 3,
#  'CHAIRMAN OF THE BOARD OF FIRE COMMIS': 3,
#  'ADMINISTRATIVE': 3,
#  'FINANCIAL ASSISTANT': 3,
#  'SECY-TREAS': 3,
#  'INDEPENDENT ACCOUNTANT': 3,
#  'LANG WOODWARD LLC': 3,
#  'LEGAL COUNSEL': 3,
#  'BUDGET PREPARER': 3,
#  'PRESEDENT': 3,
#  'PANSING, HOGAN, ERNST, BACHMAN LLP': 3,
#  'FINANCIAL MGR': 3,
#  'OFFICE MGR BOOKKEEPER': 3,
#  'FIRECHIEF': 3,
#  'RIPLEY COUNTY ROAD CREW FOREMAN': 3,
#  'DISTRICT SPECIALIST II': 3,
#  'BROWN & JAMES, P.C.': 3,
#  'EMS CHIEF': 3,
#  'DISTRICT SPECIALIST': 3,
#  'OZARK REGIONAL LIBRARY': 3,
#  'CARLOS EDWARDS': 3,
#  'COUNTY SUPERVISORS': 3,
#  'FISCAL ADMINISTRATOR': 3,
#  'PROGRAM SPECIALIST': 3,
#  'SR FINANCIAL ANALYST': 3,
#  'MGR OF FINANCE': 3,
#  'CO-MANAGER': 3,
#  'SEC TR': 3,
#  'WATERSHED COORDINATOR': 3,
#  'E911 COORDINATOR': 3,
#  'NINE ONE ONE COORDINATOR': 3,
#  'SHERIFF': 3,
#  'E NINE ONE ONE COORDINATOR': 3,
#  'HR/BUSINESS MANAGER': 3,
#  'ACCOUNTS MANAGER': 3,
#  'UTILITY DIRECTOR': 3,
#  'PROGRAMS COORDINATOR': 3,
#  'BLACKFORD COUNTY SURVEYOR': 3,
#  'TRUSTEE TREAS': 3,
#  'LIEUTENANT': 3,
#  'SECY/TREASURER': 3,
#  'ADM COORDINATOR': 3,
#  'TREASURER TRUSTEE': 3,
#  'TRUST ASSISTANT': 3,
#  'DITCH COMMISSIONER': 3,
#  'BOARD SECRETARY/TREASURER': 3,
#  'BUS MGR': 3,
#  'HEAD COMMISSIONER': 3,
#  'CRAIG AND CRAIG ATTORNEYS': 3,
#  'TREASURER COMMISSIONER': 3,
#  'OFFICE MANAGER/BOOKKEEPER': 3,
#  'TREASURER BOOKKEEPER': 3,
#  'ATTORNEY FOR DRAINAGE DISTRICT': 3,
#  'SEC TRE': 3,
#  'SECRETARY TRUSTEE': 3,
#  'DIRECTOR OF BUSINESS SERVICES': 3,
#  'SECRETARY/TREAS': 3,
#  'DISTRICT SECRETARY TREASURER': 3,
#  'CARETAKER': 3,
#  'DIRECTORS': 3,
#  'BKPR': 3,
#  'FISCAL DIRECTOR': 3,
#  'SARAH KOSER': 3,
#  'AUTHORITY CHAIRMAN': 3,
#  'SPECIAL DISTRICT SERVICES': 3,
#  'GMS-SF': 3,
#  'CRAIG WRATHELL': 3,
#  'MANAGEMENT AGENT': 3,
#  'BOOKKEEPING': 3,
#  'METRO DISTRICT MANAGEMENT': 3,
#  'PRESIDENT AND CEO': 3,
#  'MILLER AND ASSOCIATES LAW OFFICES LLC': 3,
#  'WHITE BEAR & ANKELE TANAKA & WALDRON': 3,
#  'ICENOGLE, SEAVER, POGUE P.C.': 3,
#  'WHITE BEAR & ANKELE P.C.': 3,
#  'OUTSOURCING, CLIFTON LARSON ALLEN LLP': 3,
#  'SETER & VANDER WALL, P.C.': 3,
#  'FINANCE ANALYST': 3,
#  'ADMINISTRATIVE OFFICE MANAGER': 3,
#  'SECRETARY ATTORNEY': 3,
#  'DISTRICT ENGINEER': 3,
#  'AUTHORITY SECRETARY': 3,
#  'HUMAN RESOURCE MANAGER': 3,
#  'FINANCIAL ADVISOR': 3,
#  'FINANCIAL CONTROLLER': 3,
#  'ADMINISTRATIVE SERVICE MANAGER': 3,
#  'ACCOUNTANT III': 3,
#  'JPA ACCOUNTANT': 3,
#  'DIST MANAGER': 3,
#  'AUDITOR - CONTROLLER': 3,
#  'AUDITOR / CLERK': 3,
#  'PRESIDENT, BOARD OF DIRECTORS': 3,
#  'ADMIN SERVICES MANAGER': 3,
#  'KEENAN & ASSOCIATES - SETECH': 3,
#  'ASSISTANT DISTRICT MANAGER': 3,
#  'ACCT': 3,
#  'OFFICE MANAGER TREASURER': 3,
#  'FINANCIAL ACCOUNTANT': 3,
#  'ACCOUNTANT II': 3,
#  'CHAIRMAN BOARD OF DIRECTORS': 3,
#  'OFFICE MANAGER BOOKKEEPER': 3,
#  'MANAGER, FINANCE & ACCOUNTING': 3,
#  'MANAGER/OPERATOR': 3,
#  'CONSERVATION SECRETARY': 3,
#  'R. GARY NUTTER, ATTORNEY': 3,
#  'CHAIRMAN COMMISSIONER': 3,
#  'PUBLIC HOUSING MANAGER': 3,
#  'ASST. EXECUTIVE DIRECTOR': 3,
#  'SOLID WASTE MANAGER': 3,
#  'CHAIRMAN OF COMMISSIONERS': 3,
#  'SECRETARY OF THE BOARD': 3,
#  'VICE PRESIDENT OF FINANCE': 3,
#  'ACCOUNTING MGR': 3,
#  'DIRECTOR/ADMINISTRATOR': 3,
#  'RECORDER CLERK': 3,
#  'CITY SECY': 3,
#  'SR. ACCOUNTANT': 3,
#  'MUNICIPAL FINANCE OFFICER': 3,
#  'TWP SECRETARY': 3,
#  'ACTING SECRETARY': 3,
#  'SECT TREASURER': 3,
#  'ASST SEC TREAS': 3,
#  'ADMINISTRATIVE SERVICES': 3,
#  'CHAIRMAN OF SUPERVISORS': 3,
#  'TWP MGR': 3,
#  'TWP MANAGER': 3,
#  'SEC MGR': 3,
#  'BOROUGH SECRETARY-TREASURER': 3,
#  'ASST. SECRETARY': 3,
#  'BUROUGH MANAGER': 3,
#  'ASSISTANT BOROUGH SECRETARY': 3,
#  'SECRETARY-MANAGER': 3,
#  'BOROUGH COUNCIL PRESIDENT': 3,
#  'BOUROUGH MANAGER': 3,
#  'MANAGER/SECRETARY': 3,
#  'COMMISSIONERS OFFICE': 3,
#  'COMMUNICATIONS MANAGER': 3,
#  'COMMISSIONER CHAIR': 3,
#  'CHAIRMAN OF BOARD OF TRUSTEES': 3,
#  'SECRETARY/CLERK': 3,
#  'ACCOUNTS PAYABLE': 3,
#  'FISCAL CLERK': 3,
#  'TWP FISCAL OFFICER': 3,
#  'DIR OF FINANCE': 3,
#  'FINANCE DIR': 3,
#  'COMMISSIONERS CLERK': 3,
#  'TREASURER/CLERK': 3,
#  'TOWNSHIP OFFICER': 3,
#  'ASSISTANT AUDITOR': 3,
#  'FINANCE MGR': 3,
#  'TOWN COMPTROLLER': 3,
#  'DIRECTOR OF ADMINISTRATION & FINANCE': 3,
#  'SR ACCT CLERK': 3,
#  'ADMINISTRATOR/CLERK-TREASURER': 3,
#  'HR COORDINATOR': 3,
#  'SECRETARY /TREASURER': 3,
#  'ADMINISTRATOR/CLERK/TREASURER': 3,
#  'COMMUNITY DEVELOPMENT DIR': 3,
#  'SUPERVISOR TOWNSHIP': 3,
#  'BOARD CHAIR PERSON': 3,
#  'ASSISTANT CITY PLANNER': 3,
#  'ADMINISTRATOR CLERK TREASURER': 3,
#  'MAYOR CITY CLERK': 3,
#  'AUDITOR TREASURER': 3,
#  'EXECUTIVE ADMINISTRATIVE ASSISTANT': 3,
#  'ASSISTANT TOWNSHIP MANAGER': 3,
#  'SUPERVISOR ASSESSOR': 3,
#  ...}
