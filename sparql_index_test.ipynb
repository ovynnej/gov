# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %%
import sys
# !{sys.executable} -m pip install SPARQLWrapper
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import numpy as np
import datetime
import func_lib

endpoint_url = "https://query.wikidata.org/sparql"
item = "item"


class Relation:
    """
    The class returned when createRelation is called.
    It contains string field with query.
    We call Relation.query when we need to do the query.
    """

    def __init__(self, entity_id: str, property_id: str, isSubject: bool, rowVerbose: bool,
                 colVerbose: bool, time_property: str, time: str, name: str, label: bool, limit=10000):
        self.entity_id = entity_id
        self.query_str = ""
        self.dic = {}
        self.result_dic = {"Entity ID": []}
        self.df = pd.DataFrame()
        self.count = 0
        self.time_property = time_property
        self.time = time
        self.limit = limit
        self.focus = "Entity ID"
        if property_id:
            self.extend(property_id, isSubject, name, rowVerbose, colVerbose, limit, time_property, time, label)

    def generate_html(self, name: str):
        html = (self.df).to_html()
        text_file = open(name, "w", encoding='utf-8')
        text_file.write(html)
        text_file.close()

    def query(self, require=None):
        if self.query_str == "":
            self.result_dic = {"Entity ID": ['http://www.wikidata.org/entity/' + str(self.entity_id)]}
            return self.result_dic
        results = get_results(endpoint_url, self.query_str)
        result_dict = {"Entity ID": ['http://www.wikidata.org/entity/' + str(self.entity_id)]}
        for i in range(1, self.count + 1):
            result_dict[self.dic[i]["name"] + '_' + self.dic[i]['property_id']] = []
            if self.dic[i]["colVerbose"]:
                result_dict[self.dic[i]["name"] + '_rank_' + self.dic[i]['property_id'] + '_rank'] = []
                for key, value in self.dic[i]["property_name_dic"].items():
                    result_dict[
                        self.dic[i]["name"] + "_" + value + '_' + self.dic[i]['property_id'] + '_' + str(key)] = []
                for key, value in self.dic[i]["ref_dic"].items():
                    result_dict[self.dic[i]["name"] + "_ref_" + self.dic[i]['property_id'] + '_' + str(key)] = []

            if self.dic[i]["label"]:
                result_dict[self.dic[i]["name"] + '_' + self.dic[i]['property_id'] + 'Label'] = []

        for result in results['results']['bindings']:
            for key, value in result_dict.items():
                if key in result.keys():
                    result_dict[key].append(result[key]['value'])
                else:
                    result_dict[key].append('NA')
        result_dict["Entity ID"] = ['http://www.wikidata.org/entity/' + str(self.entity_id)] * len(
            result_dict[self.dic[self.count]["name"] + '_' + self.dic[self.count]["property_id"]])
        self.result_dic = result_dict
        self.df = pd.DataFrame.from_dict(self.result_dic)
        for i in range(1, self.count + 1):
            if self.dic[i]["colVerbose"] and not self.dic[i]["rowVerbose"]:
                col = self.dic[i]['name'] + '_rank_' + self.dic[i]['property_id'] + '_rank'
                if any(self.df[col] == 'http://wikiba.se/ontology#PreferredRank'):
                    self.df = self.df.loc[self.df[col] == 'http://wikiba.se/ontology#PreferredRank']
                else:
                    self.df = self.df.loc[self.df[col] == 'http://wikiba.se/ontology#NormalRank']
#         if require is not None:
#             for r in require:
#                 self.df = self.df.loc[self.df[r] != 'NA']
        self.df = pd.DataFrame(data=self.df)
#         if self.df.shape[0] >= 10000:
#             print("Warning: Your query leads to too many results. Only 10,000 returned.")
        return self.df

    def extend(self, property_id: str, isSubject: bool, name: str, rowVerbose=False, colVerbose=False, limit=None,
               time_property=None, time=None, search=None, label=False):
        self.count += 1
        self.dic[self.count] = {}
        self.dic[self.count]["name"] = name
        self.dic[self.count]["focus"] = self.focus
        self.dic[self.count]["property_id"] = property_id
        self.dic[self.count]["isSubject"] = isSubject
        self.dic[self.count]["limit"] = limit
        self.dic[self.count]["rowVerbose"] = rowVerbose
        self.dic[self.count]["colVerbose"] = colVerbose
        self.dic[self.count]['time_property'] = time_property
        self.dic[self.count]['time'] = time
        self.dic[self.count]['search'] = search
        self.dic[self.count]['label'] = label
        if rowVerbose or colVerbose:
            self.dic[self.count]["property_name_dic"], self.dic[self.count][
                "ref_dic"] = self.search_property_for_verbose()
        if time_property and time:
            self.time_property = time_property
            self.time = time
        if limit:
            self.limit = limit
        self.query_str = self.define_query_relation()

    def changeFocus(self, name="Entity ID"):
        self.focus = name
        
    def applyFunction(self, objcolumn, func, name):
        if type(func) == str:
            if func.startswith('F'):
                try:
                    func_id = int(func[1:])
                    if func_id == 0:
                        self.df[name] = self.df[objcolumn]
                    else:
                        if func_id >= func_lib.func_num():
                            print("Not available.")
                        else:
                            self.df[name] = self.df[objcolumn].apply(func_lib.func_list[func_id])
                except:
                    raise Exception("Not a valid function id, a valid function id should be 'Fn', n is an integer.")
            else:
                raise Exception("Not a valid function id, a valid function id should be 'Fn', n is an integer.")
        else:
            self.df[name] = self.df[objcolumn].apply(func)

    def define_query_relation(self):
        rdf_triple, time_filter, limit_statement = """""", """""", """"""
        if self.count < 1:
            return None
        focusChanges = 0
        for i in range(1, self.count + 1):
            if self.dic[i]["rowVerbose"] or self.dic[i]["colVerbose"]:
                if self.dic[i]["search"] is None and not self.dic[i]["isSubject"]:
                        rdf_triple += """OPTIONAL {"""
                if self.dic[i]["focus"] == "Entity ID":
#                     if self.dic[i]["search"] is None:
#                         rdf_triple += """OPTIONAL {"""
                    rdf_triple += """wd:""" + self.entity_id + """ p:""" + self.dic[i][
                        'property_id'] + """ ?statement_""" + str(i) + """. """ \
                                  + """?statement_""" + str(i) + """ ps:""" + self.dic[i][
                                      'property_id'] + """ ?""" + \
                                  self.dic[i]['name'] \
                                  + """_""" + self.dic[i]['property_id'] + """. """
                else:
                    rdf_triple += """?""" + self.dic[i]["focus"] + """ p:""" + self.dic[i][
                        'property_id'] + """ ?statement_""" + str(i) + """. """ \
                                  + """?statement_""" + str(i) + """ ps:""" + self.dic[i][
                                      'property_id'] + """ ?""" + \
                                  self.dic[i]['name'] \
                                  + """_""" + self.dic[i]['property_id'] + """. """
                for key, value in self.dic[i]["property_name_dic"].items():
                    rdf_triple += """OPTIONAL { """ + """?statement_""" + str(i) + """ pq:""" + str(key) \
                                  + """ ?""" + self.dic[i]['name'] + """_""" + value + """_""" + self.dic[i][
                                      'property_id'] + """_""" + str(key) + """.} """
                for key, value in self.dic[i]["ref_dic"].items():
                    rdf_triple += """OPTIONAL { ?statement_""" + str(
                        i) + """ prov:wasDerivedFrom ?refnode_""" + str(
                        i) + """. ?refnode_""" + str(i) \
                                  + """ pr:""" + str(key) + """ ?""" + self.dic[i]['name'] + """_ref_""" + \
                                  self.dic[i][
                                      'property_id'] + """_""" + str(key) + """.} """
                rdf_triple += """OPTIONAL { ?statement_""" + str(i) + """ wikibase:rank ?""" + self.dic[i][
                    'name'] + """_rank_""" + self.dic[i]['property_id'] + """_rank. } """
            # none-verbose version
            else:
                if self.dic[i]["focus"] == "Entity ID":
                    if self.dic[i]["isSubject"]:
#                         if self.dic[i]["search"] is None:
#                             rdf_triple += """OPTIONAL {"""
                        rdf_triple += """?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                            'property_id'] + """ wdt:""" + self.dic[i][
                                          "property_id"] + """ wd:""" + self.entity_id + """. """
                    else:
                        if self.dic[i]["search"] is None:
                            rdf_triple += """OPTIONAL {"""
                        rdf_triple += """wd:""" + self.entity_id + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + \
                                      self.dic[i]["name"] + """_""" + self.dic[i]['property_id'] + """. """
                else:
                    if self.dic[i]["isSubject"]:
#                         if self.dic[i]["search"] is None:
#                             rdf_triple += """OPTIONAL {"""
                        rdf_triple += """?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                            'property_id'] + """ wdt:""" + self.dic[i]["property_id"] + """ ?""" + self.dic[i][
                                          'focus'] + """. """
                    else:
                        if self.dic[i]["search"] is None:
                            rdf_triple += """OPTIONAL {"""
                        rdf_triple += """?""" + self.dic[i]['focus'] + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                                          'property_id'] + """. """
            if not self.dic[i]["isSubject"]:
                if i < self.count and self.dic[i]["focus"] != self.dic[i + 1]["focus"] and self.dic[i]["search"] is None:
                    focusChanges += 1
                elif self.dic[i]["search"] is None:
                    rdf_triple += """} """
        for i in range(focusChanges):
            rdf_triple += """} """
        for i in range(1, self.count + 1):
            if self.dic[i]['search'] is not None and self.dic[i]["search"] != '!NA':
                if isinstance(self.dic[i]['search'], tuple):
                    if isinstance(self.dic[i]['search'][0], str):
                        rdf_triple += """FILTER (YEAR(?""" + self.dic[i]['name'] + """_""" + self.dic[i][
                            'property_id'] + """) >= """ + \
                                      self.dic[i]['search'][0] + """ && YEAR(?""" + self.dic[i]['name'] + \
                                      """_""" + self.dic[i]['property_id'] + """) <= """ + self.dic[i]['search'][
                                          1] + """) """
                    else:
                        rdf_triple += """FILTER (?""" + self.dic[i]['name'] + """_""" + self.dic[i]['property_id'] + \
                                      """ >= """ + str(self.dic[i]['search'][0]) + """ && ?""" + self.dic[i]['name'] + \
                                      """_""" + self.dic[i]['property_id'] + """ <= """ + str(
                            self.dic[i]['search'][1]) + """) """
                else:
                    rdf_triple += """FILTER (?""" + self.dic[i]['name'] + """_""" + self.dic[i][
                        'property_id'] + """ = """ + \
                                  """wd:""" + self.dic[i]['search'] + """) """
        if self.time_property is not None:
            time_filter = """?""" + self.dic[1]["name"] + """ p:""" + self.time_property + """ ?pubdateStatement.	
                          # ?pubdateStatement ps:""" + self.time_property + """ ?date	
                          FILTER (YEAR(?date) = """ + self.time + """)"""
        if self.limit is not None:
            limit_statement = """LIMIT """ + str(self.limit)
        label_statement = """Service wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" }"""
        query = """SELECT DISTINCT"""
        for i in range(1, self.count + 1):
            if self.dic[i]["rowVerbose"] or self.dic[i]["colVerbose"]:
                query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id']
                if self.dic[i]["label"]:
                    query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id'] + """Label"""
                for key, value in self.dic[i]["property_name_dic"].items():
                    query += """ ?""" + self.dic[i]["name"] + """_""" + value + """_""" + self.dic[i][
                        'property_id'] + """_""" + str(key)
                for key, value in self.dic[i]["ref_dic"].items():
                    query += """ ?""" + self.dic[i]["name"] + """_ref_""" + self.dic[i]['property_id'] + """_""" + str(
                        key)
                query += """ ?""" + self.dic[i]["name"] + """_rank_""" + self.dic[i]['property_id'] + """_rank"""
            else:
                query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id']
                if self.dic[i]["label"]:
                    query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id'] + """Label"""
        query += """ WHERE {""" + rdf_triple + time_filter + label_statement + """} """ + limit_statement
        return query

    def search_property_for_verbose(self):
        property_to_name = {}
        ref_to_name = {}
        rdf_triple, time_filter, limit_statement = """""", """""", """"""
        if self.dic[self.count]["rowVerbose"] or self.dic[self.count]["colVerbose"]:
            for i in range(1, self.count):
                if self.dic[i]["focus"] == "Entity ID":
                    if self.dic[i]["isSubject"]:
                        rdf_triple += """?""" + self.dic[i]["name"] + """ wdt:""" + self.dic[i][
                            "property_id"] + """ wd:""" + self.entity_id + """ ."""
                    else:
                        rdf_triple += """wd:""" + self.entity_id + """ wdt:""" + self.dic[i]["property_id"] + """ ?""" + \
                                      self.dic[i]["name"] + """ ."""
                else:
                    last = self.dic[i]["focus"].rfind('_')
                    focus = self.dic[i]["focus"][:last]
                    if self.dic[i]["isSubject"]:
                        rdf_triple += """?""" + self.dic[i]["name"] + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + focus + """ ."""
                    else:
                        rdf_triple += """?""" + focus + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + self.dic[i]["name"] + """ ."""
            if self.dic[self.count]["focus"] == "Entity ID":
                rdf_triple += """wd:""" + self.entity_id + """ p:""" + self.dic[self.count][
                    'property_id'] + """ ?statement.""" + \
                              """?statement """ + """ps:""" + self.dic[self.count]['property_id'] + """ ?item.""" + \
                              """?statement """ + """?pq """ + """?obj.""" + \
                              """?qual wikibase:qualifier ?pq.""" + \
                              """OPTIONAL{ ?statement prov:wasDerivedFrom ?refnode. ?refnode ?pr ?r.}"""
            else:
                last = self.dic[self.count]["focus"].rfind('_')
                focus = self.dic[self.count]["focus"][:last]
                rdf_triple += """?""" + focus + """ p:""" + self.dic[self.count][
                    'property_id'] + """ ?statement.""" + \
                              """?statement """ + """ps:""" + self.dic[self.count]['property_id'] + """ ?item.""" + \
                              """?statement """ + """?pq """ + """?obj.""" + \
                              """?qual wikibase:qualifier ?pq.""" + \
                              """OPTIONAL{ ?statement prov:wasDerivedFrom ?refnode. ?refnode ?pr ?r.}"""
        if self.time_property is not None:
            time_filter = """?""" + self.dic[1]["name"] + """ p:""" + self.time_property + """ ?pubdateStatement.	
                                  # ?pubdateStatement ps:""" + self.time_property + """ ?date	
                                  FILTER (YEAR(?date) = """ + self.time + """)"""
        if self.limit is not None:
            limit_statement = """LIMIT """ + str(self.limit)
        label_statement = """Service wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" }"""
        query = """SELECT DISTINCT """
        if self.dic[self.count]["rowVerbose"] or self.dic[self.count]["colVerbose"]:
            query += """?item""" + """ ?qual""" + """ ?qualLabel""" + """ ?obj """ + """?pr ?prLabel"""
            query += """ WHERE {""" + rdf_triple + time_filter + label_statement + """} """ + limit_statement
            query_result = get_results(endpoint_url, query)
            for result in query_result['results']['bindings']:
                if 'qual' in result:
                    property_to_name[result['qual']['value'].split('/')[-1]] = result['qualLabel']['value'].replace(' ',
                                                                                                                    '_')
                if 'pr' in result:
                    ref_to_name[result['pr']['value'].split('/')[-1]] = result['prLabel']['value'].replace(' ', '_')
        else:
            query += """?""" + self.dic[self.count]["name"] + """ """
        return property_to_name, ref_to_name

    def __str__(self):
        return str(self.df)

    def __getattr__(self, col_name):
        if col_name in self.df.columns:
            return self.df[col_name]
        else:
            print(col_name + " has not been found.")
            return None


def createRelation(entity_id: str, property_id=None, isSubject=None, rowVerbose=None, colVerbose=None,
                   time_property=None, time=None, name=None, label=False, limit=None):
    if property_id and not name:
        print("Please specify the name of the first column")
        return None
    return Relation(entity_id, property_id, isSubject, rowVerbose, colVerbose, time_property, time, name, label, limit)

def get_Firstname(name: str):
    return name.split(' ')[0]

def get_Lastname(name: str):
    return name.split(' ')[-1]

def remove_prefix(text, prefix):
    if text.startswith(prefix):
        return text[len(prefix):]
    return text


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


def get_name(id: str):
    query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 	
                PREFIX wd: <http://www.wikidata.org/entity/> 	
                select  *	
                where {	
                wd:""" + id + """ rdfs:label ?label .	
                FILTER (langMatches( lang(?label), "EN" ) )	
                } 	
                LIMIT 1"""
    results = get_results(endpoint_url, query)
    result = ''
    for res in results["results"]["bindings"]:
        result = res['label']['value']
    return result
# Out:
# Requirement already satisfied: SPARQLWrapper in /home/jennyvo/env/lib/python3.7/site-packages (1.8.5)
# Requirement already satisfied: rdflib>=4.0 in /home/jennyvo/env/lib/python3.7/site-packages (from SPARQLWrapper) (5.0.0)
# Requirement already satisfied: pyparsing in /home/jennyvo/env/lib/python3.7/site-packages (from rdflib>=4.0->SPARQLWrapper) (2.4.7)
# Requirement already satisfied: isodate in /home/jennyvo/env/lib/python3.7/site-packages (from rdflib>=4.0->SPARQLWrapper) (0.6.0)
# Requirement already satisfied: six in /home/jennyvo/env/lib/python3.7/site-packages (from rdflib>=4.0->SPARQLWrapper) (1.15.0)
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/jennyvo/env/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# # Query Courthouses in the US
#
# Jenny tests

# %%
r = createRelation("Q1137809") # create relation for Q1137809 = courthouses

# %%
r.extend("P31", True, "Courthouse", limit=10, label=True) # extend via property P31 = is instance of

# %%
r.query()
# Out:
#                                  Entity ID  \
# 0  http://www.wikidata.org/entity/Q1137809
# 1  http://www.wikidata.org/entity/Q1137809
# 2  http://www.wikidata.org/entity/Q1137809
# 3  http://www.wikidata.org/entity/Q1137809
# 4  http://www.wikidata.org/entity/Q1137809
# 5  http://www.wikidata.org/entity/Q1137809
# 6  http://www.wikidata.org/entity/Q1137809
# 7  http://www.wikidata.org/entity/Q1137809
# 8  http://www.wikidata.org/entity/Q1137809
# 9  http://www.wikidata.org/entity/Q1137809
#
#                             Courthouse_P31          Courthouse_P31Label
# 0   http://www.wikidata.org/entity/Q128652            Palace of Justice
# 1   http://www.wikidata.org/entity/Q481170     Courthouses in Wuppertal
# 2  http://www.wikidata.org/entity/Q1006058                     Q1006058
# 3   http://www.wikidata.org/entity/Q719011            Palace of Justice
# 4   http://www.wikidata.org/entity/Q850537       Law Courts of Brussels
# 5   http://www.wikidata.org/entity/Q876884            Palace of Justice
# 6  http://www.wikidata.org/entity/Q1281321                     Q1281321
# 7  http://www.wikidata.org/entity/Q1229654  East Hawaii Cultural Center
# 8  http://www.wikidata.org/entity/Q1503389    United States Post Office
# 9  http://www.wikidata.org/entity/Q2267420                     Q2267420

# %%
r.changeFocus('Courthouse_P31')

# %%
r.extend('P17', False, 'Country', label=True)

# %%
r.query()
# Out:
#                                  Entity ID  \
# 0  http://www.wikidata.org/entity/Q1137809
# 1  http://www.wikidata.org/entity/Q1137809
# 2  http://www.wikidata.org/entity/Q1137809
# 3  http://www.wikidata.org/entity/Q1137809
# 4  http://www.wikidata.org/entity/Q1137809
# 5  http://www.wikidata.org/entity/Q1137809
# 6  http://www.wikidata.org/entity/Q1137809
# 7  http://www.wikidata.org/entity/Q1137809
# 8  http://www.wikidata.org/entity/Q1137809
# 9  http://www.wikidata.org/entity/Q1137809
#
#                             Courthouse_P31  \
# 0   http://www.wikidata.org/entity/Q719011
# 1   http://www.wikidata.org/entity/Q201780
# 2  http://www.wikidata.org/entity/Q2269681
# 3  http://www.wikidata.org/entity/Q3001513
# 4  http://www.wikidata.org/entity/Q3361019
# 5  http://www.wikidata.org/entity/Q1322792
# 6  http://www.wikidata.org/entity/Q3361006
# 7  http://www.wikidata.org/entity/Q3361012
# 8  http://www.wikidata.org/entity/Q3361024
# 9  http://www.wikidata.org/entity/Q3361033
#
#                     Courthouse_P31Label                          Country_P17  \
# 0                     Palace of Justice  http://www.wikidata.org/entity/Q218
# 1                1841 Goshen Courthouse   http://www.wikidata.org/entity/Q30
# 2                      St. Paul's Abbey   http://www.wikidata.org/entity/Q55
# 3                      Courthouse Place   http://www.wikidata.org/entity/Q30
# 4                Justice Court in Nîmes  http://www.wikidata.org/entity/Q142
# 5         Palais de justice de Bordeaux  http://www.wikidata.org/entity/Q142
# 6                      Lille Courthouse  http://www.wikidata.org/entity/Q142
# 7                  Marseille Courthouse  http://www.wikidata.org/entity/Q142
# 8       Palais de Justice of Strasbourg  http://www.wikidata.org/entity/Q142
# 9  Argyle Township Court House and Jail   http://www.wikidata.org/entity/Q16
#
#            Country_P17Label
# 0                   Romania
# 1  United States of America
# 2               Netherlands
# 3  United States of America
# 4                    France
# 5                    France
# 6                    France
# 7                    France
# 8                    France
# 9                    Canada

# %%
df = r.df
df_us_courthouses = list(df[df.Country_P17Label=='United States of America'].Courthouse_P31Label)
df_us_courthouses
# Out:
# ['1841 Goshen Courthouse', 'Courthouse Place']

# %% [markdown]
# ## Without limiting the sample, try to grab all courthouses in the US

# %%
r = createRelation("Q1137809") # create relation for Q1137809 = courthouses
r.extend("P31", True, "Courthouse", label=True) # extend via property P31 = is instance of
r.changeFocus('Courthouse_P31')
r.extend('P17', False, 'Country', label=True)
r.query()
df = r.df
df_us_courthouses = list(df[df.Country_P17Label=='United States of America'].Courthouse_P31Label)
df_us_courthouses
# Out:
# ['St. Stephens Courthouse',
#  'Richard C. Lee United States Courthouse',
#  'Pioneer Courthouse',
#  'United States Post Office, Courthouse, and Customhouse',
#  'United States Post Office, Courthouse, and Customhouse',
#  'United States Post Office, Courthouse, and Federal Office Building',
#  'Somerset County Court House complex',
#  'Schoharie County Courthouse Complex',
#  'Susquehanna County Courthouse Complex',
#  'United States Post Office and Court House',
#  'United States Post Office and Court House',
#  "Stutsman County Courthouse and Sheriff's Residence/Jail",
#  'US Court House-Aiken, South Carolina',
#  'Ronald N. Davies Federal Building and U.S. Courthouse',
#  'Pocahontas County Courthouse and Jail',
#  'Strom Thurmond Federal Building and United States Courthouse',
#  'United States Court House and Custom House',
#  'United States Courthouse, Post Office and Customs House',
#  'United States Customhouse and Post Office',
#  'Pierce Courthouse',
#  'Joseph F. Weis, Jr. United States Courthouse',
#  'Old United States Courthouse and Post Office',
#  'Talbot County District Courthouse',
#  'Old State House',
#  'United States Courthouse Building and Downtown Postal Station',
#  'United States Federal Building and Courthouse',
#  'U.S. Post Office and Courthouse',
#  'U.S. Post Office and Courthouse',
#  'Ed Edmondson United States Courthouse',
#  'Orleans County Courthouse Historic District',
#  'Postville Courthouse State Historic Site',
#  'Potter Stewart United States Courthouse',
#  'Santiago E. Campos United States Courthouse',
#  'Union Station',
#  'Sitka United States Post Office and Court House',
#  'Paul Brown Federal Building and United States Courthouse',
#  'Oregon Supreme Court Building',
#  'Old U.S. Post Office and Federal Building',
#  'Robert N.C. Nix, Sr. Federal Building',
#  'Old Third District Courthouse',
#  'Sussex County Courthouse and the Circle',
#  'Tombstone Courthouse State Historic Park',
#  'Randolph County Courthouse and Jail',
#  'United States Court House',
#  'United States Court House',
#  'United States Courthouse',
#  'United States Courthouse',
#  'United States Courthouse',
#  'United States Customhouse',
#  'United States Customhouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'Ronald Reagan Federal Building and Courthouse',
#  'Ronald Reagan Federal Building and Courthouse',
#  'Theodore Levin United States Courthouse',
#  'Seneca County Courthouse Complex at Ovid',
#  'Renville County Courthouse and Jail',
#  "Sandra Day O'Connor United States Courthouse",
#  'Pueblo Federal Building',
#  'Rice County Courthouse and Jail',
#  'Tucker County Courthouse and Jail',
#  'Tomochichi Federal Building and United States Courthouse',
#  'William M. Steger Federal Building and United States Courthouse',
#  'Bruce M. Van Sickle Federal Building and U.S. Courthouse',
#  'United States Post Office, Courthouse, and Custom House',
#  'Schuyler County Courthouse Complex',
#  "Todd County Courthouse, Sheriff's House, and Jail",
#  'Old United States Post Office and Courts Building',
#  'Pownalborough Courthouse',
#  'United States Courthouse and Post Office',
#  'Tyler County Courthouse and Jail',
#  '1841 Goshen Courthouse',
#  'Courthouse Place',
#  'East Hawaii Cultural Center',
#  'United States Supreme Court building',
#  'Richard J. Daley Center',
#  'Joseph T. Smitherman Historic Building',
#  'Louisville Metro Hall',
#  'Old United States Post Office and Courthouse',
#  'Robert S. Vance Federal Building and United States Courthouse',
#  'G.W. Andrews Federal Building',
#  'Thurgood Marshall United States Courthouse',
#  'Jefferson Market Library',
#  'United States Post Office',
#  'Old Warren County Courthouse Complex',
#  'Dutchess County Court House',
#  'Belmont Courthouse State Historic Park',
#  'Appomattox Court House',
#  'Tweed Courthouse',
#  'University of Memphis School of Law building',
#  'Walter E. Hoffman United States Courthouse',
#  'Wayne County Building',
#  'Vandalia State House State Historic Site',
#  'Elbert P. Tuttle United States Court of Appeals Building',
#  'Gloucester County Courthouse Square Historic District',
#  'Old Courthouse',
#  'Lucas County Courthouse and Jail',
#  'William Kenzo Nakamura United States Courthouse',
#  'Wicomico County Courthouses',
#  'Columbia City Hall',
#  'Old Cape May County Courthouse Building',
#  "Niagara County Courthouse and County Clerk's Office",
#  'William H. Natcher Federal Building and United States Courthouse',
#  'United States Post Office and Courthouse–Globe Main',
#  'United States Tax Court Building',
#  'Buckingham Courthouse Historic District',
#  "Waushara County Courthouse, Waushara County Sheriff's Residence and Jail",
#  'Albemarle County Courthouse Historic District',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse',
#  'United States Post Office and Courthouse–Prescott Main',
#  'United States Post Office and Federal Courthouse-Colorado Springs Main',
#  'Spotsylvania Court House Historic District',
#  'Municipal Courts Building',
#  'Covington County Courthouse and Jail',
#  'Luis A. Ferré United States Courthouse and Post Office Building',
#  'First Arthur County Courthouse and Jail',
#  'Bergen County Court House',
#  'Wyoming County Courthouse and Jail',
#  'Greensville County Courthouse Complex',
#  'San Bernardino County Court House',
#  'Bent County Courthouse and Jail',
#  'Brunswick County Courthouse Square',
#  'James R. Browning United States Court of Appeals Building',
#  'Guam Congress Building',
#  'Old Courthouse',
#  'Goochland County Court Square',
#  'Houston County Courthouse and Jail',
#  'Justice Center Complex',
#  'J. Bratton Davis United States Bankruptcy Courthouse',
#  'William O. Douglas Federal Building',
#  'Monterey County Court House',
#  'Warsaw Courthouse Square Historic District',
#  'Harlem Courthouse',
#  'Lunenburg Courthouse Historic District',
#  "Old Grayson County Courthouse and Clerk's Office",
#  'Pepin County Courthouse and Jail',
#  'Tooele County Courthouse and City Hall',
#  'Mathews County Courthouse Square',
#  'Wayne County Courthouse District',
#  'Harold D. Donohue Federal Building and United States Courthouse',
#  'Old Court House',
#  'Worcester County District Courthouses',
#  'Powhatan Courthouse Historic District',
#  'New York Court of Appeals Building',
#  'Brentsville Courthouse and Jail',
#  'Florence County Courthouse and Jail',
#  'Mount Pulaski Courthouse State Historic Site',
#  'Highland Hall',
#  'J. Marvin Jones Federal Building and United States Courthouse',
#  'Miguel Angel García Méndez Post Office Building',
#  'Marion Courthouse Square Historic District',
#  'Federal Building',
#  'Federal Building',
#  'Michigan Hall of Justice',
#  'James M. Ashley and Thomas W.L. Ashley United States Courthouse',
#  'Heitz Place Courthouse',
#  'Hipolito F. Garcia Federal Building and United States Courthouse',
#  'Kauikeaouli Hale',
#  'Robert H. Jackson United States Courthouse',
#  'Jefferson County Courthouse Annex',
#  'Lexington History Center',
#  'Miami County Courthouse',
#  'Old Courthouse Museum – Natchitoches',
#  'Mike Mansfield Federal Building and United States Courthouse',
#  'Howard M. Metzenbaum United States Courthouse',
#  'Galveston United States Post Office and Courthouse',
#  'Northampton County Courthouse Historical District',
#  'Kendall County Courthouse and Jail',
#  'Floyd County Court House',
#  'Metamora Courthouse State Historic Site',
#  'Fredericksburg Memorial Library',
#  'James T. Foley United States Courthouse',
#  'King David Kalakaua Building',
#  'New Mexico Supreme Court Building',
#  'Hood County Courthouse Historic District',
#  'Gerald W. Heaney Federal Building, United States Courthouse and Custom House',
#  'Moscow City Hall',
#  'Grove Hill Courthouse Square Historic District',
#  'Huron County Courthouse and Jail',
#  'Federal Building and Post Office',
#  "Lake County Courthouse and Sheriff's Residence",
#  'Old Isle of Wight Courthouse',
#  'Old Customs House',
#  'Gus J. Solomon United States Courthouse',
#  'Frank E. Moss United States Courthouse',
#  'Montgomery County Circuit Courthouses',
#  'Howard County Circuit Courthouse',
#  'Hamilton County Courthouse Complex',
#  'Mohave County Courthouse and Jail',
#  'Judge Isaac C. Parker Federal Building',
#  'Nicollet County Courthouse and Jail',
#  'Jefferson County Courthouse Complex',
#  'Gene Snyder United States Courthouse',
#  'Le Sueur County Courthouse and Jail',
#  'Federal Building-Courthouse',
#  'Federal Courthouse and Post Office',
#  'Milam County Courthouse and Jail',
#  'Grand Island United States Post Office and Courthouse',
#  'Jacob Weinberger United States Courthouse',
#  'Macon County Courthouse and Annex',
#  'James A. Redden Federal Courthouse',
#  "Lobb's Cemetery and Yohogania County Courthouse Site",
#  'James A. Walsh United States Courthouse',
#  'Laredo United States Post Office, Court House and Custom House',
#  'Jose V. Toledo Federal Building and United States Courthouse',
#  'Old Courthouse',
#  'Llano County Courthouse and Jail',
#  'Old Colony House',
#  'McLean County Courthouse and Square',
#  'Kiel and Morgan Hotel',
#  'New Castle County Court House',
#  'Old Post Office and Courthouse',
#  'Greenbrier County Courthouse and Lewis Spring',
#  'John F. Kilkenny United States Post Office and Courthouse',
#  'Federal Building and United States Courthouse',
#  'Federal Building and United States Courthouse',
#  'Federal Building and United States Courthouse',
#  'Federal Building and United States Courthouse',
#  'John Archibald Campbell United States Courthouse',
#  'Iberville Parish Courthouse',
#  'Maryland Circuit Courts',
#  'Hennepin County Government Center',
#  'Little Rock United States Post Office and Courthouse',
#  'Old Government House',
#  'Frank M. Johnson, Jr., Federal Building and United States Courthouse',
#  'Courthouse of American Samoa',
#  'Dorchester County Courthouse and Jail',
#  'Cecil County Circuit Courthouse',
#  'Aroostook County Courthouse and Jail',
#  'Eastern Middlesex County Second District Court',
#  'Appellate Division Courthouse of New York State',
#  'Buchanan County Courthouse',
#  'E. Ross Adair Federal Building and United States Courthouse',
#  "Cass County Court House, Jail, and Sheriff's House",
#  "Courthouse and Lawyers' Row",
#  'Clark County Court House',
#  'Audubon County Court House',
#  '1724 Chester Courthouse',
#  "Bradley County Courthouse and Clerk's Office",
#  'Athens Governmental Buildings',
#  'City Hall Post Office and Courthouse',
#  'Bremer County Court House',
#  'Eldon B. Mahon United States Courthouse',
#  'Allamakee County Court House',
#  'Aitkin County Courthouse and Jail',
#  'Dinwiddie County Court House',
#  'Des Moines County Court House',
#  'Byron G. Rogers Federal Building and United States Courthouse',
#  'Beauregard Parish Courthouse',
#  'Ashtabula County Courthouse Group',
#  'Bristol County Courthouse Complex',
#  'Baltimore County Circuit Courthouses',
#  'Edward T. Gignoux United States Courthouse',
#  'Bronx Borough Courthouse',
#  'Bronx County Hall of Justice',
#  'Androscoggin County Courthouse and Jail',
#  'District Courthouse',
#  "Darke County Courthouse, Sheriff's House and Jail",
#  'Confederate State Capitol building',
#  'Erie Federal Courthouse',
#  'Buffalo City Court Building',
#  'Bandera County Courthouse and Jail',
#  'Carroll County Court House',
#  "Alfonse M. D'Amato United States Courthouse",
#  'Babylon Town Hall',
#  'Carl Albert Federal Building',
#  'Burnett County Government Center',
#  'Armstrong County Courthouse and Jail',
#  'County and City Hall',
#  'Clarion County Courthouse and Jail',
#  'Dickinson County Courthouse and Jail',
#  'Crow Wing County Courthouse and Jail',
#  'Delaware County Courthouse Square District',
#  'Denton County Courthouse-on-the-Square',
#  'Bastrop County Courthouse and Jail Complex',
#  'Clinton County Courthouse Complex',
#  'El Viejo Post Office',
#  'Chemung County Courthouse Complex',
#  'Chenango County Courthouse District',
#  'Colonial Williamsburg Courthouse',
#  'Daniel Patrick Moynihan United States Courthouse',
#  'Birch Bayh Federal Building and United States Courthouse',
#  "Cayuga County Courthouse and Clerk's Office",
#  'Carbondale City Hall and Courthouse',
#  'Duluth Civic Center Historic District',
#  'David W. Dyer Federal Building and United States Courthouse',
#  'Maryland District Court',
#  'Huerfano County Courthouse and Jail',
#  'United States Post Office',
#  'Edward R. Roybal Federal Building and United States Courthouse',
#  'Mitchell H. Cohen United States Courthouse',
#  'Sussex County Courthouse Historic District',
#  'United States Court of Military Appeals',
#  'Napa County Courthouse Plaza',
#  'Somerville Courthouse',
#  'Surry County Courthouse Complex',
#  'Petersburg Courthouse',
#  'Van Dyne Civic Building',
#  'Telfair County Courthouse and Jail',
#  'Winston E. Arnow Federal Building',
#  'Warwick County Courthouses',
#  'Hillsborough County Registry of Deeds',
#  'Tennessee Supreme Court Building',
#  'Federal Building and U.S. Courthouse',
#  'Lawrence County Courthouse',
#  'Thebes Courthouse',
#  'Sidney M. Aronovitz United States Courthouse',
#  'Tazewell Historic District',
#  'Las Vegas Post Office and Courthouse',
#  'Hudson County Administration Building',
#  'United States Post Office and Courthouse',
#  'Portsmouth Courthouse',
#  'Knox County Courthouse',
#  'Passaic County Court House',
#  'Peoria Federal Building and U.S. Courthouse',
#  'Charles L. Brieant, Jr. Federal Building and Courthouse',
#  'Arkansas County Courthouse-Southern District',
#  'Sebastian County Courthouse/Ft. Smith City Hall',
#  'Kohala District Courthouse',
#  'Pottawattamie County Sub Courthouse',
#  'C.F. Haynsworth Federal Building and United States Courthouse',
#  'Rockaway Courthouse',
#  'Searcy Municipal Courthouse',
#  'United States Courthouse for the District of Utah',
#  'Federal Building-U.S. Post Office and Court House',
#  'United States Post Office',
#  'Carroll County Courthouse, Eastern District',
#  'Alton Lennon Federal Building and Courthouse',
#  'Currituck County Courthouse and Jail',
#  'Melvin Price Federal Building and United States Courthouse',
#  'Watonwan County Courthouse',
#  'Arkansas County Courthouse-Northern District',
#  'Jacob Trieber Federal Building, United States Post Office, and United States Court House',
#  'Iron County Courthouse',
#  'Edwards County Courthouse and Jail',
#  'Johnson County Courthouse Square',
#  'Logan County Courthouse, Southern Judicial District',
#  'Durward G. Hall Federal Building and United States Courthouse',
#  'Warren County Courthouse and Circuit Court Building',
#  'Old Logan County Jail',
#  'Estes Kefauver Federal Building and United States Courthouse',
#  'Old Courthouse Square',
#  'United States Courthouse',
#  'Morehouse Parish Courthouse',
#  'U.S. Post Office and Customshouse',
#  'Logan County Courthouse, Eastern District',
#  'Carroll County Court House',
#  'Madison Parish Courthouse',
#  'Carrollton Courthouse',
#  'Brooks County Jail',
#  'Troup County Courthouse, Annex, and Jail',
#  'Supreme Court of South Carolina Building',
#  'St. Louis County District Courthouse',
#  'Eastside District Court',
#  'Courthouse Square Museum',
#  'Barnstable’s Olde Colonial Courthouse',
#  'Chaffee County Courthouse and Jail Buildings',
#  'Deuel County Courthouse and Jail',
#  'Washington County Courthouse and Jail',
#  'Vernon Parish Courthouse',
#  'Adair County Courthouse',
#  'Camden County Hall of Justice',
#  'Metcalfe County Kentucky Courthouse',
#  'United States Courthouse',
#  'Concordia Parish Courthouse',
#  'Franklin County Courthouse and Jail',
#  'County courthouses in New Jersey',
#  'Edward J. Devitt U.S. Courthouse and Federal Building',
#  'George Howard Jr. Federal Building and United States Courthouse',
#  'Marshall County Courthouse',
#  'Throckmorton County Courthouse and Jail',
#  'Rice County Courthouse',
#  'Allen Parish Courthouse',
#  'Ewing T. Kerr Federal Building and U.S. Courthouse',
#  'Old Livingston Parish Courthouse',
#  'Robert C. Murphy Courts of Appeal Building',
#  "Coeur d'Alene City Hall",
#  'St. Martin Parish Courthouse',
#  'U.S. Bankruptcy Court, District of Nevada',
#  'Salem courthouse demolished 1839',
#  'Moore County Courthouse and Jail',
#  'Park County Courthouse and Jail',
#  'Bruce R. Thompson U.S. Courthouse and Federal Building',
#  'Theodore Roosevelt Federal Courthouse',
#  'Millard County Courthouse',
#  'Joseph P. Kinneary United States Courthouse',
#  'John H. Wood, Jr. United States Courthouse',
#  'Old Jefferson Parish Courthouse',
#  'Scott M. Matheson Courthouse',
#  'Fayette County Precinct No. 2 Courthouse']

# %%
len(df_us_courthouses)
# Out:
# 410

# %% [markdown]
# ## Grab all courthouses in the US as well as states and lon/lat data

# %%
building_type = 'Courthouse'
qnum = 'Q1137809'

# %%
r = createRelation(qnum, label=True) # create relation for Q1137809 = courthouses
r.extend('P31', True, building_type, label=True) # extend via property P31 = is instance of
r.changeFocus('%s_P31' % building_type)
r.extend('P17', False, 'Country', label=True) # extend via property P17 = is in country
r.extend('P131', False, 'State', label=True)
r.extend('P625', False, 'Lon_Lat')
r.query()

# filter r's dataframe to only include entities in the US
df = r.df
r.df = df[df.Country_P17Label=='United States of America']

r.df.head()
# Out:
#                                  Entity ID  \
# 1  http://www.wikidata.org/entity/Q1137809
# 2  http://www.wikidata.org/entity/Q1137809
# 3  http://www.wikidata.org/entity/Q1137809
# 4  http://www.wikidata.org/entity/Q1137809
# 5  http://www.wikidata.org/entity/Q1137809
#
#                             Courthouse_P31  \
# 1  http://www.wikidata.org/entity/Q5127180
# 2  http://www.wikidata.org/entity/Q5123209
# 3  http://www.wikidata.org/entity/Q5049154
# 4  http://www.wikidata.org/entity/Q4838521
# 5  http://www.wikidata.org/entity/Q4968884
#
#                                  Courthouse_P31Label  \
# 1                           Clark County Court House
# 2               City Hall Post Office and Courthouse
# 3  Cass County Court House, Jail, and Sheriff's H...
# 4                                  Babylon Town Hall
# 5                  Bristol County Courthouse Complex
#
#                           Country_P17          Country_P17Label  \
# 1  http://www.wikidata.org/entity/Q30  United States of America
# 2  http://www.wikidata.org/entity/Q30  United States of America
# 3  http://www.wikidata.org/entity/Q30  United States of America
# 4  http://www.wikidata.org/entity/Q30  United States of America
# 5  http://www.wikidata.org/entity/Q30  United States of America
#
#                                 State_P131  State_P131Label  \
# 1     http://www.wikidata.org/entity/Q1603         Kentucky
# 2    http://www.wikidata.org/entity/Q11299        Manhattan
# 3    http://www.wikidata.org/entity/Q34109            Fargo
# 4  http://www.wikidata.org/entity/Q3461796  Babylon Village
# 5      http://www.wikidata.org/entity/Q771    Massachusetts
#
#                         Lon_Lat_P625
# 1        Point(-84.178056 37.992778)
# 2            Point(-74.0075 40.7121)
# 3        Point(-96.793056 46.871944)
# 4  Point(-73.324111111 40.696416666)
# 5            Point(-71.0925 41.9145)

# %%
r.df
# Out:
#                                     Entity ID  \
# 1     http://www.wikidata.org/entity/Q1137809
# 2     http://www.wikidata.org/entity/Q1137809
# 3     http://www.wikidata.org/entity/Q1137809
# 4     http://www.wikidata.org/entity/Q1137809
# 5     http://www.wikidata.org/entity/Q1137809
# ...                                       ...
# 1147  http://www.wikidata.org/entity/Q1137809
# 1151  http://www.wikidata.org/entity/Q1137809
# 1158  http://www.wikidata.org/entity/Q1137809
# 1161  http://www.wikidata.org/entity/Q1137809
# 1171  http://www.wikidata.org/entity/Q1137809
#
#                                 Courthouse_P31  \
# 1      http://www.wikidata.org/entity/Q5127180
# 2      http://www.wikidata.org/entity/Q5123209
# 3      http://www.wikidata.org/entity/Q5049154
# 4      http://www.wikidata.org/entity/Q4838521
# 5      http://www.wikidata.org/entity/Q4968884
# ...                                        ...
# 1147  http://www.wikidata.org/entity/Q18158200
# 1151   http://www.wikidata.org/entity/Q7084281
# 1158  http://www.wikidata.org/entity/Q18154867
# 1161  http://www.wikidata.org/entity/Q18159020
# 1171   http://www.wikidata.org/entity/Q5388303
#
#                                     Courthouse_P31Label  \
# 1                              Clark County Court House
# 2                  City Hall Post Office and Courthouse
# 3     Cass County Court House, Jail, and Sheriff's H...
# 4                                     Babylon Town Hall
# 5                     Bristol County Courthouse Complex
# ...                                                 ...
# 1147                              Somerville Courthouse
# 1151                       Old Isle of Wight Courthouse
# 1158                       Napa County Courthouse Plaza
# 1161                  Winston E. Arnow Federal Building
# 1171                            Erie Federal Courthouse
#
#                              Country_P17          Country_P17Label  \
# 1     http://www.wikidata.org/entity/Q30  United States of America
# 2     http://www.wikidata.org/entity/Q30  United States of America
# 3     http://www.wikidata.org/entity/Q30  United States of America
# 4     http://www.wikidata.org/entity/Q30  United States of America
# 5     http://www.wikidata.org/entity/Q30  United States of America
# ...                                  ...                       ...
# 1147  http://www.wikidata.org/entity/Q30  United States of America
# 1151  http://www.wikidata.org/entity/Q30  United States of America
# 1158  http://www.wikidata.org/entity/Q30  United States of America
# 1161  http://www.wikidata.org/entity/Q30  United States of America
# 1171  http://www.wikidata.org/entity/Q30  United States of America
#
#                                    State_P131  State_P131Label  \
# 1        http://www.wikidata.org/entity/Q1603         Kentucky
# 2       http://www.wikidata.org/entity/Q11299        Manhattan
# 3       http://www.wikidata.org/entity/Q34109            Fargo
# 4     http://www.wikidata.org/entity/Q3461796  Babylon Village
# 5         http://www.wikidata.org/entity/Q771    Massachusetts
# ...                                       ...              ...
# 1147    http://www.wikidata.org/entity/Q67979       Somerville
# 1151     http://www.wikidata.org/entity/Q1370         Virginia
# 1158    http://www.wikidata.org/entity/Q60537             Napa
# 1161   http://www.wikidata.org/entity/Q486306        Pensacola
# 1171     http://www.wikidata.org/entity/Q1384         New York
#
#                            Lon_Lat_P625
# 1           Point(-84.178056 37.992778)
# 2               Point(-74.0075 40.7121)
# 3           Point(-96.793056 46.871944)
# 4     Point(-73.324111111 40.696416666)
# 5               Point(-71.0925 41.9145)
# ...                                 ...
# 1147             Point(-86.7958 34.475)
# 1151            Point(-76.6322 36.9817)
# 1158            Point(-122.284 38.2975)
# 1161            Point(-87.2156 30.4144)
# 1171            Point(-79.0842 42.2956)
#
# [412 rows x 8 columns]

# %% [markdown]
# So a problem that arises is that not every building in WikiData has a state associated as its administrative territorial entity. (That is, P131 = "located in the administrative territorial entity.")
#
# For example, Thurgood Marshall United States Courthouse's administrative territorial entity is Manhattan and Appomattox Court House's administrative territorial entity is Virginia.
#
# However, since longitude and latitude are given for all these entities, anyone who wants address information could easily look it up.

# %% [markdown]
# # Can we see all government buildings in the US in one go?

# %%
building_type = 'Gov_Building'
qnum = 'Q16831714' # qnum of gov building

# %%
r = createRelation(qnum, label=True)
r.extend('P31', True, building_type, label=True) # extend via property P31 = is instance of
r.changeFocus('%s_P31' % building_type)
r.extend('P17', False, 'Country', label=True) # extend via property P17 = is in country
r.extend('P131', False, 'State', label=True)
r.extend('P625', False, 'Lon_Lat')
r.query()

# filter r's dataframe to only include entities in the US
df = r.df
r.df = df[df.Country_P17Label=='United States of America']

r.df.head()
# Out:
#                                   Entity ID  \
# 0  http://www.wikidata.org/entity/Q16831714
# 1  http://www.wikidata.org/entity/Q16831714
# 5  http://www.wikidata.org/entity/Q16831714
# 7  http://www.wikidata.org/entity/Q16831714
# 8  http://www.wikidata.org/entity/Q16831714
#
#                           Gov_Building_P31  \
# 0  http://www.wikidata.org/entity/Q5440392
# 1  http://www.wikidata.org/entity/Q7071913
# 5  http://www.wikidata.org/entity/Q6133196
# 7  http://www.wikidata.org/entity/Q5440314
# 8  http://www.wikidata.org/entity/Q5547508
#
#                                Gov_Building_P31Label  \
# 0  Federal Reserve Bank of San Francisco, Los Ang...
# 1                      O'Neill House Office Building
# 5              James E. Rudder State Office Building
# 7                            Federal Office Building
# 8                         Georgia Governor's Mansion
#
#                           Country_P17          Country_P17Label  \
# 0  http://www.wikidata.org/entity/Q30  United States of America
# 1  http://www.wikidata.org/entity/Q30  United States of America
# 5  http://www.wikidata.org/entity/Q30  United States of America
# 7  http://www.wikidata.org/entity/Q30  United States of America
# 8  http://www.wikidata.org/entity/Q30  United States of America
#
#                                State_P131   State_P131Label  \
# 0      http://www.wikidata.org/entity/Q65       Los Angeles
# 1      http://www.wikidata.org/entity/Q61  Washington, D.C.
# 5   http://www.wikidata.org/entity/Q16559            Austin
# 7   http://www.wikidata.org/entity/Q43199             Omaha
# 8  http://www.wikidata.org/entity/Q486633     Fulton County
#
#                    Lon_Lat_P625
# 0  Point(-118.258611 34.042778)
# 1       Point(-77.0068 38.8857)
# 5   Point(-97.739444 30.271944)
# 7   Point(-95.936667 41.255278)
# 8   Point(-84.399217 33.846176)

# %%
len(r.df)
# Out:
# 117

# %% [markdown]
# Answer: No, apparently because WikiData doesn't transitively populate instance relationships all the way through subclasses, so only 117 buildings are listed as instances of `government building` even though there are 400+ courthouses and `courthouse` is a subclass of `government building`.

# %% [markdown]
# # Trace through class hierarchies under `government building`
#
# ## Find every subclass of `government building`

# %%
gov_building_subclass = 'Gov_Building'
qnum = 'Q16831714' # qnum of government building
r = createRelation(qnum, label=True)
r.extend('P279', True, gov_building_subclass, label=True) # extend via property P279 = is subclass of
r.query()
r.df
# Out:
#                                    Entity ID  \
# 0   http://www.wikidata.org/entity/Q16831714
# 1   http://www.wikidata.org/entity/Q16831714
# 2   http://www.wikidata.org/entity/Q16831714
# 3   http://www.wikidata.org/entity/Q16831714
# 4   http://www.wikidata.org/entity/Q16831714
# 5   http://www.wikidata.org/entity/Q16831714
# 6   http://www.wikidata.org/entity/Q16831714
# 7   http://www.wikidata.org/entity/Q16831714
# 8   http://www.wikidata.org/entity/Q16831714
# 9   http://www.wikidata.org/entity/Q16831714
# 10  http://www.wikidata.org/entity/Q16831714
# 11  http://www.wikidata.org/entity/Q16831714
# 12  http://www.wikidata.org/entity/Q16831714
# 13  http://www.wikidata.org/entity/Q16831714
# 14  http://www.wikidata.org/entity/Q16831714
# 15  http://www.wikidata.org/entity/Q16831714
# 16  http://www.wikidata.org/entity/Q16831714
# 17  http://www.wikidata.org/entity/Q16831714
#
#                             Gov_Building_P279        Gov_Building_P279Label
# 0      http://www.wikidata.org/entity/Q481289            official residence
# 1     http://www.wikidata.org/entity/Q1407236                   weigh house
# 2     http://www.wikidata.org/entity/Q1137809                    courthouse
# 3      http://www.wikidata.org/entity/Q757292             border checkpoint
# 4      http://www.wikidata.org/entity/Q218653                  custom house
# 5     http://www.wikidata.org/entity/Q5469110  Forest Service Guard Station
# 6   http://www.wikidata.org/entity/Q100705206   Prefectural Office Building
# 7     http://www.wikidata.org/entity/Q3250715             province building
# 8      http://www.wikidata.org/entity/Q861951                police station
# 9    http://www.wikidata.org/entity/Q30124446          legislative building
# 10   http://www.wikidata.org/entity/Q51183740              federal building
# 11   http://www.wikidata.org/entity/Q25550691      seat of local government
# 12   http://www.wikidata.org/entity/Q65270763                     Q65270763
# 13   http://www.wikidata.org/entity/Q65275063                     Q65275063
# 14   http://www.wikidata.org/entity/Q41439394                  warden cabin
# 15      http://www.wikidata.org/entity/Q40357                        prison
# 16   http://www.wikidata.org/entity/Q30310495          land registry office
# 17   http://www.wikidata.org/entity/Q69255748     Joint Government Building

# %% [markdown]
# ## Find every subclass of `government building` -> `official residence`

# %%
gov_building_subclass = 'Official_Residence'
qnum = 'Q481289' # qnum of official residence
r = createRelation(qnum, label=True)
r.extend('P279', True, gov_building_subclass, label=True) # extend via property P279 = is subclass of
r.query()
r.df
# Out:
#                                 Entity ID  \
# 0  http://www.wikidata.org/entity/Q481289
# 1  http://www.wikidata.org/entity/Q481289
# 2  http://www.wikidata.org/entity/Q481289
# 3  http://www.wikidata.org/entity/Q481289
# 4  http://www.wikidata.org/entity/Q481289
# 5  http://www.wikidata.org/entity/Q481289
# 6  http://www.wikidata.org/entity/Q481289
#
#                     Official_Residence_P279  \
# 0   http://www.wikidata.org/entity/Q2128615
# 1   http://www.wikidata.org/entity/Q2114972
# 2   http://www.wikidata.org/entity/Q5588918
# 3   http://www.wikidata.org/entity/Q3012073
# 4   http://www.wikidata.org/entity/Q1180262
# 5  http://www.wikidata.org/entity/Q23925100
# 6  http://www.wikidata.org/entity/Q47163308
#
#                         Official_Residence_P279Label
# 0                                         Raj Bhavan
# 1                                Presidential palace
# 2  Government House of the British Empire and Com...
# 3                                          Daikansho
# 4                                           residenz
# 5                                          Q23925100
# 6                             ambassador's residence

# %% [markdown]
# ## Find every subclass of `government building` -> `official residence` -> `ambassador's residence`

# %%
gov_building_subclass = 'Ambassadors_Residence'
qnum = 'Q47163308' # qnum of ambassador's residence
r = createRelation(qnum, label=True)
r.extend('P279', True, gov_building_subclass, label=True) # extend via property P279 = is subclass of
r.query()
r.df
# Out:
# Empty DataFrame
# Columns: [Entity ID, Ambassadors_Residence_P279, Ambassadors_Residence_P279Label]
# Index: []

# %%
gov_building_subclass = 'Ambassadors_Residence'
qnum = 'Q47163308' # qnum of ambassador's residence
r = createRelation(qnum, label=True)
r.extend('P31', True, gov_building_subclass, label=True) # extend via property P31 = is instance of
r.query()
r.df
# Out:
#                                    Entity ID  \
# 0   http://www.wikidata.org/entity/Q47163308
# 1   http://www.wikidata.org/entity/Q47163308
# 2   http://www.wikidata.org/entity/Q47163308
# 3   http://www.wikidata.org/entity/Q47163308
# 4   http://www.wikidata.org/entity/Q47163308
# 5   http://www.wikidata.org/entity/Q47163308
# 6   http://www.wikidata.org/entity/Q47163308
# 7   http://www.wikidata.org/entity/Q47163308
# 8   http://www.wikidata.org/entity/Q47163308
# 9   http://www.wikidata.org/entity/Q47163308
# 10  http://www.wikidata.org/entity/Q47163308
# 11  http://www.wikidata.org/entity/Q47163308
# 12  http://www.wikidata.org/entity/Q47163308
# 13  http://www.wikidata.org/entity/Q47163308
# 14  http://www.wikidata.org/entity/Q47163308
# 15  http://www.wikidata.org/entity/Q47163308
# 16  http://www.wikidata.org/entity/Q47163308
# 17  http://www.wikidata.org/entity/Q47163308
# 18  http://www.wikidata.org/entity/Q47163308
# 19  http://www.wikidata.org/entity/Q47163308
#
#                    Ambassadors_Residence_P31  \
# 0    http://www.wikidata.org/entity/Q7272144
# 1    http://www.wikidata.org/entity/Q1137916
# 2    http://www.wikidata.org/entity/Q3298156
# 3    http://www.wikidata.org/entity/Q4969437
# 4    http://www.wikidata.org/entity/Q5501970
# 5    http://www.wikidata.org/entity/Q7315412
# 6    http://www.wikidata.org/entity/Q7382168
# 7   http://www.wikidata.org/entity/Q14954758
# 8   http://www.wikidata.org/entity/Q47163357
# 9   http://www.wikidata.org/entity/Q47163498
# 10  http://www.wikidata.org/entity/Q47163465
# 11  http://www.wikidata.org/entity/Q20529433
# 12  http://www.wikidata.org/entity/Q65505208
# 13  http://www.wikidata.org/entity/Q65515701
# 14  http://www.wikidata.org/entity/Q28225884
# 15  http://www.wikidata.org/entity/Q47163285
# 16  http://www.wikidata.org/entity/Q28225802
# 17  http://www.wikidata.org/entity/Q65503516
# 18  http://www.wikidata.org/entity/Q65515684
# 19  http://www.wikidata.org/entity/Q47163445
#
#                        Ambassadors_Residence_P31Label
# 0                                        Quincy House
# 1                                      Winfield House
# 2                                 Deerfield Residence
# 3   British Ambassador's residence in Washington, ...
# 4   French ambassador's residence in Washington, D.C.
# 5   Residence of the Ambassador of the Netherlands...
# 6   Russian ambassador's residence in Washington, ...
# 7                                  49 Belgrave Square
# 8               Dutch ambassador's residence in Tokyo
# 9              German ambassador's residence in Tokyo
# 10            Spanish ambassador's residence in Tokyo
# 11           German Ambassador's Residence in Tallinn
# 12                                          Q65505208
# 13                                          Q65515701
# 14                                   Hagemann Mansion
# 15           American ambassador's residence in Tokyo
# 16       Italian ambassador's residence in Copenhagen
# 17                Spanish Embassy residence in Prague
# 18                    Greek Embassy residence, Prague
# 19           Canadian ambassador's residence in Tokyo

# %% [markdown]
# # Find every subclass of `public building`

# %%
gov_building_subclass = 'Public_Building'
qnum = 'Q294422' # qnum of public building
r = createRelation(qnum, label=True) # create relation for Q1137809 = courthouses
r.extend('P279', True, gov_building_subclass, label=True) # extend via property P279 = is subclass of
r.query()
r.df
# Out:
#                                  Entity ID  \
# 0   http://www.wikidata.org/entity/Q294422
# 1   http://www.wikidata.org/entity/Q294422
# 2   http://www.wikidata.org/entity/Q294422
# 3   http://www.wikidata.org/entity/Q294422
# 4   http://www.wikidata.org/entity/Q294422
# 5   http://www.wikidata.org/entity/Q294422
# 6   http://www.wikidata.org/entity/Q294422
# 7   http://www.wikidata.org/entity/Q294422
# 8   http://www.wikidata.org/entity/Q294422
# 9   http://www.wikidata.org/entity/Q294422
# 10  http://www.wikidata.org/entity/Q294422
# 11  http://www.wikidata.org/entity/Q294422
# 12  http://www.wikidata.org/entity/Q294422
# 13  http://www.wikidata.org/entity/Q294422
# 14  http://www.wikidata.org/entity/Q294422
# 15  http://www.wikidata.org/entity/Q294422
#
#                         Public_Building_P279 Public_Building_P279Label
# 0     http://www.wikidata.org/entity/Q180370                  hospital
# 1    http://www.wikidata.org/entity/Q1137809                courthouse
# 2    http://www.wikidata.org/entity/Q3917681                   embassy
# 3   http://www.wikidata.org/entity/Q16410648                 Q16410648
# 4   http://www.wikidata.org/entity/Q39364723         hospital building
# 5    http://www.wikidata.org/entity/Q3530380                    toguna
# 6   http://www.wikidata.org/entity/Q55221816                 Q55221816
# 7    http://www.wikidata.org/entity/Q6908719                 moot hall
# 8      http://www.wikidata.org/entity/Q35054               post office
# 9   http://www.wikidata.org/entity/Q32350958                bingo hall
# 10     http://www.wikidata.org/entity/Q41253             movie theater
# 11     http://www.wikidata.org/entity/Q24354                   theatre
# 12     http://www.wikidata.org/entity/Q46124                sanatorium
# 13  http://www.wikidata.org/entity/Q52177058            civic building
# 14  http://www.wikidata.org/entity/Q97459036              civic center
# 15  http://www.wikidata.org/entity/Q69503165           public facility

# %% [markdown]
# # Find every subclass of `civic building`

# %%
gov_building_subclass = 'Civic_Building'
qnum = 'Q52177058' # qnum of civic building
r = createRelation(qnum, label=True) # create relation for Q1137809 = courthouses
r.extend('P279', True, gov_building_subclass, label=True) # extend via property P279 = is subclass of
r.query()
r.df
# Out:
#                                   Entity ID  \
# 0  http://www.wikidata.org/entity/Q52177058
# 1  http://www.wikidata.org/entity/Q52177058
# 2  http://www.wikidata.org/entity/Q52177058
# 3  http://www.wikidata.org/entity/Q52177058
# 4  http://www.wikidata.org/entity/Q52177058
# 5  http://www.wikidata.org/entity/Q52177058
#
#                        Civic_Building_P279 Civic_Building_P279Label
# 0   http://www.wikidata.org/entity/Q367885             village hall
# 1   http://www.wikidata.org/entity/Q543654                city hall
# 2  http://www.wikidata.org/entity/Q1137809               courthouse
# 3  http://www.wikidata.org/entity/Q7138926      parliament building
# 4  http://www.wikidata.org/entity/Q5177802              county hall
# 5  http://www.wikidata.org/entity/Q1500368         Municipal office

# %% [markdown]
# # Conclusion for now
#
# At this point, it became clear that manually going through to consolidate a list of all instances under "government buildings" is not the way to do this.
#
# I asked Dinghao if there were plans to include some functionality in the system to address this, and we had a good correspondence about it.
#
# #### My question to Dinghao:
#
# I'd like to grab every government building in wikidata. However, because WikiData doesn't transitively populate instance relationships all the way through subclasses, when I query for all instances of "government building", only 117 buildings are listed as instances of "government building" (even though there are 400+ courthouses alone and courthouse is a subclass of government building).
#
# With your code, is there away to recursively search through subclasses and find all government buildings?
#
# In the SPARQL web interface, I am able to recursively see all the subclasses under "government buildings" by adding a plus sign (+) after the P-number for "is subclass of" (P279), and this shows me all the classes, as follows:
#
# https://query.wikidata.org/#SELECT%20%3Fs%20%3Fdesc%0AWHERE%0A%7B%0A%20%20%3Fs%20wdt%3AP279%2B%20wd%3AQ16831714%20.%0A%20%20OPTIONAL%20%7B%0A%20%20%20%20%20%3Fs%20rdfs%3Alabel%20%3Fdesc%20filter%20%28lang%28%3Fdesc%29%20%3D%20%22en%22%29.%0A%20%20%20%7D%0A%20%7D
#
# #### Dinghao's response:
#
# Hi Jenny. A short answer is no. This is actually a very good point. This problem has actually been raised before. As you can see, "government buildings" actually has a lot of subclasses, and all of these subclasses may contain a lot of instances. This might require great computational cost. At that time, we hadn't build up our system yet, so we decided to shelve it. But now I believe it's a good time to reconsider this problem. I'll try to fix this problem this week if you are not in a hurry. But if you really need it to be done as soon as possible, please let me know. Thank you for your great question which improves the system.
#
# # Next steps
#
# Once Dinghao implements recursive collection of instances under a class, I'll use that to collect all instances under `Government Buildings` and filter + grab related data we want, and that will go into the knowledge graph.
