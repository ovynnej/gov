# %% [markdown]
# # Objective
#
# Task: Create an absolutely bare-bones data pipeline. Try to build a "good" output out of 2 or more of the found datasets.

# %%
import io, requests
import pandas as pd
from datetime import date
from htmldate import find_date

# %% [markdown]
# # Functions

# %% [markdown]
# ### Check whether updates are needed
#
# **Inputs**:
# - URL to the landing page for a csv file that we know has address data for government buildings
# - date last pulled
#
# **Output**:
# - boolean indicating whether an update is needed

# %%
def needs_update(url, date_last_pulled):
    date_last_updated = find_date(url)
    return date_last_updated > date_last_pulled

# %% [markdown]
# ### Get addresses
#
# **Input**: URL to a csv file that we know has address data for government buildings
#
# **Output**: list of addresses from the file

# %%
def get_addresses(url):
    s = requests.get(url).content
    df = pd.read_csv(io.StringIO(s.decode('utf-8')))

    address_col_names = []
    for x in df.columns:
        if 'address' in x.lower():
            address_col_names.append(x)

    for address_col_name in address_col_names:
        print(list(df[address_col_name]))

# %% [markdown]
# # Demo
#
# With 3 outputs from the found datasets

# %%
# CA Dept. of Tax and Fee Administration Offices
cdtfa_data_url = 'http://data-cdtfa.opendata.arcgis.com/datasets/6b7ab4e55a2d463db9e902c2496c6e37_0.csv?outSR=%7B%22latestWkid%22%3A3857%2C%22wkid%22%3A102100%7D'
cdtfa_landing_url = 'https://data.ca.gov/dataset/cdtfa-offices'

# Directory of conference rooms available in buildings owned by the CA Dept. of General Services
dgs_data_url = 'https://data.ca.gov/dataset/c5a3c577-3d2f-47fa-85f7-7aae00b2adc3/resource/def5d673-e39a-461d-bef1-a417579fd02e/download/dgs-conference-rooms.csv'
dgs_landing_url = 'https://data.ca.gov/dataset/dgs-conference-rooms'

# CA Dept. of Developmental Services Regional Centers
dds_data_url = 'https://data.chhs.ca.gov/dataset/0e68b593-183d-41d0-80e0-7e828d99a22d/resource/369ea9be-077f-423d-b10d-09022e3fda9f/download/regional-center-information.csv'
dds_landing_url = 'https://data.ca.gov/dataset/regional-center-information'

# %% [markdown]
# ###  Quick look at data contents

# %%
s = requests.get(cdtfa_data_url).content
pd.read_csv(io.StringIO(s.decode('utf-8'))).head()
# Out:
#               X             Y  OBJECTID  doid         city  \
# 0 -1.324950e+07  4.216651e+06         1     1  Bakersfield
# 1 -1.314243e+07  4.011057e+06         2     6     Cerritos
# 2 -1.317931e+07  4.026731e+06         3     2  Culver City
# 3 -1.286559e+07  3.867842e+06         4     3    El Centro
# 4 -1.358663e+07  4.618437e+06         5    32    Fairfield
#
#                          address1   address2 state         zip  \
# 0                    1800 30th St  Suite 380    CA  93301-1922
# 1  12750 Center Court Drive South   Ste. 400    CA  90703-8594
# 2        5901 Green Valley Circle   Ste. 200    CA  90230-6948
# 3              1550 West Main St.               CA  92243-2832
# 4               2480 Hilborn Road  Suite 200    CA       94534
#
#             phone             fax  \
# 0  (661) 395-2880  (661) 395-2588
# 1  (562) 356-1102  (562) 402-8503
# 2  (310) 342-1000  (310) 342-1061
# 3  (760) 352-3431  (760) 352-8149
# 4  (707) 427-4800  (707) 427-4815
#
#                                           directions     comments type  \
# 0  https://www.google.com/maps/dir//1800+30th+St,...  Bakersfield   in
# 1  https://www.google.com/maps/dir//12750+Center+...     Cerritos   in
# 2  https://www.google.com/maps/dir//5901+Green+Va...  Culver City   in
# 3  https://www.google.com/maps/dir//1550+W+Main+S...    El Centro   in
# 4  https://www.google.com/maps/dir//2480+Hilborn+...    Fairfield   in
#
#   DISTRICT_OF_LOC   OfficeType
# 0             DFB  Bakersfield
# 1              AA     Cerritos
# 2              AS  Culver City
# 3             FHA    El Centro
# 4             JHF    Fairfield

# %%
s = requests.get(dgs_data_url).content
pd.read_csv(io.StringIO(s.decode('utf-8'))).head()
# Out:
#                 RegionName       BuildingName           Address1        City  \
# 0  Capitol Historic Region       900 N Street       900 N Street  Sacramento
# 1  Capitol Historic Region   914 Capitol Mall   914 Capitol Mall  Sacramento
# 2  Capitol Historic Region   915 Capitol Mall   915 Capitol Mall  Sacramento
# 3                Region II  31 E. Channel St.  31 E. Channel St.    Stockton
# 4                Region II  31 E. Channel St.  31 E. Channel St.    Stockton
#
#   State    ZIP    RoomName  RoomComments            Contact     Telephone  \
# 0    CA  95814         501           NaN        Jack Nolan   916-654-0033
# 1    CA  95814         500           NaN        Jack Nolan   916-654-0033
# 2    CA  95814         587           NaN   Luis Hermosillo   916-653-3382
# 3    CA  95202        A-10           NaN  Building Manager   209-948-7730
# 4    CA  95202  Auditorium           NaN  Building Manager   209-948-7730
#
#    ...  VideoConferencing ProjectionScreen SpeakerSystem Projector  \
# 0  ...                  N                Y             N         N
# 1  ...                  N                Y             N         N
# 2  ...                  N                Y             N         N
# 3  ...                  N                Y             Y         N
# 4  ...                  N                Y             Y         N
#
#   TeleDataOutlet WhiteBoard VCRorDVD TenantUse StateAgencyUse PublicUse
# 0              Y          Y        N         N              N         N
# 1              Y          N        Y         Y              N         N
# 2              Y          N        N         Y              N         N
# 3              N          N        N         Y              Y         N
# 4              N          N        N         Y              Y         N
#
# [5 rows x 22 columns]

# %%
s = requests.get(dds_data_url).content
pd.read_csv(io.StringIO(s.decode('utf-8'))).head()
# Out:
#                     Regional Center   Office                     Address  \
# 0      Far Northern Regional Center    Field         421 Chestnut Street
# 1         North Bay Regional Center     Main            610 Airpark Road
# 2       San Andreas Regional Center     Main      300 Orchard City Drive
# 3  Regional Center of Orange County  Mailing               P.O Box 22010
# 4            Inland Regional Center     Main  1365 South Waterman Avenue
#
#       Suite            City State  Zip Code       Telephone  \
# 0       NaN      Mt. Shasta    CA     96067  (530) 222-4791
# 1       NaN            Napa    CA     94558  (707) 256-1100
# 2  Ste. 170        Campbell    CA     95008  (408) 374-9960
# 3       NaN       Santa Ana    CA     92702  (714) 796-5100
# 4       NaN  San Bernardino    CA     92408  (909) 890-3000
#
#                  Website   County Served Los Angeles Health District Served  \
# 0  www.farnorthernrc.org             NaN                                NaN
# 1           www.nbrc.net          Solano                                NaN
# 2           www.sarc.org     Santa Clara                                NaN
# 3         www.rcocdd.com             NaN                                NaN
# 4       www.inlandrc.org  San Bernardino                                NaN
#
#                                           Location 1
# 0  421 Chestnut Street\nMt. Shasta 96067\n(41.315...
# 1  610 Airpark Road\nNapa 94558\n(38.218198, -122...
# 2  300 Orchard City Drive\nCampbell 95008\n(37.28...
# 3                   P.O Box 22010\nSanta Ana 92702\n
# 4  1365 South Waterman Avenue\nSan Bernardino 924...

# %% [markdown]
# ## Check whether the data needs to be pulled again

# %%
date_last_pulled = str(date.today()) # Example 1

for landing_url in [cdtfa_landing_url, dgs_landing_url, dds_landing_url]:
    print(needs_update(landing_url, date_last_pulled))

print('-------')
date_last_pulled = '2020-08-01' # Example 2

for landing_url in [cdtfa_landing_url, dgs_landing_url, dds_landing_url]:
    print(needs_update(landing_url, date_last_pulled))
# Out:
# False
# False
# False
# -------
# True
# False
# True

# %% [markdown]
# ## Pull datasets and print government building addresses listed

# %%
for data_url in [cdtfa_data_url, dgs_data_url, dds_data_url]:
    get_addresses(data_url)
    print('\n\n')
# Out:
# ['1800 30th St', '12750 Center Court Drive South', '5901 Green Valley Circle', '1550 West Main St.', '2480 Hilborn Road', '8050 N Palm Ave', '505 N Brand Blvd', '16715 Von Karman Avenue', '1515 Clay St.', '35-900 Bob Hope Dr.', '2881 Churn Creek Rd.', '3737 Main St.', '3321 Power Inn Rd.', '450 N Street', '950 E. Blanco Road', '15015 Avenue of Science', '250 South Second St.', '25360 Magic Mountain Parkway', '50 D St.', '4820 McGrath St.', '1521 West Cameron Ave.', '120 N. La Salle St.', '1155 Dairy Ashford', '485 Lexington Avenue', '1030 Riverside Parkway', '3321 Power Inn Rd.']
# ['Suite 380', 'Ste. 400', 'Ste. 200', ' ', 'Suite 200', 'Ste 205', 'Ste. 700', 'Suite 200', 'Ste. 303', 'Ste. 280', 'Ste. B', 'Ste. 1000', 'Ste. 210', ' ', 'Ste. 202', 'Suite 200', ' ', 'Suite 330', 'Room 230', 'Ste. 260', 'Ste. 300', 'Ste. 1500', 'Ste. 550', 'Suite 400', 'Suite 125', 'Ste. 130']
#
#
#
# ['900 N Street', '914 Capitol Mall', '915 Capitol Mall', '31 E. Channel St.', '31 E. Channel St.', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '1600 9th St.', '1600 9th St.', '901 P St.', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '2440 Main Street', '2135 Civic Center Drive', '1500 11th St.', '1500 11th St.', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1616 Capitol Avenue', '1616 Capitol Avenue', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '707 Third St.', '707 Third St.', '100 Paseo de San Antonio', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '50 D St.', '50 D St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1350 Front Street', '1350 Front Street', '1350 Front Street', '1350 Front Street', '2550 Mariposa Mall', '2550 Mariposa Mall', '2550 Mariposa Mall', '2550 Mariposa Mall', '3374 E. Shields', '4050 Taylor Street', '4050 Taylor Street', '7575 Metropolitan Drive # 101', '7575 Metropolitan Drive # 101', '3737 Main Street', '3737 Main Street', '3737 Main Street', '3737 Main Street', '3737 Main Street', '605 W. Santa Ana Boulevard', '605 W. Santa Ana Boulevard', '605 W. Santa Ana Boulevard', '6150 Van Nuys Blvd.']
#
#
#
# ['421 Chestnut Street', '610 Airpark Road', '300 Orchard City Drive', 'P.O Box 22010', '1365 South Waterman Avenue', '3303 Wilshire Blvd.', '702 North Aurora Street', '270 Chestnut Street', '2241 Harvard Street', '702 North Aurora Street', '15400 Sherman Way', '825 North Downs', '5901 Green Valley Circle', '1900 Churn Creek Road', '5441 West Cypress Avenue', '300 Orchard City Drive', '43210 Gingham Avenue', '21231 Hawthorne Blvd.', '1160 East Lerdo Highway', '75 Rancho Camino Drive', '333 Crown Point Circle', '4615 North Marty Avenue', '21231 Hawthorne Blvd.', '344 Placerville Drive', '520 East Montecito Street', '520 East Montecito Street', '10803 Hope Street', '525 2nd Street', '915 North 10th Street', '2241 Harvard Street', '3303 Wilshire Blvd.', '3303 Wilshire Blvd.', '1525 North Tustin Avenue', '1000 South Fremont Avenue', '702 North Aurora Street', '2500 South Western Avenue', '2241 Harvard Street', '4615 North Marty Avenue', '15400 Sherman Way', '401 Peninsula Drive', '15400 Sherman Way', '1355 Market Street', '525 2nd Street', '500 Davis Street', '704 Mountain Ranch Road', '2401 East Gonzales Road', '2241 Harvard Street', '1500 Iowa Avenue', '13450 Donner Pass Road', '4615 North Marty Avenue', '13215 Penn Street', '1820 Blue Gum Avenue', '2727 Hoover Avenue', '5931 Priestly Drive', '21231 Hawthorne Blvd.', '1900 Churn Creek Road', '3200 North Sillect Avenue', '4615 North Marty Avenue', '1116 Airport Park Blvd.', '1900 Churn Creek Road', '20031 West Valley Blvd.', '4615 North Marty Avenue', '1110 Main Street', '2500 South Western Avenue', '530 West 16th Street', '525 2nd Street', '1365 South Waterman Avenue', 'P.O. Box 50002', '300 Orchard City Drive', '525 2nd Street', '3450 Broad Street', '1000 South Fremont Avenue', '1377 East Lassen Avenue', '1355 Market Street', '1900 Churn Creek Road', '1900 Churn Creek Road', '3130 La Selva Drive', '1234 Fairway Drive', '3200 North Sillect Avenue', '8760 Cuyamaca Street', '1900 Churn Creek Road', '75 Rancho Camino Drive', '2500 South Western Avenue', '4355 Ruffin Road', '8601 High Street', '1355 Market Street', '4000 Civic Center Drive', '2241 Harvard Street', '25360 Magic Mountain Parkway', '7855 Wren Avenue', '250 West Main Street', '75 Rancho Camino Drive', '2241 Harvard Street', '2489 Lake Tahoe Blvd.', '1000 South Fremont Avenue', '2635 Park Center Drive', '1155 East San Antonio Drive', '2241 Harvard Street', '300 Orchard City Drive', '520 East Montecito Street', '1301-A Northcrest Drive', '21231 Hawthorne Blvd.', '512 West Aten Road', '2500 Sout Western Avenue', '1000 South Fremont Avenue', '702 North Aurora Street', '610 Airpark Road', '7305 Morro Road', '2500 South Western Avenue', '4355 Ruffin Road', '2241 Harvard Street', '180 3rd Street', '610 Airpark Road', '75 Rancho Camino Drive', '2351 Mendocino Avenue', '950 Tharp Road', '2241 Harvard Street', '5901 Green Valley Circle', 'P.O. Box 692290', '344 Salinas Street', 'P.O. Box 7916', '1320 Willow Pass Road', '702 North Aurora Street', 'P.O. Box 19037', '1900 Churn Creek Road', '2241 Harvard Street', '1900 Churn Creek Road', '3200 North Sillect Avenue', '459 West Line Street', '1900 Churn Creek Road', '7707 Panama Road', '1620 Santa Clara Drive', '3303 Wilshire Blvd.', '500 Davis Street', '4615 North Marty Avenue']

# %% [markdown]
# # Sandbox
# Everything below this is just the remnants from when I was testing things out and learning; I'm keeping them here for my own reference.

# %%
date_last_updated = find_date(cdtfa_landing_url)
date_last_updated
# Out:
# '2020-09-27'

# %%
date_last_pulled = str(date.today())
date_last_pulled
# Out:
# '2020-09-29'

# %%
cdtfa_url = 'http://data-cdtfa.opendata.arcgis.com/datasets/6b7ab4e55a2d463db9e902c2496c6e37_0.csv?outSR=%7B%22latestWkid%22%3A3857%2C%22wkid%22%3A102100%7D'
s = requests.get(cdtfa_url).content
df = pd.read_csv(io.StringIO(s.decode('utf-8')))
df.head()
# Out:
#               X             Y  OBJECTID  doid         city  \
# 0 -1.324950e+07  4.216651e+06         1     1  Bakersfield
# 1 -1.314243e+07  4.011057e+06         2     6     Cerritos
# 2 -1.317931e+07  4.026731e+06         3     2  Culver City
# 3 -1.286559e+07  3.867842e+06         4     3    El Centro
# 4 -1.358663e+07  4.618437e+06         5    32    Fairfield
#
#                          address1   address2 state         zip  \
# 0                    1800 30th St  Suite 380    CA  93301-1922
# 1  12750 Center Court Drive South   Ste. 400    CA  90703-8594
# 2        5901 Green Valley Circle   Ste. 200    CA  90230-6948
# 3              1550 West Main St.               CA  92243-2832
# 4               2480 Hilborn Road  Suite 200    CA       94534
#
#             phone             fax  \
# 0  (661) 395-2880  (661) 395-2588
# 1  (562) 356-1102  (562) 402-8503
# 2  (310) 342-1000  (310) 342-1061
# 3  (760) 352-3431  (760) 352-8149
# 4  (707) 427-4800  (707) 427-4815
#
#                                           directions     comments type  \
# 0  https://www.google.com/maps/dir//1800+30th+St,...  Bakersfield   in
# 1  https://www.google.com/maps/dir//12750+Center+...     Cerritos   in
# 2  https://www.google.com/maps/dir//5901+Green+Va...  Culver City   in
# 3  https://www.google.com/maps/dir//1550+W+Main+S...    El Centro   in
# 4  https://www.google.com/maps/dir//2480+Hilborn+...    Fairfield   in
#
#   DISTRICT_OF_LOC   OfficeType
# 0             DFB  Bakersfield
# 1              AA     Cerritos
# 2              AS  Culver City
# 3             FHA    El Centro
# 4             JHF    Fairfield

# %%
address_col_names = []
for x in df.columns:
    if 'address' in x.lower():
        address_col_names.append(x)
address_col_names
# Out:
# ['address1', 'address2']

# %%
for address_col_name in address_col_names:
    print(address_col_name)
    print(list(df[address_col_name]))
# Out:
# address1
# ['1800 30th St', '12750 Center Court Drive South', '5901 Green Valley Circle', '1550 West Main St.', '2480 Hilborn Road', '8050 N Palm Ave', '505 N Brand Blvd', '16715 Von Karman Avenue', '1515 Clay St.', '35-900 Bob Hope Dr.', '2881 Churn Creek Rd.', '3737 Main St.', '3321 Power Inn Rd.', '450 N Street', '950 E. Blanco Road', '15015 Avenue of Science', '250 South Second St.', '25360 Magic Mountain Parkway', '50 D St.', '4820 McGrath St.', '1521 West Cameron Ave.', '120 N. La Salle St.', '1155 Dairy Ashford', '485 Lexington Avenue', '1030 Riverside Parkway', '3321 Power Inn Rd.']
# address2
# ['Suite 380', 'Ste. 400', 'Ste. 200', ' ', 'Suite 200', 'Ste 205', 'Ste. 700', 'Suite 200', 'Ste. 303', 'Ste. 280', 'Ste. B', 'Ste. 1000', 'Ste. 210', ' ', 'Ste. 202', 'Suite 200', ' ', 'Suite 330', 'Room 230', 'Ste. 260', 'Ste. 300', 'Ste. 1500', 'Ste. 550', 'Suite 400', 'Suite 125', 'Ste. 130']

# %%
dgs_url = 'https://data.ca.gov/dataset/c5a3c577-3d2f-47fa-85f7-7aae00b2adc3/resource/def5d673-e39a-461d-bef1-a417579fd02e/download/dgs-conference-rooms.csv'
s = requests.get(dgs_url).content
dgs_data = pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
dgs_data.head()
# Out:
#                 RegionName       BuildingName           Address1        City  \
# 0  Capitol Historic Region       900 N Street       900 N Street  Sacramento
# 1  Capitol Historic Region   914 Capitol Mall   914 Capitol Mall  Sacramento
# 2  Capitol Historic Region   915 Capitol Mall   915 Capitol Mall  Sacramento
# 3                Region II  31 E. Channel St.  31 E. Channel St.    Stockton
# 4                Region II  31 E. Channel St.  31 E. Channel St.    Stockton
#
#   State    ZIP    RoomName  RoomComments            Contact     Telephone  \
# 0    CA  95814         501           NaN        Jack Nolan   916-654-0033
# 1    CA  95814         500           NaN        Jack Nolan   916-654-0033
# 2    CA  95814         587           NaN   Luis Hermosillo   916-653-3382
# 3    CA  95202        A-10           NaN  Building Manager   209-948-7730
# 4    CA  95202  Auditorium           NaN  Building Manager   209-948-7730
#
#    ...  VideoConferencing ProjectionScreen SpeakerSystem Projector  \
# 0  ...                  N                Y             N         N
# 1  ...                  N                Y             N         N
# 2  ...                  N                Y             N         N
# 3  ...                  N                Y             Y         N
# 4  ...                  N                Y             Y         N
#
#   TeleDataOutlet WhiteBoard VCRorDVD TenantUse StateAgencyUse PublicUse
# 0              Y          Y        N         N              N         N
# 1              Y          N        Y         Y              N         N
# 2              Y          N        N         Y              N         N
# 3              N          N        N         Y              Y         N
# 4              N          N        N         Y              Y         N
#
# [5 rows x 22 columns]

# %%
address_col_names = []
for x in dgs_data.columns:
    if 'address' in x.lower():
        address_col_names.append(x)
address_col_names
# Out:
# ['Address1']

# %%
for address_col_name in address_col_names:
    print(address_col_name)
    print(list(dgs_data[address_col_name]))
# Out:
# Address1
# ['900 N Street', '914 Capitol Mall', '915 Capitol Mall', '31 E. Channel St.', '31 E. Channel St.', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '744 P Street (OB-9)', '1600 9th St.', '1600 9th St.', '901 P St.', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '1516 9th Street', '2440 Main Street', '2135 Civic Center Drive', '1500 11th St.', '1500 11th St.', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '9645 Butterfield Way', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1300 I Street', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1500 Capitol Avenue', '1616 Capitol Avenue', '1616 Capitol Avenue', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '450 N Street', '707 Third St.', '707 Third St.', '100 Paseo de San Antonio', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '455 Golden Gate Ave', '50 D St.', '50 D St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1515 Clay St.', '1350 Front Street', '1350 Front Street', '1350 Front Street', '1350 Front Street', '2550 Mariposa Mall', '2550 Mariposa Mall', '2550 Mariposa Mall', '2550 Mariposa Mall', '3374 E. Shields', '4050 Taylor Street', '4050 Taylor Street', '7575 Metropolitan Drive # 101', '7575 Metropolitan Drive # 101', '3737 Main Street', '3737 Main Street', '3737 Main Street', '3737 Main Street', '3737 Main Street', '605 W. Santa Ana Boulevard', '605 W. Santa Ana Boulevard', '605 W. Santa Ana Boulevard', '6150 Van Nuys Blvd.']
