# %% [markdown]
# # Objective
#
# - Take a random sample of 100 (or 500, in the case of government buildings)
# - Label them by hand to see if they're actually examples of the desired class
# - Measure precision
#
# # Results
# - 500/500 entities are actually government buildings.
# - 18/100 entities are actually occupations.
# - 100/100 entities are actually cities.
# - 13/100 entities are actually sports.
# - 99/100 entities are actually houses.

# %%
import sys
# !{sys.executable} -m pip install SPARQLWrapper
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import numpy as np
import datetime
import func_lib

endpoint_url = "https://query.wikidata.org/sparql"
item = "item"


class Relation:
    """
    The class returned when createRelation is called.
    It contains string field with query.
    We call Relation.query when we need to do the query.
    """

    def __init__(self, entity_id: str, property_id: str, isSubject: bool, rowVerbose: bool,
                 colVerbose: bool, time_property: str, time: str, name: str, label: bool, limit=10000, subclass=False):
        self.entity_id = entity_id
        self.query_str = ""
        self.dic = {}
        self.result_dic = {"Entity ID": []}
        self.df = pd.DataFrame()
        self.count = 0
        self.time_property = time_property
        self.time = time
        self.limit = limit
        self.subclass = subclass
        self.focus = "Entity ID"
        if property_id:
            self.extend(property_id, isSubject, name, rowVerbose, colVerbose, limit, time_property, time, label, subclass)

    def generate_html(self, name: str):
        html = (self.df).to_html()
        text_file = open(name, "w", encoding='utf-8')
        text_file.write(html)
        text_file.close()

    def query(self, require=None):
        if self.query_str == "":
            self.result_dic = {"Entity ID": ['http://www.wikidata.org/entity/' + str(self.entity_id)]}
            return self.result_dic
        results = get_results(endpoint_url, self.query_str)
        result_dict = {"Entity ID": ['http://www.wikidata.org/entity/' + str(self.entity_id)]}
        for i in range(1, self.count + 1):
            result_dict[self.dic[i]["name"] + '_' + self.dic[i]['property_id']] = []
            if self.dic[i]["colVerbose"]:
                result_dict[self.dic[i]["name"] + '_rank_' + self.dic[i]['property_id'] + '_rank'] = []
                for key, value in self.dic[i]["property_name_dic"].items():
                    result_dict[
                        self.dic[i]["name"] + "_" + value + '_' + self.dic[i]['property_id'] + '_' + str(key)] = []
                for key, value in self.dic[i]["ref_dic"].items():
                    result_dict[self.dic[i]["name"] + "_ref_" + self.dic[i]['property_id'] + '_' + str(key)] = []

            if self.dic[i]["label"]:
                result_dict[self.dic[i]["name"] + '_' + self.dic[i]['property_id'] + 'Label'] = []

        for result in results['results']['bindings']:
            for key, value in result_dict.items():
                if key in result.keys():
                    result_dict[key].append(result[key]['value'])
                else:
                    result_dict[key].append('NA')
        result_dict["Entity ID"] = ['http://www.wikidata.org/entity/' + str(self.entity_id)] * len(
            result_dict[self.dic[self.count]["name"] + '_' + self.dic[self.count]["property_id"]])
        self.result_dic = result_dict
        self.df = pd.DataFrame.from_dict(self.result_dic)
        for i in range(1, self.count + 1):
            if self.dic[i]["colVerbose"] and not self.dic[i]["rowVerbose"]:
                col = self.dic[i]['name'] + '_rank_' + self.dic[i]['property_id'] + '_rank'
                if any(self.df[col] == 'http://wikiba.se/ontology#PreferredRank'):
                    self.df = self.df.loc[self.df[col] == 'http://wikiba.se/ontology#PreferredRank']
                else:
                    self.df = self.df.loc[self.df[col] == 'http://wikiba.se/ontology#NormalRank']
#         if require is not None:
#             for r in require:
#                 self.df = self.df.loc[self.df[r] != 'NA']
        self.df = pd.DataFrame(data=self.df)
#         if self.df.shape[0] >= 10000:
#             print("Warning: Your query leads to too many results. Only 10,000 returned.")
        return self.df

    def extend(self, property_id: str, isSubject: bool, name: str, rowVerbose=False, colVerbose=False, limit=None,
               time_property=None, time=None, search=None, label=False, subclass=False):
        self.count += 1
        self.dic[self.count] = {}
        self.dic[self.count]["name"] = name
        self.dic[self.count]["focus"] = self.focus
        self.dic[self.count]["property_id"] = property_id
        self.dic[self.count]["isSubject"] = isSubject
        self.dic[self.count]["limit"] = limit
        self.dic[self.count]["rowVerbose"] = rowVerbose
        self.dic[self.count]["colVerbose"] = colVerbose
        self.dic[self.count]['time_property'] = time_property
        self.dic[self.count]['time'] = time
        self.dic[self.count]['search'] = search
        self.dic[self.count]['label'] = label
        self.dic[self.count]['subclass'] = subclass
        # subclass is specific to P31, when subclass is true, we get intance of all subclasses of the entity
        if rowVerbose or colVerbose:
            self.dic[self.count]["property_name_dic"], self.dic[self.count][
                "ref_dic"] = self.search_property_for_verbose()
        if time_property and time:
            self.time_property = time_property
            self.time = time
        if limit:
            self.limit = limit
        self.query_str = self.define_query_relation()

    def changeFocus(self, name="Entity ID"):
        self.focus = name
        
    def extendWithFunction(self, objcolumn, func, name):
        if type(func) == str:
            if func.startswith('F'):
                try:
                    func_id = int(func[1:])
                    if func_id >= func_lib.func_num():
                        print("Not available.")
                    else:
                        if isinstance(objcolumn, list):
                            self.df[name] = self.df[objcolumn].apply(lambda x: func_lib.func_list[func_id](*x), axis=1)
                        else:
                            self.df[name] = self.df[objcolumn].apply(func_lib.func_list[func_id])
                except:
                    raise Exception("Not a valid function id, a valid function id should be 'Fn', n is an integer.")
            else:
                raise Exception("Not a valid function id, a valid function id should be 'Fn', n is an integer.")
        else:
            if isinstance(objcolumn, list):
                self.df[name] = self.df[objcolumn].apply(lambda x: func(*x), axis=1)
            else:
                self.df[name] = self.df[objcolumn].apply(func)

    def define_query_relation(self):
        rdf_triple, time_filter, limit_statement = """""", """""", """"""
        if self.count < 1:
            return None
        focusChanges = 0
        for i in range(1, self.count + 1):
            if self.dic[i]["rowVerbose"] or self.dic[i]["colVerbose"]:
                if self.dic[i]["search"] is None and not self.dic[i]["isSubject"]:
                        rdf_triple += """OPTIONAL {"""
                if self.dic[i]["focus"] == "Entity ID":
#                     if self.dic[i]["search"] is None:
#                         rdf_triple += """OPTIONAL {"""
                    rdf_triple += """wd:""" + self.entity_id + """ p:""" + self.dic[i][
                        'property_id'] + """ ?statement_""" + str(i) + """. """ \
                                  + """?statement_""" + str(i) + """ ps:""" + self.dic[i][
                                      'property_id'] + """ ?""" + \
                                  self.dic[i]['name'] \
                                  + """_""" + self.dic[i]['property_id'] + """. """
                else:
                    rdf_triple += """?""" + self.dic[i]["focus"] + """ p:""" + self.dic[i][
                        'property_id'] + """ ?statement_""" + str(i) + """. """ \
                                  + """?statement_""" + str(i) + """ ps:""" + self.dic[i][
                                      'property_id'] + """ ?""" + \
                                  self.dic[i]['name'] \
                                  + """_""" + self.dic[i]['property_id'] + """. """
                for key, value in self.dic[i]["property_name_dic"].items():
                    rdf_triple += """OPTIONAL { """ + """?statement_""" + str(i) + """ pq:""" + str(key) \
                                  + """ ?""" + self.dic[i]['name'] + """_""" + value + """_""" + self.dic[i][
                                      'property_id'] + """_""" + str(key) + """.} """
                for key, value in self.dic[i]["ref_dic"].items():
                    rdf_triple += """OPTIONAL { ?statement_""" + str(
                        i) + """ prov:wasDerivedFrom ?refnode_""" + str(
                        i) + """. ?refnode_""" + str(i) \
                                  + """ pr:""" + str(key) + """ ?""" + self.dic[i]['name'] + """_ref_""" + \
                                  self.dic[i][
                                      'property_id'] + """_""" + str(key) + """.} """
                rdf_triple += """OPTIONAL { ?statement_""" + str(i) + """ wikibase:rank ?""" + self.dic[i][
                    'name'] + """_rank_""" + self.dic[i]['property_id'] + """_rank. } """
            # none-verbose version
            else:
                if self.dic[i]["focus"] == "Entity ID":
                    if self.dic[i]["isSubject"]:
                        if not self.dic[i]['subclass']:
                            rdf_triple += """?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                                'property_id'] + """ wdt:""" + self.dic[i][
                                              "property_id"] + """ wd:""" + self.entity_id + """. """
                        else:
                            if self.dic[i]['property_id'] == "P31":
                                rdf_triple += """?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                                    'property_id'] + """ wdt:""" + self.dic[i][
                                                  "property_id"] + """ ?subclasses. """
                                rdf_triple += """?subclasses wdt:P279+ wd:""" + self.entity_id + """. """
                    else:
                        if self.dic[i]["search"] is None:
                            rdf_triple += """OPTIONAL {"""
                        rdf_triple += """wd:""" + self.entity_id + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + \
                                      self.dic[i]["name"] + """_""" + self.dic[i]['property_id'] + """. """
                else:
                    if self.dic[i]["isSubject"]:
                        if not self.dic[i]['subclass']:
                            rdf_triple += """?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                                'property_id'] + """ wdt:""" + self.dic[i]["property_id"] + """ ?""" + self.dic[i][
                                              'focus'] + """. """
                        else:
                            if self.dic[i]['property_id'] == "P31":
                                rdf_triple += """?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                                'property_id'] + """ wdt:""" + self.dic[i]["property_id"] + """ ?subclasses. """
                                rdf_triple += """?subclasses wdt:P279+ ?""" + self.dic[i]['focus'] + """. """
                    else:
                        if self.dic[i]["search"] is None:
                            rdf_triple += """OPTIONAL {"""
                        rdf_triple += """?""" + self.dic[i]['focus'] + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i][
                                          'property_id'] + """. """
            if not self.dic[i]["isSubject"]:
                if i < self.count and self.dic[i]["focus"] != self.dic[i + 1]["focus"] and self.dic[i]["search"] is None:
                    focusChanges += 1
                elif self.dic[i]["search"] is None:
                    rdf_triple += """} """
                
        for i in range(focusChanges):
            rdf_triple += """} """
        for i in range(1, self.count + 1):
            if self.dic[i]['search'] is not None and self.dic[i]["search"] != '!NA':
                if isinstance(self.dic[i]['search'], tuple):
                    if isinstance(self.dic[i]['search'][0], str):
                        rdf_triple += """FILTER (YEAR(?""" + self.dic[i]['name'] + """_""" + self.dic[i][
                            'property_id'] + """) >= """ + \
                                      self.dic[i]['search'][0] + """ && YEAR(?""" + self.dic[i]['name'] + \
                                      """_""" + self.dic[i]['property_id'] + """) <= """ + self.dic[i]['search'][
                                          1] + """) """
                    else:
                        rdf_triple += """FILTER (?""" + self.dic[i]['name'] + """_""" + self.dic[i]['property_id'] + \
                                      """ >= """ + str(self.dic[i]['search'][0]) + """ && ?""" + self.dic[i]['name'] + \
                                      """_""" + self.dic[i]['property_id'] + """ <= """ + str(
                            self.dic[i]['search'][1]) + """) """
                else:
                    rdf_triple += """FILTER (?""" + self.dic[i]['name'] + """_""" + self.dic[i][
                        'property_id'] + """ = """ + \
                                  """wd:""" + self.dic[i]['search'] + """) """
        if self.time_property is not None:
            time_filter = """?""" + self.dic[1]["name"] + """ p:""" + self.time_property + """ ?pubdateStatement.	
                          # ?pubdateStatement ps:""" + self.time_property + """ ?date	
                          FILTER (YEAR(?date) = """ + self.time + """)"""
        if self.limit is not None:
            limit_statement = """LIMIT """ + str(self.limit)
        label_statement = """Service wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" }"""
        query = """SELECT DISTINCT"""
        for i in range(1, self.count + 1):
            if self.dic[i]["rowVerbose"] or self.dic[i]["colVerbose"]:
                query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id']
                if self.dic[i]["label"]:
                    query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id'] + """Label"""
                for key, value in self.dic[i]["property_name_dic"].items():
                    query += """ ?""" + self.dic[i]["name"] + """_""" + value + """_""" + self.dic[i][
                        'property_id'] + """_""" + str(key)
                for key, value in self.dic[i]["ref_dic"].items():
                    query += """ ?""" + self.dic[i]["name"] + """_ref_""" + self.dic[i]['property_id'] + """_""" + str(
                        key)
                query += """ ?""" + self.dic[i]["name"] + """_rank_""" + self.dic[i]['property_id'] + """_rank"""
            else:
                query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id']
                if self.dic[i]["label"]:
                    query += """ ?""" + self.dic[i]["name"] + """_""" + self.dic[i]['property_id'] + """Label"""
        query += """ WHERE {""" + rdf_triple + time_filter + label_statement + """} """ + limit_statement
        return query

    def search_property_for_verbose(self):
        property_to_name = {}
        ref_to_name = {}
        rdf_triple, time_filter, limit_statement = """""", """""", """"""
        if self.dic[self.count]["rowVerbose"] or self.dic[self.count]["colVerbose"]:
            for i in range(1, self.count):
                if self.dic[i]["focus"] == "Entity ID":
                    if self.dic[i]["isSubject"]:
                        rdf_triple += """?""" + self.dic[i]["name"] + """ wdt:""" + self.dic[i][
                            "property_id"] + """ wd:""" + self.entity_id + """ ."""
                    else:
                        rdf_triple += """wd:""" + self.entity_id + """ wdt:""" + self.dic[i]["property_id"] + """ ?""" + \
                                      self.dic[i]["name"] + """ ."""
                else:
                    last = self.dic[i]["focus"].rfind('_')
                    focus = self.dic[i]["focus"][:last]
                    if self.dic[i]["isSubject"]:
                        rdf_triple += """?""" + self.dic[i]["name"] + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + focus + """ ."""
                    else:
                        rdf_triple += """?""" + focus + """ wdt:""" + self.dic[i][
                            "property_id"] + """ ?""" + self.dic[i]["name"] + """ ."""
            if self.dic[self.count]["focus"] == "Entity ID":
                rdf_triple += """wd:""" + self.entity_id + """ p:""" + self.dic[self.count][
                    'property_id'] + """ ?statement.""" + \
                              """?statement """ + """ps:""" + self.dic[self.count]['property_id'] + """ ?item.""" + \
                              """?statement """ + """?pq """ + """?obj.""" + \
                              """?qual wikibase:qualifier ?pq.""" + \
                              """OPTIONAL{ ?statement prov:wasDerivedFrom ?refnode. ?refnode ?pr ?r.}"""
            else:
                last = self.dic[self.count]["focus"].rfind('_')
                focus = self.dic[self.count]["focus"][:last]
                rdf_triple += """?""" + focus + """ p:""" + self.dic[self.count][
                    'property_id'] + """ ?statement.""" + \
                              """?statement """ + """ps:""" + self.dic[self.count]['property_id'] + """ ?item.""" + \
                              """?statement """ + """?pq """ + """?obj.""" + \
                              """?qual wikibase:qualifier ?pq.""" + \
                              """OPTIONAL{ ?statement prov:wasDerivedFrom ?refnode. ?refnode ?pr ?r.}"""
        if self.time_property is not None:
            time_filter = """?""" + self.dic[1]["name"] + """ p:""" + self.time_property + """ ?pubdateStatement.	
                                  # ?pubdateStatement ps:""" + self.time_property + """ ?date	
                                  FILTER (YEAR(?date) = """ + self.time + """)"""
        if self.limit is not None:
            limit_statement = """LIMIT """ + str(self.limit)
        label_statement = """Service wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" }"""
        query = """SELECT DISTINCT """
        if self.dic[self.count]["rowVerbose"] or self.dic[self.count]["colVerbose"]:
            query += """?item""" + """ ?qual""" + """ ?qualLabel""" + """ ?obj """ + """?pr ?prLabel"""
            query += """ WHERE {""" + rdf_triple + time_filter + label_statement + """} """ + limit_statement
            query_result = get_results(endpoint_url, query)
            for result in query_result['results']['bindings']:
                if 'qual' in result:
                    property_to_name[result['qual']['value'].split('/')[-1]] = result['qualLabel']['value'].replace(' ',
                                                                                                                    '_')
                if 'pr' in result:
                    ref_to_name[result['pr']['value'].split('/')[-1]] = result['prLabel']['value'].replace(' ', '_')
        else:
            query += """?""" + self.dic[self.count]["name"] + """ """
        return property_to_name, ref_to_name

    def __str__(self):
        return str(self.df)

    def __getattr__(self, col_name):
        if col_name in self.df.columns:
            return self.df[col_name]
        else:
            print(col_name + " has not been found.")
            return None


def createRelation(entity_id: str, property_id=None, isSubject=None, rowVerbose=None, colVerbose=None,
                   time_property=None, time=None, name=None, label=False, limit=None, subclass=False):
    if property_id and not name:
        print("Please specify the name of the first column")
        return None
    return Relation(entity_id, property_id, isSubject, rowVerbose, colVerbose, time_property, time, name, label, limit, subclass)

def get_Firstname(name: str):
    return name.split(' ')[0]

def get_Lastname(name: str):
    return name.split(' ')[-1]

def remove_prefix(text, prefix):
    if text.startswith(prefix):
        return text[len(prefix):]
    return text


def get_results(endpoint_url, query):
    user_agent = "WDQS-example Python/%s.%s" % (sys.version_info[0], sys.version_info[1])
    # TODO adjust user agent; see https://w.wiki/CX6
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()


def get_name(id: str):
    query = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 	
                PREFIX wd: <http://www.wikidata.org/entity/> 	
                select  *	
                where {	
                wd:""" + id + """ rdfs:label ?label .	
                FILTER (langMatches( lang(?label), "EN" ) )	
                } 	
                LIMIT 1"""
    results = get_results(endpoint_url, query)
    result = ''
    for res in results["results"]["bindings"]:
        result = res['label']['value']
    return result
# Out:
# Requirement already satisfied: SPARQLWrapper in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (1.8.5)
# Requirement already satisfied: rdflib>=4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from SPARQLWrapper) (5.0.0)
# Requirement already satisfied: pyparsing in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper) (2.4.6)
# Requirement already satisfied: isodate in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper) (0.6.0)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper) (1.14.0)
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3 -m pip install --upgrade pip' command.

# %%
import random

# %%
r = createRelation("Q1137809")
r.extend('P31',True, 'Courthouse', limit=10, label=True)
r.changeFocus('Courthouse_P31')
r.extend('P17',False, 'Country')
r.query()
r.df
# Out:
#                                  Entity ID  \
# 0  http://www.wikidata.org/entity/Q1137809
# 1  http://www.wikidata.org/entity/Q1137809
# 2  http://www.wikidata.org/entity/Q1137809
# 3  http://www.wikidata.org/entity/Q1137809
# 4  http://www.wikidata.org/entity/Q1137809
# 5  http://www.wikidata.org/entity/Q1137809
# 6  http://www.wikidata.org/entity/Q1137809
# 7  http://www.wikidata.org/entity/Q1137809
# 8  http://www.wikidata.org/entity/Q1137809
# 9  http://www.wikidata.org/entity/Q1137809
#
#                             Courthouse_P31  \
# 0  http://www.wikidata.org/entity/Q7863296
# 1  http://www.wikidata.org/entity/Q7863297
# 2  http://www.wikidata.org/entity/Q7889666
# 3  http://www.wikidata.org/entity/Q7889667
# 4  http://www.wikidata.org/entity/Q7889682
# 5  http://www.wikidata.org/entity/Q7889683
# 6  http://www.wikidata.org/entity/Q7889685
# 7  http://www.wikidata.org/entity/Q7889703
# 8  http://www.wikidata.org/entity/Q7889714
# 9  http://www.wikidata.org/entity/Q7891082
#
#                         Courthouse_P31Label  \
# 0           U.S. Post Office and Courthouse
# 1           U.S. Post Office and Courthouse
# 2                 United States Court House
# 3                 United States Court House
# 4                  United States Courthouse
# 5                  United States Courthouse
# 6                  United States Courthouse
# 7                 United States Customhouse
# 8                 United States Customhouse
# 9  United States Post Office and Courthouse
#
#                           Country_P17
# 0  http://www.wikidata.org/entity/Q30
# 1  http://www.wikidata.org/entity/Q30
# 2  http://www.wikidata.org/entity/Q30
# 3  http://www.wikidata.org/entity/Q30
# 4  http://www.wikidata.org/entity/Q30
# 5  http://www.wikidata.org/entity/Q30
# 6  http://www.wikidata.org/entity/Q30
# 7  http://www.wikidata.org/entity/Q30
# 8  http://www.wikidata.org/entity/Q30
# 9  http://www.wikidata.org/entity/Q30

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.9.2)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from beautifulsoup4) (2.0.1)
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Government buildings in the US

# %%
gov_building_class = 'Gov_Building'
qnum = 'Q16831714' # qnum of government building
r = createRelation(qnum, label=True)
r.extend('P31', True, gov_building_class, label=True, subclass=True) # extend via property P279 = is subclass of
r.changeFocus('Gov_Building_P31')
r.extend('P17', False, 'Country',label=True, search="Q30")
r.query()
r.df
# Out:
#                                      Entity ID  \
# 0     http://www.wikidata.org/entity/Q16831714
# 1     http://www.wikidata.org/entity/Q16831714
# 2     http://www.wikidata.org/entity/Q16831714
# 3     http://www.wikidata.org/entity/Q16831714
# 4     http://www.wikidata.org/entity/Q16831714
# ...                                        ...
# 3866  http://www.wikidata.org/entity/Q16831714
# 3867  http://www.wikidata.org/entity/Q16831714
# 3868  http://www.wikidata.org/entity/Q16831714
# 3869  http://www.wikidata.org/entity/Q16831714
# 3870  http://www.wikidata.org/entity/Q16831714
#
#                               Gov_Building_P31  \
# 0     http://www.wikidata.org/entity/Q16891643
# 1     http://www.wikidata.org/entity/Q16892091
# 2     http://www.wikidata.org/entity/Q16892539
# 3     http://www.wikidata.org/entity/Q16894060
# 4     http://www.wikidata.org/entity/Q16895259
# ...                                        ...
# 3866   http://www.wikidata.org/entity/Q5488071
# 3867   http://www.wikidata.org/entity/Q6825074
# 3868   http://www.wikidata.org/entity/Q4325144
# 3869  http://www.wikidata.org/entity/Q91468230
# 3870   http://www.wikidata.org/entity/Q4644731
#
#                                   Gov_Building_P31Label  \
# 0                                        Gib Lewis Unit
# 1                                  Hancock State Prison
# 2                   Huerfano County Courthouse and Jail
# 3                        Lea County Correctional Center
# 4                           Moberly Correctional Center
# ...                                                 ...
# 3866  Frank M. Johnson, Jr., Federal Building and Un...
# 3867         Metropolitan Detention Center, Los Angeles
# 3868                                         New Russia
# 3869                        Matagorda County Courthouse
# 3870            83rd Precinct Police Station and Stable
#
#                              Country_P17          Country_P17Label
# 0     http://www.wikidata.org/entity/Q30  United States of America
# 1     http://www.wikidata.org/entity/Q30  United States of America
# 2     http://www.wikidata.org/entity/Q30  United States of America
# 3     http://www.wikidata.org/entity/Q30  United States of America
# 4     http://www.wikidata.org/entity/Q30  United States of America
# ...                                  ...                       ...
# 3866  http://www.wikidata.org/entity/Q30  United States of America
# 3867  http://www.wikidata.org/entity/Q30  United States of America
# 3868  http://www.wikidata.org/entity/Q30  United States of America
# 3869  http://www.wikidata.org/entity/Q30  United States of America
# 3870  http://www.wikidata.org/entity/Q30  United States of America
#
# [3871 rows x 5 columns]

# %%
random.seed(100)
random_indices = random.sample(list(r.df.index), 500)
for ind in random_indices:
    print(r.df.Gov_Building_P31[ind], '\t', r.df.Gov_Building_P31Label[ind])
# Out:
# http://www.wikidata.org/entity/Q28446385 	 Big Muddy River Correctional Center
# http://www.wikidata.org/entity/Q30624657 	 Grey Eagle Village Hall
# http://www.wikidata.org/entity/Q96694097 	 Houghton Masonic Temple Building
# http://www.wikidata.org/entity/Q14689588 	 Hodgeman County Courthouse
# http://www.wikidata.org/entity/Q7338733 	 Riverview Correctional Facility
# http://www.wikidata.org/entity/Q7443606 	 Second Tompkins County Courthouse
# http://www.wikidata.org/entity/Q1340072 	 Metropolitan Correctional Center, San Diego
# http://www.wikidata.org/entity/Q6163932 	 Jasper County Courthouse
# http://www.wikidata.org/entity/Q4746049 	 Amherst Town Hall
# http://www.wikidata.org/entity/Q7797658 	 Three Nations Crossing
# http://www.wikidata.org/entity/Q7891079 	 United States Post Office and Court House
# http://www.wikidata.org/entity/Q16199079 	 Allendale County Courthouse
# http://www.wikidata.org/entity/Q28206745 	 Howard R. Young Correctional Institution
# http://www.wikidata.org/entity/Q56278651 	 Dickens County Courthouse and Jail
# http://www.wikidata.org/entity/Q28446259 	 Rio Grande Detention Center
# http://www.wikidata.org/entity/Q16991665 	 Delta Correctional Facility
# http://www.wikidata.org/entity/Q29641509 	 Durward G. Hall Federal Building and United States Courthouse
# http://www.wikidata.org/entity/Q99744419 	 Harpers Ferry Town Hall
# http://www.wikidata.org/entity/Q5440147 	 Federal Correctional Institution, Schuylkill
# http://www.wikidata.org/entity/Q5526247 	 Garza West Unit
# http://www.wikidata.org/entity/Q5301363 	 Douglas County Courthouse
# http://www.wikidata.org/entity/Q98033940 	 Red River Parish Courthouse
# http://www.wikidata.org/entity/Q5559308 	 Gibson County Courthouse
# http://www.wikidata.org/entity/Q7889712 	 United States Customhouse
# http://www.wikidata.org/entity/Q4811096 	 Astoria City Hall
# http://www.wikidata.org/entity/Q5135129 	 Cloquet City Hall
# http://www.wikidata.org/entity/Q7089413 	 Omaha City Hall
# http://www.wikidata.org/entity/Q28102730 	 Codington County Courthouse
# http://www.wikidata.org/entity/Q14712154 	 Charlotte County Courthouse
# http://www.wikidata.org/entity/Q7889710 	 United States Customhouse
# http://www.wikidata.org/entity/Q5196500 	 Customs House
# http://www.wikidata.org/entity/Q28446755 	 Southern Desert Correctional Center
# http://www.wikidata.org/entity/Q4791414 	 Arizona State Prison Complex – Lewis
# http://www.wikidata.org/entity/Q55637426 	 Warren County Courthouse
# http://www.wikidata.org/entity/Q4804910 	 Asheville City Hall
# http://www.wikidata.org/entity/Q16902741 	 Village of Davis Junction Town Hall
# http://www.wikidata.org/entity/Q7138293 	 Coryell County Courthouse
# http://www.wikidata.org/entity/Q28006205 	 St. Joseph City Hall
# http://www.wikidata.org/entity/Q20707130 	 Monroe County Courthouse
# http://www.wikidata.org/entity/Q7972269 	 Washington State Penitentiary
# http://www.wikidata.org/entity/Q18158052 	 Siler City City Hall
# http://www.wikidata.org/entity/Q48837333 	 Big Creek Schoolhouse
# http://www.wikidata.org/entity/Q18706137 	 Fryeburg Registry of Deeds
# http://www.wikidata.org/entity/Q85678037 	 Cotulla Unit
# http://www.wikidata.org/entity/Q65042346 	 Platte County Courthouse
# http://www.wikidata.org/entity/Q16890077 	 Calhoun County Courthouse
# http://www.wikidata.org/entity/Q18385386 	 Old Minnehaha County Courthouse
# http://www.wikidata.org/entity/Q14714886 	 Deep River Town Hall
# http://www.wikidata.org/entity/Q7491220 	 Shawangunk Correctional Facility
# http://www.wikidata.org/entity/Q48790163 	 Burlington County Courthouse
# http://www.wikidata.org/entity/Q5508417 	 Fulton County Courthouse
# http://www.wikidata.org/entity/Q5336642 	 Eddy County Courthouse
# http://www.wikidata.org/entity/Q27621435 	 Old Police Headquarters
# http://www.wikidata.org/entity/Q3050471 	 Elayn Hunt Correctional Center
# http://www.wikidata.org/entity/Q16895958 	 North Fork Correctional Facility
# http://www.wikidata.org/entity/Q5096193 	 Chickasaw County Courthouse
# http://www.wikidata.org/entity/Q8564089 	 Flushing Town Hall
# http://www.wikidata.org/entity/Q28446546 	 Ridgeland Correctional Institution
# http://www.wikidata.org/entity/Q14705303 	 Washoe County Courthouse
# http://www.wikidata.org/entity/Q24693691 	 Kennebec County Courthouse
# http://www.wikidata.org/entity/Q6940240 	 Muscatine County Courthouse
# http://www.wikidata.org/entity/Q7598646 	 Standish Maximum Correctional Facility
# http://www.wikidata.org/entity/Q4874114 	 Bay State Correctional Center
# http://www.wikidata.org/entity/Q7261209 	 Purgatory Correctional Facility
# http://www.wikidata.org/entity/Q23017147 	 Old Perry County Courthouse
# http://www.wikidata.org/entity/Q14714686 	 Clearmont Jail
# http://www.wikidata.org/entity/Q60789037 	 Perry County Courthouse
# http://www.wikidata.org/entity/Q1142661 	 Alcatraz Federal Penitentiary
# http://www.wikidata.org/entity/Q5123199 	 City Hall of University City, Missouri
# http://www.wikidata.org/entity/Q24190602 	 Willow Creek Border Crossing
# http://www.wikidata.org/entity/Q16163418 	 Bacon County Courthouse
# http://www.wikidata.org/entity/Q5439007 	 Fayette County Courthouse
# http://www.wikidata.org/entity/Q65067010 	 Cass County Courthouse
# http://www.wikidata.org/entity/Q64877556 	 Elmore County Courthouse
# http://www.wikidata.org/entity/Q7969258 	 Ware Town Hall
# http://www.wikidata.org/entity/Q26831348 	 Diboll Unit
# http://www.wikidata.org/entity/Q7351997 	 Roberts County Courthouse
# http://www.wikidata.org/entity/Q1915348 	 McPherson County Courthouse
# http://www.wikidata.org/entity/Q14712125 	 Campbell County Courthouse
# http://www.wikidata.org/entity/Q5440470 	 Federal Transfer Center, Oklahoma City
# http://www.wikidata.org/entity/Q5131026 	 Cleburne County Courthouse
# http://www.wikidata.org/entity/Q7890873 	 United States Penitentiary, Atwater
# http://www.wikidata.org/entity/Q6268249 	 Johnson County Courthouse
# http://www.wikidata.org/entity/Q7396542 	 Sac County Courthouse
# http://www.wikidata.org/entity/Q14705973 	 De Baca County Courthouse
# http://www.wikidata.org/entity/Q7964718 	 Walter E. Hoffman United States Courthouse
# http://www.wikidata.org/entity/Q5602133 	 Greeley County Courthouse
# http://www.wikidata.org/entity/Q5457876 	 Flatbush Town Hall
# http://www.wikidata.org/entity/Q7971761 	 Washington County Courthouse
# http://www.wikidata.org/entity/Q4949927 	 Boundary County Courthouse
# http://www.wikidata.org/entity/Q3694507 	 New Mexico State Capitol
# http://www.wikidata.org/entity/Q14714292 	 Old Court House
# http://www.wikidata.org/entity/Q5026956 	 Camp Albuquerque
# http://www.wikidata.org/entity/Q4838521 	 Babylon Town Hall
# http://www.wikidata.org/entity/Q5501970 	 French ambassador's residence in Washington, D.C.
# http://www.wikidata.org/entity/Q48838485 	 Osage County Courthouse
# http://www.wikidata.org/entity/Q17184210 	 Wilton Town Hall Theatre
# http://www.wikidata.org/entity/Q7559967 	 Somerset County Court House complex
# http://www.wikidata.org/entity/Q18152916 	 Kensington Town House
# http://www.wikidata.org/entity/Q14692664 	 Isanti County Courthouse
# http://www.wikidata.org/entity/Q16971257 	 Baltimore City Detention Center
# http://www.wikidata.org/entity/Q16962806 	 Drew County Courthouse
# http://www.wikidata.org/entity/Q6911620 	 Morgan County Correctional Complex
# http://www.wikidata.org/entity/Q55605598 	 Bledsoe County Courthouse
# http://www.wikidata.org/entity/Q6815534 	 Memorial Town Hall
# http://www.wikidata.org/entity/Q5149673 	 Columbia County Courthouse
# http://www.wikidata.org/entity/Q14707515 	 Trout River Border Crossing
# http://www.wikidata.org/entity/Q5440349 	 Federal Prison Camp, Yankton
# http://www.wikidata.org/entity/Q5084110 	 Charleston City Hall
# http://www.wikidata.org/entity/Q25006866 	 Old McDonald County Courthouse
# http://www.wikidata.org/entity/Q18153573 	 Lexington County Courthouse
# http://www.wikidata.org/entity/Q65072573 	 Third Sarpy County Courthouse
# http://www.wikidata.org/entity/Q7989281 	 Westmoreland County Courthouse
# http://www.wikidata.org/entity/Q6468688 	 Lackawanna County Courthouse
# http://www.wikidata.org/entity/Q5351761 	 El Paso BOTA Port of Entry
# http://www.wikidata.org/entity/Q14685086 	 Sedgwick County Courthouse
# http://www.wikidata.org/entity/Q54874615 	 Green Lake County Courthouse
# http://www.wikidata.org/entity/Q14714652 	 Waushara County Courthouse, Waushara County Sheriff's Residence and Jail
# http://www.wikidata.org/entity/Q15268624 	 Prince William County Courthouse
# http://www.wikidata.org/entity/Q7084281 	 Old Isle of Wight Courthouse
# http://www.wikidata.org/entity/Q60789043 	 Calhoun County Courthouse
# http://www.wikidata.org/entity/Q6939183 	 Murray County Courthouse
# http://www.wikidata.org/entity/Q5440097 	 Federal Correctional Institution, Bastrop
# http://www.wikidata.org/entity/Q28446484 	 Hardee Correctional Institution
# http://www.wikidata.org/entity/Q17035346 	 Skyline Correctional Center
# http://www.wikidata.org/entity/Q1503389 	 United States Post Office
# http://www.wikidata.org/entity/Q7083674 	 Old Citrus County Courthouse
# http://www.wikidata.org/entity/Q38251412 	 Glacier County Courthouse
# http://www.wikidata.org/entity/Q55606713 	 Casa San Diego
# http://www.wikidata.org/entity/Q7209514 	 Police Station No. 3
# http://www.wikidata.org/entity/Q5147364 	 Collins Correctional Facility
# http://www.wikidata.org/entity/Q26441325 	 Supreme Court of South Carolina Building
# http://www.wikidata.org/entity/Q85678031 	 Bradshaw Unit
# http://www.wikidata.org/entity/Q7495149 	 Sherman County Courthouse
# http://www.wikidata.org/entity/Q7636402 	 Sullivan County Courthouse
# http://www.wikidata.org/entity/Q28446236 	 Phillips State Prison
# http://www.wikidata.org/entity/Q5773486 	 Historic Fairfax County Courthouse
# http://www.wikidata.org/entity/Q5027110 	 Camp Cusino
# http://www.wikidata.org/entity/Q16890530 	 Colbert County Courthouse
# http://www.wikidata.org/entity/Q4884344 	 Belmont County Courthouse
# http://www.wikidata.org/entity/Q55623649 	 Monroe County Courthouse
# http://www.wikidata.org/entity/Q8032392 	 Woodbourne Correctional Facility
# http://www.wikidata.org/entity/Q54952610 	 Manitowoc County Courthouse
# http://www.wikidata.org/entity/Q6411384 	 King County Courthouse
# http://www.wikidata.org/entity/Q14716560 	 Justice Center Complex
# http://www.wikidata.org/entity/Q7084736 	 Old Pinellas County Courthouse
# http://www.wikidata.org/entity/Q8030875 	 Women's Eastern Reception, Diagnostic and Correctional Center
# http://www.wikidata.org/entity/Q5149354 	 Colquitt County Courthouse
# http://www.wikidata.org/entity/Q16903022 	 Wayne County Courthouse
# http://www.wikidata.org/entity/Q28007735 	 Carroll County Court House
# http://www.wikidata.org/entity/Q5742205 	 Hernando County Courthouse
# http://www.wikidata.org/entity/Q7084177 	 Old Harrison County Courthouse
# http://www.wikidata.org/entity/Q14685737 	 Old Town Hall
# http://www.wikidata.org/entity/Q4666903 	 Aberdeen City Hall
# http://www.wikidata.org/entity/Q48790976 	 Soda Springs City Hall
# http://www.wikidata.org/entity/Q16858683 	 Central New Mexico Correctional Facility
# http://www.wikidata.org/entity/Q7971760 	 Washington County Courthouse
# http://www.wikidata.org/entity/Q26831363 	 Otero County Prison Facility
# http://www.wikidata.org/entity/Q60747827 	 Brigham City Fire Station/City Hall
# http://www.wikidata.org/entity/Q5354019 	 Eldon B. Mahon United States Courthouse
# http://www.wikidata.org/entity/Q19462609 	 Jefferson County Courthouse
# http://www.wikidata.org/entity/Q14683393 	 Monterey County Court House
# http://www.wikidata.org/entity/Q28124291 	 Chattahoochee County Jail
# http://www.wikidata.org/entity/Q5766211 	 Hinds County Courthouse
# http://www.wikidata.org/entity/Q4884791 	 Beltrami County Courthouse
# http://www.wikidata.org/entity/Q4791413 	 Arizona State Prison Complex – Florence
# http://www.wikidata.org/entity/Q5491392 	 Franklin County Correctional Facility II
# http://www.wikidata.org/entity/Q7546743 	 Smyrna Town Hall-Opera House
# http://www.wikidata.org/entity/Q6471393 	 Lafayette County Courthouse
# http://www.wikidata.org/entity/Q6758570 	 Marcy Correctional Facility
# http://www.wikidata.org/entity/Q20741690 	 Elgin Opera House
# http://www.wikidata.org/entity/Q5259599 	 Denton County Courthouse-on-the-Square
# http://www.wikidata.org/entity/Q5647031 	 Hancock County Courthouse
# http://www.wikidata.org/entity/Q28446428 	 Ojibway Correctional Facility
# http://www.wikidata.org/entity/Q7231608 	 Porter County Courthouse
# http://www.wikidata.org/entity/Q5228067 	 Dauphin County Courthouse
# http://www.wikidata.org/entity/Q5244096 	 DeSoto County Courthouse
# http://www.wikidata.org/entity/Q28123620 	 School House and Town Hall
# http://www.wikidata.org/entity/Q1866507 	 Livingston County Courthouse
# http://www.wikidata.org/entity/Q5460712 	 Florence McClure Women's Correctional Center
# http://www.wikidata.org/entity/Q7913181 	 Van Buren County Courthouse
# http://www.wikidata.org/entity/Q27068096 	 Norton U.S. Inspection Station
# http://www.wikidata.org/entity/Q7492123 	 Shea Farm Halfway House
# http://www.wikidata.org/entity/Q5592740 	 Graham Correctional Center
# http://www.wikidata.org/entity/Q16895057 	 Merrimack County Courthouse
# http://www.wikidata.org/entity/Q60667261 	 Old Grants Pass City Hall
# http://www.wikidata.org/entity/Q48815112 	 Kingsbury County Courthouse
# http://www.wikidata.org/entity/Q14686163 	 Madison County Courthouse
# http://www.wikidata.org/entity/Q5311173 	 Dubuque County Jail
# http://www.wikidata.org/entity/Q2068997 	 Alexander Hamilton U.S. Custom House
# http://www.wikidata.org/entity/Q1400021 	 Federal Correctional Institution, Loretto
# http://www.wikidata.org/entity/Q7338088 	 Riverbend Maximum Security Institution
# http://www.wikidata.org/entity/Q5641112 	 Halawa Correctional Facility
# http://www.wikidata.org/entity/Q98098849 	 Republic County Courthouse
# http://www.wikidata.org/entity/Q28446724 	 Guerrero Correctional Institution
# http://www.wikidata.org/entity/Q7603160 	 State Correctional Institution – Smithfield
# http://www.wikidata.org/entity/Q5211300 	 Dallas County Courthouse
# http://www.wikidata.org/entity/Q6709642 	 Lyon Mountain Correctional Facility
# http://www.wikidata.org/entity/Q27812857 	 Penny Lane
# http://www.wikidata.org/entity/Q5440154 	 Federal Correctional Institution, Three Rivers
# http://www.wikidata.org/entity/Q17284401 	 Dade Correctional Institution
# http://www.wikidata.org/entity/Q7922099 	 Vernon County Courthouse
# http://www.wikidata.org/entity/Q23303008 	 Peoria Federal Building and U.S. Courthouse
# http://www.wikidata.org/entity/Q22059322 	 University of Southern Maine Art Gallery
# http://www.wikidata.org/entity/Q5140908 	 Coffee Creek Correctional Facility
# http://www.wikidata.org/entity/Q18240988 	 Allegheny County Jail
# http://www.wikidata.org/entity/Q642270 	 United States Disciplinary Barracks
# http://www.wikidata.org/entity/Q60742304 	 Goshen Town Hall
# http://www.wikidata.org/entity/Q24191180 	 Thousand Islands Border Crossing
# http://www.wikidata.org/entity/Q16896137 	 Old State Capitol
# http://www.wikidata.org/entity/Q8002505 	 Wilkin County Courthouse
# http://www.wikidata.org/entity/Q28153729 	 Dubuque City Hall
# http://www.wikidata.org/entity/Q14712379 	 Goochland County Court Square
# http://www.wikidata.org/entity/Q1141887 	 Allan B. Polunsky Unit
# http://www.wikidata.org/entity/Q5002599 	 Butler County Courthouse
# http://www.wikidata.org/entity/Q6913658 	 Morris County Courthouse
# http://www.wikidata.org/entity/Q30601833 	 Johnson County Courthouse
# http://www.wikidata.org/entity/Q5440132 	 Federal Correctional Institution, Mendota
# http://www.wikidata.org/entity/Q4778428 	 Anzalduas Port of Entry
# http://www.wikidata.org/entity/Q28446354 	 Baker Correctional Institution
# http://www.wikidata.org/entity/Q19864072 	 Cerro Gordo County Courthouse
# http://www.wikidata.org/entity/Q2313790 	 Spring Creek Correctional Center
# http://www.wikidata.org/entity/Q28006161 	 Adair County Courthouse
# http://www.wikidata.org/entity/Q18154630 	 Morehead City Municipal Building
# http://www.wikidata.org/entity/Q18155362 	 Old Bedford County Jail
# http://www.wikidata.org/entity/Q5087641 	 Chatham County Courthouse
# http://www.wikidata.org/entity/Q43371270 	 Granite County Jail
# http://www.wikidata.org/entity/Q22073862 	 North Town Hall
# http://www.wikidata.org/entity/Q25206335 	 Hamilton County Courthouse
# http://www.wikidata.org/entity/Q5440139 	 Federal Correctional Institution, Pekin
# http://www.wikidata.org/entity/Q22034010 	 Elkhart County Courthouse
# http://www.wikidata.org/entity/Q6117036 	 Jackson County Courthouse
# http://www.wikidata.org/entity/Q6117045 	 Jackson County Jail
# http://www.wikidata.org/entity/Q12203187 	 Lowell Correctional Institution
# http://www.wikidata.org/entity/Q4914240 	 Binghamton City Hall
# http://www.wikidata.org/entity/Q5440138 	 Federal Correctional Institution, Oxford
# http://www.wikidata.org/entity/Q7157225 	 Peabody City Hall
# http://www.wikidata.org/entity/Q85678103 	 Moore, B. Unit
# http://www.wikidata.org/entity/Q16892244 	 Hermitage City Hall and Jail
# http://www.wikidata.org/entity/Q54871441 	 Jack County Courthouse
# http://www.wikidata.org/entity/Q16162105 	 Atkinson County Courthouse
# http://www.wikidata.org/entity/Q5604880 	 Greenwich Town Hall
# http://www.wikidata.org/entity/Q5193875 	 Cumberland County Jail
# http://www.wikidata.org/entity/Q14688745 	 Plainfield Correctional Facility
# http://www.wikidata.org/entity/Q18148840 	 Caswell County Courthouse
# http://www.wikidata.org/entity/Q17028638 	 Frank M. Scarlett Federal Building
# http://www.wikidata.org/entity/Q7083691 	 Old City Hall
# http://www.wikidata.org/entity/Q4967727 	 Brighton Town Hall
# http://www.wikidata.org/entity/Q27957570 	 Waterville Opera House and City Hall
# http://www.wikidata.org/entity/Q16896138 	 Old Jail (Washington, Georgia)
# http://www.wikidata.org/entity/Q5251534 	 Defiance County Courthouse
# http://www.wikidata.org/entity/Q18706170 	 North Durham County Prison Camp
# http://www.wikidata.org/entity/Q7692918 	 Tecumseh State Correctional Institution
# http://www.wikidata.org/entity/Q6936200 	 Municipal Building
# http://www.wikidata.org/entity/Q5501569 	 Fremont County Courthouse
# http://www.wikidata.org/entity/Q5182846 	 Crawford County Courthouse
# http://www.wikidata.org/entity/Q6275179 	 Jones County Courthouse
# http://www.wikidata.org/entity/Q75371269 	 U.S. Inspection Station--Beebe Plain, Vermont
# http://www.wikidata.org/entity/Q14690880 	 Luther Luckett Correctional Complex
# http://www.wikidata.org/entity/Q48837650 	 Cape May County Courthouse
# http://www.wikidata.org/entity/Q7055774 	 North Kern State Prison
# http://www.wikidata.org/entity/Q16965198 	 Macon County Courthouse
# http://www.wikidata.org/entity/Q7082176 	 Oklahoma County Courthouse
# http://www.wikidata.org/entity/Q2570396 	 Tennessee State Capitol
# http://www.wikidata.org/entity/Q1683354 	 Nebraska State Capitol
# http://www.wikidata.org/entity/Q4721975 	 Alfonse M. D'Amato United States Courthouse
# http://www.wikidata.org/entity/Q24061467 	 Sarles–Crystal City Border Crossing
# http://www.wikidata.org/entity/Q5044590 	 Carol Vance Unit
# http://www.wikidata.org/entity/Q6360801 	 Kanawha County Courthouse
# http://www.wikidata.org/entity/Q14688972 	 Hardin County Courthouse
# http://www.wikidata.org/entity/Q4791422 	 Arizona State Prison Phoenix-West
# http://www.wikidata.org/entity/Q6144540 	 James V. Allred Unit
# http://www.wikidata.org/entity/Q15844969 	 Joseph Harp Correctional Center
# http://www.wikidata.org/entity/Q7650563 	 Suwannee County Courthouse
# http://www.wikidata.org/entity/Q7194575 	 Pima County Courthouse
# http://www.wikidata.org/entity/Q38252131 	 Pulaski County Courthouse
# http://www.wikidata.org/entity/Q4833123 	 Azusa Civic Center
# http://www.wikidata.org/entity/Q28006171 	 Andrew County Courthouse
# http://www.wikidata.org/entity/Q14716401 	 Delaware County Courthouse
# http://www.wikidata.org/entity/Q5169463 	 Coral Gables Police and Fire Station
# http://www.wikidata.org/entity/Q28446550 	 Toledo Correctional Institution
# http://www.wikidata.org/entity/Q7587363 	 St. Brides Correctional Center
# http://www.wikidata.org/entity/Q8037159 	 Worth County Courthouse
# http://www.wikidata.org/entity/Q16894458 	 Madison County Sheriff's House and Jail
# http://www.wikidata.org/entity/Q5440091 	 Federal Correctional Complex, Victorville
# http://www.wikidata.org/entity/Q18158200 	 Somerville Courthouse
# http://www.wikidata.org/entity/Q16891208 	 Farquhar Cattle Ranch
# http://www.wikidata.org/entity/Q7856684 	 Tuscarawas County Courthouse
# http://www.wikidata.org/entity/Q1156778 	 Manhattan Municipal Building
# http://www.wikidata.org/entity/Q7976137 	 Wayne County Building
# http://www.wikidata.org/entity/Q18706135 	 Former Otisfield Town House
# http://www.wikidata.org/entity/Q7603145 	 State Correctional Institution – Fayette
# http://www.wikidata.org/entity/Q8034018 	 Woonsocket City Hall
# http://www.wikidata.org/entity/Q7681706 	 Tampa City Hall
# http://www.wikidata.org/entity/Q6173681 	 Jeff Davis County Courthouse
# http://www.wikidata.org/entity/Q24190330 	 Whitlash-Aden Border Crossing
# http://www.wikidata.org/entity/Q912407 	 San Quentin State Prison
# http://www.wikidata.org/entity/Q7971781 	 Washington County Jail and Sheriff's Residence
# http://www.wikidata.org/entity/Q64877741 	 Fillmore County Courthouse
# http://www.wikidata.org/entity/Q4999659 	 Burnet County Courthouse
# http://www.wikidata.org/entity/Q19987495 	 Pender County Courthouse
# http://www.wikidata.org/entity/Q6765139 	 Marion County Courthouse
# http://www.wikidata.org/entity/Q7085084 	 Old State House
# http://www.wikidata.org/entity/Q85678070 	 Hospital Galveston Unit
# http://www.wikidata.org/entity/Q20741771 	 Saginaw Correctional Facility
# http://www.wikidata.org/entity/Q7099555 	 Orange County Courthouse
# http://www.wikidata.org/entity/Q5560674 	 Gila River War Relocation Center
# http://www.wikidata.org/entity/Q7228357 	 Pontotoc County Courthouse
# http://www.wikidata.org/entity/Q55612003 	 Franklin County Courthouse and Jail
# http://www.wikidata.org/entity/Q28446547 	 McCormick Correctional Institution
# http://www.wikidata.org/entity/Q65118996 	 Henderson County Courthouse
# http://www.wikidata.org/entity/Q7083515 	 Old Bradford County Courthouse
# http://www.wikidata.org/entity/Q38252210 	 Jefferson County Courthouse
# http://www.wikidata.org/entity/Q6906478 	 Montrose County Courthouse
# http://www.wikidata.org/entity/Q6781282 	 Maryland Circuit Courts
# http://www.wikidata.org/entity/Q27957513 	 Steuben County Jail
# http://www.wikidata.org/entity/Q64864973 	 Scotts Bluff County Courthouse
# http://www.wikidata.org/entity/Q7085285 	 Old Town Hall
# http://www.wikidata.org/entity/Q23302852 	 Newton County Jail
# http://www.wikidata.org/entity/Q28543714 	 Lawrence County Courthouse
# http://www.wikidata.org/entity/Q28206794 	 Mid-State Correctional Facility
# http://www.wikidata.org/entity/Q7008511 	 New Haven County Courthouse
# http://www.wikidata.org/entity/Q7106368 	 Osceola County Courthouse
# http://www.wikidata.org/entity/Q7858281 	 Twin Rivers Corrections Center
# http://www.wikidata.org/entity/Q55627443 	 Old Morris County Courthouse
# http://www.wikidata.org/entity/Q985484 	 Manzanar
# http://www.wikidata.org/entity/Q17986157 	 Buncombe County Courthouse
# http://www.wikidata.org/entity/Q29097572 	 Mountain Grove City Hall
# http://www.wikidata.org/entity/Q7414758 	 San Luis Port of Entry
# http://www.wikidata.org/entity/Q6393026 	 Keokuk County Courthouse
# http://www.wikidata.org/entity/Q2817266 	 Fresno City Hall
# http://www.wikidata.org/entity/Q29641980 	 Pulaski County Courthouse
# http://www.wikidata.org/entity/Q6456321 	 L.V. Hightower Unit
# http://www.wikidata.org/entity/Q22058516 	 Montgomery Women's Facility
# http://www.wikidata.org/entity/Q5178529 	 Courthouse and Jail Rocks
# http://www.wikidata.org/entity/Q23074171 	 Sherwood–Carievale Border Crossing
# http://www.wikidata.org/entity/Q4712966 	 Alcatraz Citadel
# http://www.wikidata.org/entity/Q14689267 	 North Central Correctional Facility
# http://www.wikidata.org/entity/Q5759013 	 Highland Park Police Station
# http://www.wikidata.org/entity/Q7567964 	 South Mississippi Correctional Institution
# http://www.wikidata.org/entity/Q7824771 	 Topaz War Relocation Center
# http://www.wikidata.org/entity/Q26849242 	 Bledsoe County Correctional Complex
# http://www.wikidata.org/entity/Q7971762 	 Washington County Courthouse
# http://www.wikidata.org/entity/Q6460980 	 LaVista Correctional Facility
# http://www.wikidata.org/entity/Q7083686 	 Old City Hall
# http://www.wikidata.org/entity/Q43371267 	 Elk County Courthouse
# http://www.wikidata.org/entity/Q4854518 	 Bandera County Courthouse and Jail
# http://www.wikidata.org/entity/Q6868208 	 Minnesota Correctional Facility – Willow River/Moose Lake
# http://www.wikidata.org/entity/Q1626056 	 Pitkin County Courthouse
# http://www.wikidata.org/entity/Q6843993 	 Mifflin County Courthouse
# http://www.wikidata.org/entity/Q20710112 	 Wayne County Courthouse
# http://www.wikidata.org/entity/Q64788717 	 Hall County Courthouse
# http://www.wikidata.org/entity/Q28446728 	 Stanley Correctional Institution
# http://www.wikidata.org/entity/Q14704961 	 Morrill County Courthouse
# http://www.wikidata.org/entity/Q3355048 	 Orange County Courthouse
# http://www.wikidata.org/entity/Q7045712 	 Noble County Courthouse
# http://www.wikidata.org/entity/Q28446548 	 Belmont Correctional Institution
# http://www.wikidata.org/entity/Q7181262 	 Phelps County Jail
# http://www.wikidata.org/entity/Q17104999 	 Wakefield Town Hall and Opera House
# http://www.wikidata.org/entity/Q5440042 	 Federal Building and United States Courthouse
# http://www.wikidata.org/entity/Q6914204 	 Morrow County Courthouse
# http://www.wikidata.org/entity/Q7855967 	 Turner Town House
# http://www.wikidata.org/entity/Q5944689 	 Hunterdon County Courthouse
# http://www.wikidata.org/entity/Q6486174 	 Langlade County Courthouse
# http://www.wikidata.org/entity/Q85764705 	 Guadalupe County Courthouse in Santa Rosa
# http://www.wikidata.org/entity/Q5433975 	 Fannin County Courthouse
# http://www.wikidata.org/entity/Q23302737 	 Jackson County Courthouse
# http://www.wikidata.org/entity/Q7629181 	 Stutsman County Courthouse and Sheriff's Residence/Jail
# http://www.wikidata.org/entity/Q44747926 	 Travis County Courthouse
# http://www.wikidata.org/entity/Q368489 	 Los Angeles City Hall
# http://www.wikidata.org/entity/Q28104128 	 Greene Correctional Facility
# http://www.wikidata.org/entity/Q821601 	 Thurgood Marshall United States Courthouse
# http://www.wikidata.org/entity/Q16898768 	 Presque Isle County Courthouse
# http://www.wikidata.org/entity/Q42431581 	 Hogansville City Hall
# http://www.wikidata.org/entity/Q23074178 	 Cleburne County Courthouse
# http://www.wikidata.org/entity/Q85678156 	 Wallace/San Angelo Work Camp Unit
# http://www.wikidata.org/entity/Q7986642 	 West Tennessee State Penitentiary
# http://www.wikidata.org/entity/Q16984158 	 Hillsborough County Registry of Deeds
# http://www.wikidata.org/entity/Q14689789 	 Miami County Courthouse
# http://www.wikidata.org/entity/Q16902499 	 Van Buren County Courthouse
# http://www.wikidata.org/entity/Q99570704 	 Las Vegas Carnegie Public Library
# http://www.wikidata.org/entity/Q5346130 	 Edwards Town Hall
# http://www.wikidata.org/entity/Q5248624 	 Debtors' Prison
# http://www.wikidata.org/entity/Q16894143 	 Liberty County Jail
# http://www.wikidata.org/entity/Q7945221 	 W.J. Estelle Unit
# http://www.wikidata.org/entity/Q7891078 	 United States Post Office and Court House
# http://www.wikidata.org/entity/Q28446268 	 St. Clair Correctional Facility
# http://www.wikidata.org/entity/Q4680319 	 Adams County Courthouse
# http://www.wikidata.org/entity/Q6824714 	 Metro State Prison
# http://www.wikidata.org/entity/Q26831359 	 Gadsden Correctional Facility
# http://www.wikidata.org/entity/Q98959896 	 Garden City City Hall
# http://www.wikidata.org/entity/Q7084481 	 Old Martin County Courthouse
# http://www.wikidata.org/entity/Q5440159 	 Federal Correctional Institution, Williamsburg
# http://www.wikidata.org/entity/Q18159020 	 Winston E. Arnow Federal Building
# http://www.wikidata.org/entity/Q17515020 	 Catalina Federal Honor Camp
# http://www.wikidata.org/entity/Q2985164 	 Maine State House
# http://www.wikidata.org/entity/Q14712375 	 Gloucester County Courthouse Square Historic District
# http://www.wikidata.org/entity/Q65066728 	 Monroe City Hall
# http://www.wikidata.org/entity/Q7889702 	 United States Customhouse
# http://www.wikidata.org/entity/Q5611403 	 Grove Hill Courthouse Square Historic District
# http://www.wikidata.org/entity/Q5589988 	 Gowanda Correctional Facility
# http://www.wikidata.org/entity/Q4974183 	 Bronx County Hall of Justice
# http://www.wikidata.org/entity/Q7890896 	 United States Post Office, Courthouse, and Customhouse
# http://www.wikidata.org/entity/Q5046535 	 Carroll County Courthouse
# http://www.wikidata.org/entity/Q5440098 	 Federal Correctional Institution, Beaumont Low
# http://www.wikidata.org/entity/Q14713014 	 Old Fauquier County Jail
# http://www.wikidata.org/entity/Q4923936 	 Blaine County Courthouse
# http://www.wikidata.org/entity/Q65059293 	 Lassen County Court House
# http://www.wikidata.org/entity/Q14692654 	 Houston County Courthouse and Jail
# http://www.wikidata.org/entity/Q18706139 	 Gates County Courthouse
# http://www.wikidata.org/entity/Q64728858 	 Humphreys County Courthouse
# http://www.wikidata.org/entity/Q23302920 	 Russell Jail
# http://www.wikidata.org/entity/Q7525475 	 Sioux County Courthouse
# http://www.wikidata.org/entity/Q4828377 	 Avery County Courthouse
# http://www.wikidata.org/entity/Q5138321 	 Coastal State Prison
# http://www.wikidata.org/entity/Q6902161 	 Monroe County Courthouse
# http://www.wikidata.org/entity/Q7989414 	 Weston County Courthouse
# http://www.wikidata.org/entity/Q5241975 	 Davis Town Meeting House
# http://www.wikidata.org/entity/Q29643977 	 Mount Pleasant City Hall
# http://www.wikidata.org/entity/Q12060982 	 Kendall County Courthouse
# http://www.wikidata.org/entity/Q16947606 	 Branchville Correctional Facility
# http://www.wikidata.org/entity/Q26831353 	 Kyle Unit
# http://www.wikidata.org/entity/Q7961220 	 Wakulla Correctional Institution
# http://www.wikidata.org/entity/Q15263747 	 Old Cadillac City Hall
# http://www.wikidata.org/entity/Q1658839 	 Illinois State Capitol
# http://www.wikidata.org/entity/Q24062025 	 Hendricks County Jail and Sheriff's Residence
# http://www.wikidata.org/entity/Q7169749 	 Perry County Courthouse
# http://www.wikidata.org/entity/Q7080984 	 Ohio Theatre
# http://www.wikidata.org/entity/Q6391306 	 Kenosha County Courthouse and Jail
# http://www.wikidata.org/entity/Q7016654 	 Newark City Hall
# http://www.wikidata.org/entity/Q7007040 	 New Durham Town Hall
# http://www.wikidata.org/entity/Q7963192 	 Wallowa County Courthouse
# http://www.wikidata.org/entity/Q7415402 	 San Ysidro Port of Entry
# http://www.wikidata.org/entity/Q7108227 	 Oswego County Courthouse
# http://www.wikidata.org/entity/Q5006763 	 C. Paul Phelps Correctional Center
# http://www.wikidata.org/entity/Q38149262 	 Residence of the Australian Ambassador in Washington
# http://www.wikidata.org/entity/Q6933880 	 Mule Creek State Prison
# http://www.wikidata.org/entity/Q7603148 	 State Correctional Institution – Graterford
# http://www.wikidata.org/entity/Q2749733 	 Missouri State Capitol
# http://www.wikidata.org/entity/Q4968881 	 Bristol County Courthouse
# http://www.wikidata.org/entity/Q14704781 	 Teton County Courthouse
# http://www.wikidata.org/entity/Q5134096 	 Clinton County Courthouse
# http://www.wikidata.org/entity/Q7262326 	 Putnam County Courthouse
# http://www.wikidata.org/entity/Q28446821 	 Val Verde Correctional Facility
# http://www.wikidata.org/entity/Q95980561 	 U.S. Inspection Station–Fort Fairfield, Maine
# http://www.wikidata.org/entity/Q5642154 	 Halifax County Courthouse
# http://www.wikidata.org/entity/Q7108476 	 Otay Mesa Port of Entry
# http://www.wikidata.org/entity/Q6837706 	 Michigan State Prison
# http://www.wikidata.org/entity/Q30623287 	 Racine County Courthouse
# http://www.wikidata.org/entity/Q55316804 	 President's House, University of Michigan
# http://www.wikidata.org/entity/Q4887559 	 Benewah County Courthouse
# http://www.wikidata.org/entity/Q7889704 	 United States Customhouse
# http://www.wikidata.org/entity/Q1491417 	 Idaho State Capitol
# http://www.wikidata.org/entity/Q85678040 	 Dominguez Unit
# http://www.wikidata.org/entity/Q28446560 	 Riverbend Correctional Facility
# http://www.wikidata.org/entity/Q5278762 	 Dinwiddie County Court House
# http://www.wikidata.org/entity/Q26902716 	 Florence Correctional Center
# http://www.wikidata.org/entity/Q23074076 	 Fortuna–Oungre Border Crossing
# http://www.wikidata.org/entity/Q14689375 	 Atchison County Courthouse
# http://www.wikidata.org/entity/Q16903207 	 Whiteville Correctional Facility
# http://www.wikidata.org/entity/Q93092543 	 Q93092543
# http://www.wikidata.org/entity/Q7891102 	 United States Post Office and Courthouse
# http://www.wikidata.org/entity/Q7230711 	 Port Isabel Detention Center
# http://www.wikidata.org/entity/Q65120623 	 Hibbing City Hall
# http://www.wikidata.org/entity/Q18205736 	 C.F. Haynsworth Federal Building and United States Courthouse
# http://www.wikidata.org/entity/Q5003136 	 Butts County Courthouse
# http://www.wikidata.org/entity/Q5562496 	 Gilmer County Courthouse
# http://www.wikidata.org/entity/Q5026776 	 Camino Nuevo Correctional Center
# http://www.wikidata.org/entity/Q85788351 	 Nevada County Courthouse
# http://www.wikidata.org/entity/Q48816196 	 Brown County Courthouse
# http://www.wikidata.org/entity/Q2985180 	 Montana State Capitol
# http://www.wikidata.org/entity/Q16889777 	 White County Jail
# http://www.wikidata.org/entity/Q5739254 	 Herkimer County Jail
# http://www.wikidata.org/entity/Q7365198 	 Ronald Reagan Federal Building and Courthouse
# http://www.wikidata.org/entity/Q20738548 	 Earnest C. Brooks Correctional Facility
# http://www.wikidata.org/entity/Q15242902 	 Los Ebanos Port of Entry
# http://www.wikidata.org/entity/Q7501485 	 Shorewood Village Hall
# http://www.wikidata.org/entity/Q7570177 	 Southern Nevada Correctional Center
# http://www.wikidata.org/entity/Q4996972 	 Bulloch County Correctional Institution
# http://www.wikidata.org/entity/Q7414734 	 San Luis II Port of Entry
# http://www.wikidata.org/entity/Q1637388 	 Clinton Correctional Facility
# http://www.wikidata.org/entity/Q7889723 	 United States Customshouse
# http://www.wikidata.org/entity/Q29094695 	 Emanuel County Courthouse and Sheriff Department
# http://www.wikidata.org/entity/Q7890883 	 United States Penitentiary, McCreary
# http://www.wikidata.org/entity/Q7680055 	 Tallahatchie County Correctional Facility
# http://www.wikidata.org/entity/Q28126479 	 Cedar County Courthouse
# http://www.wikidata.org/entity/Q20745496 	 Sangerville Town Hall
# http://www.wikidata.org/entity/Q7199249 	 Pittsburgh City-County Building
# http://www.wikidata.org/entity/Q5440130 	 Federal Correctional Institution, McDowell
# http://www.wikidata.org/entity/Q64797150 	 Jefferson County Courthouse
# http://www.wikidata.org/entity/Q14705423 	 A. C. Wagner Youth Correctional Facility
# http://www.wikidata.org/entity/Q65071135 	 Saunders County Courthouse
# http://www.wikidata.org/entity/Q85678035 	 Cole Unit
# http://www.wikidata.org/entity/Q5365318 	 Ellicottville Town Hall
# http://www.wikidata.org/entity/Q7891101 	 United States Post Office and Courthouse
# http://www.wikidata.org/entity/Q7227749 	 Pondville Correctional Center
# http://www.wikidata.org/entity/Q5440038 	 Federal Building
# http://www.wikidata.org/entity/Q5330311 	 Eastern Middlesex County Second District Court
# http://www.wikidata.org/entity/Q7232477 	 Portsmouth Naval Prison
# http://www.wikidata.org/entity/Q6984788 	 Nebraska State Penitentiary

# %% [markdown]
# ### Precision: 500/500 entities are actually government buildings.

# %% [markdown]
# # Occupations

# %%
qnum = 'Q12737077' # qnum of occupation
r = createRelation(qnum, label=True)
r.extend('P31', True, 'Occupation', label=True, subclass=True)
r.query()
df_occupation = r.df
df_occupation
# Out:
#                                        Entity ID  \
# 0       http://www.wikidata.org/entity/Q12737077
# 1       http://www.wikidata.org/entity/Q12737077
# 2       http://www.wikidata.org/entity/Q12737077
# 3       http://www.wikidata.org/entity/Q12737077
# 4       http://www.wikidata.org/entity/Q12737077
# ...                                          ...
# 362249  http://www.wikidata.org/entity/Q12737077
# 362250  http://www.wikidata.org/entity/Q12737077
# 362251  http://www.wikidata.org/entity/Q12737077
# 362252  http://www.wikidata.org/entity/Q12737077
# 362253  http://www.wikidata.org/entity/Q12737077
#
#                                   Occupation_P31 Occupation_P31Label
# 0         http://www.wikidata.org/entity/Q201788           historian
# 1         http://www.wikidata.org/entity/Q250566             Q250566
# 2         http://www.wikidata.org/entity/Q212980        psychologist
# 3         http://www.wikidata.org/entity/Q268190             Q268190
# 4         http://www.wikidata.org/entity/Q245068            comedian
# ...                                          ...                 ...
# 362249  http://www.wikidata.org/entity/Q97681058           Q97681058
# 362250  http://www.wikidata.org/entity/Q97681196           Q97681196
# 362251  http://www.wikidata.org/entity/Q97681207           Q97681207
# 362252  http://www.wikidata.org/entity/Q97681221           Q97681221
# 362253  http://www.wikidata.org/entity/Q97681330           Q97681330
#
# [362254 rows x 3 columns]

# %%
'engineer' in df_occupation.Occupation_P31Label.values
# Out:
# True

# %%
'data scientist' in df_occupation.Occupation_P31Label.values
# Out:
# True

# %%
'tax collector' in df_occupation.Occupation_P31Label.values
# Out:
# True

# %%
'doctor' in df_occupation.Occupation_P31Label.values
# Out:
# False

# %%
'physician' in df_occupation.Occupation_P31Label.values
# Out:
# True

# %%
random.seed(100)
random_indices = random.sample(list(df_occupation.index), 50)
for ind in random_indices:
    print(df_occupation.Occupation_P31[ind], '\t', df_occupation.Occupation_P31Label[ind])
# Out:
# http://www.wikidata.org/entity/Q63597861 	 A Study to Assess Bioquivalence Between a Novel Naproxen Sodium 275 mg Film-coated Tablet and Nalgesin Naproxen Sodium 275 mg Film-coated Tablet in Healthy Adult Volunteers
# http://www.wikidata.org/entity/Q65470361 	 CRAIL - Controlled Reperfusion of the Acutely Ischemic Limb
# http://www.wikidata.org/entity/Q65399668 	 Ameparomo Capsules 250 mg Drug Use Investigation
# http://www.wikidata.org/entity/Q63834343 	 Circulating Endothelial Compartment During Normal and Pathological Aging
# http://www.wikidata.org/entity/Q65348618 	 Study Evaluating Pyrotinib in Combination With Capecitabine In Patients With HER2 Positive Metastatic Breast Cancer
# http://www.wikidata.org/entity/Q64790812 	 Contrast-Enhanced Subharmonic Ultrasound Imaging in Improving Characterization of Adnexal Masses in Patients Undergoing Surgery
# http://www.wikidata.org/entity/Q65380811 	 Efficacy of Coreg CR and Lisinopril on Markers for Cardiovascular Functional and Structural Disease
# http://www.wikidata.org/entity/Q66040530 	 Phase I Safety Study of Anti-HIV Immune Serum Globulin (Human)
# http://www.wikidata.org/entity/Q63397375 	 Olanzapine for the Prevention and Treatment of Nausea and Vomiting Induced by Chemotherapy of Lung Cancer
# http://www.wikidata.org/entity/Q66066571 	 Perioperative Virtual Reality for Pediatric Anesthesia
# http://www.wikidata.org/entity/Q63534203 	 CONNECARE-Assuta-Case Study 1
# http://www.wikidata.org/entity/Q63062184 	 Efficacy of Esomeprazole for Non-Allergic Rhinitis: A Double-Blind, Placebo Controlled Trial
# http://www.wikidata.org/entity/Q65401756 	 Myeloablative Conditioning, Prophylactic Defibrotide and Haplo AlloSCT for Patients With Sickle Cell Disease
# http://www.wikidata.org/entity/Q64622478 	 Amnesia After Surgery for Anterior Communicating Aneurysm： High Resolution Magnetic Resonance (MR) Imaging Findings
# http://www.wikidata.org/entity/Q61965920 	 Boceprevir/PegIFN α-2b/Riba in HCV+ Gt1 Menopausal Women, Nonresponders to PegIFN/Riba or Treatment-naives (MEN_BOC)
# http://www.wikidata.org/entity/Q89154990 	 [18F]-DPA-714 PET/CT (Positron Emission Tomography/Computerized Tomography) in Triple Negative Breast Cancers
# http://www.wikidata.org/entity/Q86270262 	 Intensive Robotic Rehabilitation in Children With Hemiparesia Using GEOSYSTEM
# http://www.wikidata.org/entity/Q64171795 	 Phase 2 Study of Pembrolizumab in Combination With Gemcitabine and Cisplatin as Neoadjuvant Therapy
# http://www.wikidata.org/entity/Q64719654 	 Preemptive Analgesia for Postlaminectomy
# http://www.wikidata.org/entity/Q64352682 	 Assessment of a Health Informatics System on Insulin-treated Diabetic Patients
# http://www.wikidata.org/entity/Q64676107 	 Sleep Disordered Breathing and Diabetes
# http://www.wikidata.org/entity/Q64171244 	 Addiction Treatment in Primary Care Expansion
# http://www.wikidata.org/entity/Q63837625 	 Efficacy of Acarbose on Intestinal Microbiome and Incretins of Type 2 Diabetes
# http://www.wikidata.org/entity/Q63594741 	 Effects of Microcrystalline Titanium Dioxide With Covalently Linked Monovalent Silver Ions on Complications After Total Hysterectomy ( ISTIAB-0)
# http://www.wikidata.org/entity/Q64029856 	 Comparison of Gadobutrol and Gadobenate Dimeglumin for Delayed Enhancement Cardiac MRI
# http://www.wikidata.org/entity/Q64789143 	 Saliva Levels of S100A12, CRP, Fetuin-A in Periodontal Disease Patients
# http://www.wikidata.org/entity/Q64808365 	 Substudy of CADRE: for People With Extreme Phenotype: BIOCADRE
# http://www.wikidata.org/entity/Q74280938 	 Evaluation of Harmonicity in Running Gait by the Use of Innovative Techniques of Video Analysis
# http://www.wikidata.org/entity/Q65362107 	 A Safety and Efficacy Study of Obinutuzumab Alone or in Combination With Chemotherapy in Participants With Chronic Lymphocytic Leukemia
# http://www.wikidata.org/entity/Q64188196 	 Effect of Muscle Coactivation Strengthening for Rotator Cuff Tendinopathy
# http://www.wikidata.org/entity/Q65355669 	 Exercise Training in Treating Diastolic Heart Failure
# http://www.wikidata.org/entity/Q65471644 	 Patients Completing Core Protocol (CAMN107A2103), Exhibiting Stable Disease (SD), Partial Response (PR) or Complete Response (CR) to Nilotinib in Combination With Imatinib
# http://www.wikidata.org/entity/Q66079371 	 Predictive Factors of Acute Oral Mucositis Induced by Chemo-radiotherapy for Local Advanced Nasopharyngeal Carcinoma
# http://www.wikidata.org/entity/Q64642752 	 Psychoeducation to Sick-listed Individuals With Mental Health Problems
# http://www.wikidata.org/entity/Q64837077 	 Women's Antioxidant and Folic Acid Cardiovascular Study (WAFACS)
# http://www.wikidata.org/entity/Q63816390 	 Functional Magnetic Resonance Imaging (fMRI) Findings in Children With Early Exposure to General Anesthesia
# http://www.wikidata.org/entity/Q86281608 	 A Brief Lifestyle Modification Programme in Overweight Subjects With Obstructive Sleep Apnoea - Needs Assessment
# http://www.wikidata.org/entity/Q79113177 	 Validation Of Quantitative Flow Ratio (QFR) - Derived Virtual Angioplasty
# http://www.wikidata.org/entity/Q63571726 	 A Trial of Pembrolizumab and Metformin Versus Pembrolizumab Alone in Advanced Melanoma
# http://www.wikidata.org/entity/Q63839324 	 Safety and Efficacy of MP-214 in Patients With Schizophrenia
# http://www.wikidata.org/entity/Q613087 	 Anwalt
# http://www.wikidata.org/entity/Q66545943 	 A Trial of Two Fixed Doses of ZX008 (Fenfluramine HCl) as an Adjunctive Therapy in Children and Young Adults With Dravet Syndrome
# http://www.wikidata.org/entity/Q65350035 	 A Phase I/II Trial of HER-2/Neu Pulsed DC1 Vaccine Combined With Trastuzumab for Patients With DCIS
# http://www.wikidata.org/entity/Q63599794 	 Liposomal Bupivicaine for Skin Graft Donor Sites in Burn Patients
# http://www.wikidata.org/entity/Q66343875 	 Assessment of Photopill Capsule Treatment for Safety and Feasibility in Ulcerative Proctitis
# http://www.wikidata.org/entity/Q63817500 	 Continuum of Care for Frail Elderly People
# http://www.wikidata.org/entity/Q64044903 	 Relationship Between Physical Activity and Stem Cells in Older Adults
# http://www.wikidata.org/entity/Q63829461 	 Phase-3 Double-Blind, Placebo-Controlled Study of Pomalidomide in Persons With Myeloproliferative-Neoplasm-Associated Myelofibrosis and RBC-Transfusion-Dependence Myelofibrosis and RBC-Transfusion-Dependence
# http://www.wikidata.org/entity/Q61904970 	 CD19/CD22-targeted Chimeric Antigen Receptor Engineered T Cell (CART) in B-Cell Acute Lymphoblastic Leukemia.
# http://www.wikidata.org/entity/Q93328857 	 Adaptation and Evaluation of the PMTCT CSC in Dedza and Ntcheu Districts, Malawi

# %%
df_occupation_filtered = df_occupation[df_occupation.Occupation_P31Label.str.len() < 40]
df_occupation_filtered
# Out:
#                                        Entity ID  \
# 0       http://www.wikidata.org/entity/Q12737077
# 1       http://www.wikidata.org/entity/Q12737077
# 2       http://www.wikidata.org/entity/Q12737077
# 3       http://www.wikidata.org/entity/Q12737077
# 4       http://www.wikidata.org/entity/Q12737077
# ...                                          ...
# 362249  http://www.wikidata.org/entity/Q12737077
# 362250  http://www.wikidata.org/entity/Q12737077
# 362251  http://www.wikidata.org/entity/Q12737077
# 362252  http://www.wikidata.org/entity/Q12737077
# 362253  http://www.wikidata.org/entity/Q12737077
#
#                                   Occupation_P31 Occupation_P31Label
# 0         http://www.wikidata.org/entity/Q201788           historian
# 1         http://www.wikidata.org/entity/Q250566             Q250566
# 2         http://www.wikidata.org/entity/Q212980        psychologist
# 3         http://www.wikidata.org/entity/Q268190             Q268190
# 4         http://www.wikidata.org/entity/Q245068            comedian
# ...                                          ...                 ...
# 362249  http://www.wikidata.org/entity/Q97681058           Q97681058
# 362250  http://www.wikidata.org/entity/Q97681196           Q97681196
# 362251  http://www.wikidata.org/entity/Q97681207           Q97681207
# 362252  http://www.wikidata.org/entity/Q97681221           Q97681221
# 362253  http://www.wikidata.org/entity/Q97681330           Q97681330
#
# [33839 rows x 3 columns]

# %%
df_occupation_filtered = df_occupation_filtered[df_occupation_filtered.Occupation_P31Label.str[0] != 'Q']
df_occupation_filtered
# Out:
#                                        Entity ID  \
# 0       http://www.wikidata.org/entity/Q12737077
# 2       http://www.wikidata.org/entity/Q12737077
# 4       http://www.wikidata.org/entity/Q12737077
# 5       http://www.wikidata.org/entity/Q12737077
# 6       http://www.wikidata.org/entity/Q12737077
# ...                                          ...
# 362226  http://www.wikidata.org/entity/Q12737077
# 362227  http://www.wikidata.org/entity/Q12737077
# 362228  http://www.wikidata.org/entity/Q12737077
# 362232  http://www.wikidata.org/entity/Q12737077
# 362233  http://www.wikidata.org/entity/Q12737077
#
#                                   Occupation_P31  \
# 0         http://www.wikidata.org/entity/Q201788
# 2         http://www.wikidata.org/entity/Q212980
# 4         http://www.wikidata.org/entity/Q245068
# 5         http://www.wikidata.org/entity/Q201948
# 6         http://www.wikidata.org/entity/Q215536
# ...                                          ...
# 362226  http://www.wikidata.org/entity/Q65548935
# 362227  http://www.wikidata.org/entity/Q67226868
# 362228  http://www.wikidata.org/entity/Q62024396
# 362232     http://www.wikidata.org/entity/Q49819
# 362233     http://www.wikidata.org/entity/Q55692
#
#                             Occupation_P31Label
# 0                                     historian
# 2                                  psychologist
# 4                                      comedian
# 5                                        sniper
# 6                                      merchant
# ...                                         ...
# 362226  Dual Frequency Synthetic Aperture Radar
# 362227             Prince Edward station attack
# 362228             Radartoren Tweede Maasvlakte
# 362232                          Charles Simonyi
# 362233                         Active Directory
#
# [30420 rows x 3 columns]

# %%
random.seed(100)
random_indices = random.sample(list(df_occupation_filtered.index), 100)
for ind in random_indices:
    print(df_occupation_filtered.Occupation_P31[ind], '\t', df_occupation_filtered.Occupation_P31Label[ind])
# Out:
# http://www.wikidata.org/entity/Q60244908 	 plant physiologist
# http://www.wikidata.org/entity/Q64622931 	 Amphetamine-Enhanced Stroke Recovery
# http://www.wikidata.org/entity/Q64611437 	 Role of BCG as Booster Vaccination
# http://www.wikidata.org/entity/Q66545898 	 Ocular Imaging Study Using Advanced OCT
# http://www.wikidata.org/entity/Q876535 	 Federal Criminal Police Office
# http://www.wikidata.org/entity/Q66068417 	 Monitoring Physical Activity (Fitbit)
# http://www.wikidata.org/entity/Q64186642 	 AcoArt III / AVF China
# http://www.wikidata.org/entity/Q66083962 	 Extending the hCG OPU Interval
# http://www.wikidata.org/entity/Q63816058 	 VIBration Training in EpicondylitiS
# http://www.wikidata.org/entity/Q64376017 	 Oxytocin and the Social Brain
# http://www.wikidata.org/entity/Q64680854 	 Chromium and Insulin Resistance
# http://www.wikidata.org/entity/Q76980528 	 Alpha-1 Research Registry
# http://www.wikidata.org/entity/Q16736386 	 Corregedor
# http://www.wikidata.org/entity/Q64789629 	 BCAA Supplemental Study
# http://www.wikidata.org/entity/Q21653400 	 Make-up artist
# http://www.wikidata.org/entity/Q14341585 	 lithotomist
# http://www.wikidata.org/entity/Q66346159 	 Managing Weight in Pregnancy
# http://www.wikidata.org/entity/Q64612509 	 Octaplas Adult TTP Trial
# http://www.wikidata.org/entity/Q62812626 	 L Test in Children With Cerebral Palsy
# http://www.wikidata.org/entity/Q3133901 	 herbalist
# http://www.wikidata.org/entity/Q66026214 	 Efficacy and Safety of BG00012 in MS
# http://www.wikidata.org/entity/Q65540736 	 Ross Aortic Valve Replacement Patients
# http://www.wikidata.org/entity/Q64025894 	 Archbishop of Mosul
# http://www.wikidata.org/entity/Q63598275 	 Anesthetic Method and Cerebral Outcomes
# http://www.wikidata.org/entity/Q61924525 	 Study of Families With Melanoma
# http://www.wikidata.org/entity/Q63535170 	 The ALERT-Pilot Study
# http://www.wikidata.org/entity/Q95718170 	 Cervical Cancer Screening in Cameroon
# http://www.wikidata.org/entity/Q66408352 	 "Equistasi" and Gait in Hemiparesis
# http://www.wikidata.org/entity/Q55987869 	 Auxiliary bishop of Paris
# http://www.wikidata.org/entity/Q1143194 	 National Police Corps of Spain
# http://www.wikidata.org/entity/Q54165684 	 chaser
# http://www.wikidata.org/entity/Q1678054 	 Miles Christianus
# http://www.wikidata.org/entity/Q64698472 	 ambassador of Romania to Bahrain
# http://www.wikidata.org/entity/Q63813504 	 Metoclopramide Pilot Trial
# http://www.wikidata.org/entity/Q63842131 	 Epidrum for Thoracic Epidural Analgesia
# http://www.wikidata.org/entity/Q65390461 	 Light Therapy for Elderly Depression
# http://www.wikidata.org/entity/Q64350878 	 Probiotics in Prevention of Common Cold
# http://www.wikidata.org/entity/Q93581127 	 MRI-guided Focal Laser Ablation
# http://www.wikidata.org/entity/Q100269042 	 tango singer
# http://www.wikidata.org/entity/Q64222173 	 Insomnia Treatment for Women Veterans
# http://www.wikidata.org/entity/Q64625960 	 Family Welfare Pilot Intervention Study
# http://www.wikidata.org/entity/Q64807687 	 Rapamycin Treatment for ALS
# http://www.wikidata.org/entity/Q63317919 	 TiLoop® Bra for Breast Reconstruction
# http://www.wikidata.org/entity/Q26262756 	 ambassador of France to Côte d'Ivoire
# http://www.wikidata.org/entity/Q74280183 	 Early Diagnosis of Neonatal Sepsis
# http://www.wikidata.org/entity/Q86310982 	 FamilyLink Family-Centered Rounds
# http://www.wikidata.org/entity/Q64030308 	 Positive Angle Kappa
# http://www.wikidata.org/entity/Q87285943 	 factory worker
# http://www.wikidata.org/entity/Q88320541 	 Paramus Police Department
# http://www.wikidata.org/entity/Q65541266 	 Study In Patients With Dyslipidaemia
# http://www.wikidata.org/entity/Q65472392 	 Housing, Insulation and Health Study
# http://www.wikidata.org/entity/Q23892384 	 trampolinist
# http://www.wikidata.org/entity/Q12063956 	 New Zealand Police
# http://www.wikidata.org/entity/Q511878 	 Coureur des bois
# http://www.wikidata.org/entity/Q65369509 	 Fibroscan Study in HCC
# http://www.wikidata.org/entity/Q64188629 	 Bacterial Arrangement on the Teeth
# http://www.wikidata.org/entity/Q61743042 	 film colorist
# http://www.wikidata.org/entity/Q67125144 	 "Immunomodulation in GWI (Phlebotomy)"
# http://www.wikidata.org/entity/Q99957461 	 SCO2T (Servo vs. Servo)
# http://www.wikidata.org/entity/Q65334610 	 Canadian WATCHMAN Registry
# http://www.wikidata.org/entity/Q88111836 	 antique trader
# http://www.wikidata.org/entity/Q1672788 	 Bremen Police
# http://www.wikidata.org/entity/Q94292243 	 martial arts teacher
# http://www.wikidata.org/entity/Q96143595 	 Alcohol And Sexual Risk Behavior
# http://www.wikidata.org/entity/Q1537445 	 stevedore
# http://www.wikidata.org/entity/Q55542415 	 Peruvian Ambassador to China
# http://www.wikidata.org/entity/Q66033445 	 A/H5N1in Adult - Aventis
# http://www.wikidata.org/entity/Q61957236 	 Effect of the Adjunctive IVB Before PRP
# http://www.wikidata.org/entity/Q64603859 	 PE PREMIER CHINA CLINICAL TRIAL
# http://www.wikidata.org/entity/Q76979871 	 Sleep Quality & Spinal Cord Injury
# http://www.wikidata.org/entity/Q65471807 	 Disturbed Sleep Model Study.
# http://www.wikidata.org/entity/Q38360602 	 ambassador of Iceland to Liechtenstein
# http://www.wikidata.org/entity/Q26262322 	 ambassador of France to Haiti
# http://www.wikidata.org/entity/Q64171938 	 Metabolic Effects of Hydroxychloroquine
# http://www.wikidata.org/entity/Q25543366 	 dermatovenereologist
# http://www.wikidata.org/entity/Q65388679 	 Prospective Study of Infant Dengue
# http://www.wikidata.org/entity/Q64806187 	 tDCS Plus Virtual Reality for PTSD
# http://www.wikidata.org/entity/Q66401883 	 COPD Exacerbations
# http://www.wikidata.org/entity/Q3403392 	 Prince Imperial of France
# http://www.wikidata.org/entity/Q65375990 	 Decision Aid Development for Smokers
# http://www.wikidata.org/entity/Q62025767 	 Multi-Drug Resistant Organism Network
# http://www.wikidata.org/entity/Q66074951 	 Retrospective CI532 Hearing Performance
# http://www.wikidata.org/entity/Q65383373 	 Measuring Blood Flow in the Brain
# http://www.wikidata.org/entity/Q67125886 	 Inhalation Flow Rate-study
# http://www.wikidata.org/entity/Q64683686 	 Instanyl® Non-Interventional Study
# http://www.wikidata.org/entity/Q66073342 	 Mayo AVC Registry and Biobank
# http://www.wikidata.org/entity/Q63340129 	 Intrapartum Hydration
# http://www.wikidata.org/entity/Q66061020 	 68-Ga-FAPI PET Imaging in Malignancy
# http://www.wikidata.org/entity/Q65358626 	 Preeclampsia and Circulating Biomarkers
# http://www.wikidata.org/entity/Q63613395 	 Stabilizer in Abdominal Wall Muscles
# http://www.wikidata.org/entity/Q64724795 	 LoBAG30 Diet in Patients on Metformin
# http://www.wikidata.org/entity/Q66046464 	 Benefit of IQP-AO-101 for Sleep
# http://www.wikidata.org/entity/Q63811535 	 HERrespect Evaluation
# http://www.wikidata.org/entity/Q64794719 	 CGM Precision and Glycaemic Variability
# http://www.wikidata.org/entity/Q6364821 	 Kansas City Police Department
# http://www.wikidata.org/entity/Q63834885 	 Phase 2/3 Oxabact Study
# http://www.wikidata.org/entity/Q84581412 	 Yamikumo Kerin
# http://www.wikidata.org/entity/Q55266597 	 2019 in Brazilian television
# http://www.wikidata.org/entity/Q66404305 	 RELIEF Europe Study
# http://www.wikidata.org/entity/Q5065142 	 Certified Anesthesia Technician

# %% [markdown]
# ### Precision: 18/100 entities are actually occupations.

# %% [markdown]
# # Cities in the US

# %%
qnum = 'Q515' # qnum of city
r = createRelation(qnum, label=True)
r.extend('P31', True, 'city', label=True, subclass=True) # extend via property P279 = is subclass of
r.changeFocus('city_P31')
r.extend('P17', False, 'Country',label=True, search="Q30")
r.query()
df_US_cities = r.df
df_US_cities
# Out:
#                                  Entity ID  \
# 0      http://www.wikidata.org/entity/Q515
# 1      http://www.wikidata.org/entity/Q515
# 2      http://www.wikidata.org/entity/Q515
# 3      http://www.wikidata.org/entity/Q515
# 4      http://www.wikidata.org/entity/Q515
# ...                                    ...
# 10338  http://www.wikidata.org/entity/Q515
# 10339  http://www.wikidata.org/entity/Q515
# 10340  http://www.wikidata.org/entity/Q515
# 10341  http://www.wikidata.org/entity/Q515
# 10342  http://www.wikidata.org/entity/Q515
#
#                                       city_P31 city_P31Label  \
# 0          http://www.wikidata.org/entity/Q975   San Antonio
# 1        http://www.wikidata.org/entity/Q16568  Jacksonville
# 2        http://www.wikidata.org/entity/Q16739    Long Beach
# 3        http://www.wikidata.org/entity/Q17042       Oakland
# 4        http://www.wikidata.org/entity/Q28218   Baton Rouge
# ...                                        ...           ...
# 10338    http://www.wikidata.org/entity/Q25395        Newark
# 10339  http://www.wikidata.org/entity/Q2056387   Taylor Mill
# 10340   http://www.wikidata.org/entity/Q544890    Plainfield
# 10341  http://www.wikidata.org/entity/Q2055351        Badger
# 10342   http://www.wikidata.org/entity/Q985592   Perth Amboy
#
#                               Country_P17          Country_P17Label
# 0      http://www.wikidata.org/entity/Q30  United States of America
# 1      http://www.wikidata.org/entity/Q30  United States of America
# 2      http://www.wikidata.org/entity/Q30  United States of America
# 3      http://www.wikidata.org/entity/Q30  United States of America
# 4      http://www.wikidata.org/entity/Q30  United States of America
# ...                                   ...                       ...
# 10338  http://www.wikidata.org/entity/Q30  United States of America
# 10339  http://www.wikidata.org/entity/Q30  United States of America
# 10340  http://www.wikidata.org/entity/Q30  United States of America
# 10341  http://www.wikidata.org/entity/Q30  United States of America
# 10342  http://www.wikidata.org/entity/Q30  United States of America
#
# [10343 rows x 5 columns]

# %% [markdown]
# This is actually not off by orders of magnitude: As of 2018, there are 19,502 incorporated cities, towns and villages in the United States. (https://www.census.gov/data/tables/time-series/demo/popest/2010s-total-cities-and-towns.html)

# %%
random.seed(100)
random_indices = random.sample(list(df_US_cities.index), 100)
for ind in random_indices:
    print(df_US_cities.city_P31[ind], '\t', df_US_cities.city_P31Label[ind])
# Out:
# http://www.wikidata.org/entity/Q950926 	 Pleasant Hill
# http://www.wikidata.org/entity/Q1890310 	 Webster
# http://www.wikidata.org/entity/Q1931777 	 Dayton
# http://www.wikidata.org/entity/Q771422 	 Viburnum
# http://www.wikidata.org/entity/Q1925833 	 Schaller
# http://www.wikidata.org/entity/Q1762858 	 Eufaula
# http://www.wikidata.org/entity/Q1928324 	 Missouri Valley
# http://www.wikidata.org/entity/Q2251642 	 Bock
# http://www.wikidata.org/entity/Q483349 	 North Ogden
# http://www.wikidata.org/entity/Q2374507 	 Redfield
# http://www.wikidata.org/entity/Q661006 	 Bluff City
# http://www.wikidata.org/entity/Q482523 	 Cottonwood Heights
# http://www.wikidata.org/entity/Q1928512 	 Leighton
# http://www.wikidata.org/entity/Q963694 	 Arbyrd
# http://www.wikidata.org/entity/Q575097 	 Winnebago
# http://www.wikidata.org/entity/Q807830 	 Barberton
# http://www.wikidata.org/entity/Q1055861 	 Monroe
# http://www.wikidata.org/entity/Q846426 	 Brentwood
# http://www.wikidata.org/entity/Q1022748 	 Eastpointe
# http://www.wikidata.org/entity/Q773495 	 Bellaire
# http://www.wikidata.org/entity/Q970397 	 Canadian
# http://www.wikidata.org/entity/Q942496 	 La Coste
# http://www.wikidata.org/entity/Q954451 	 Scranton
# http://www.wikidata.org/entity/Q987296 	 Colma
# http://www.wikidata.org/entity/Q1378018 	 North Tonawanda
# http://www.wikidata.org/entity/Q2714928 	 Lowell
# http://www.wikidata.org/entity/Q1863158 	 Atlanta
# http://www.wikidata.org/entity/Q957991 	 Long Pine
# http://www.wikidata.org/entity/Q2073632 	 Louisville
# http://www.wikidata.org/entity/Q1890228 	 Covington
# http://www.wikidata.org/entity/Q2761946 	 Pine Lake
# http://www.wikidata.org/entity/Q983845 	 South El Monte
# http://www.wikidata.org/entity/Q1944958 	 Carter Lake
# http://www.wikidata.org/entity/Q125733 	 St. Helena
# http://www.wikidata.org/entity/Q930939 	 Sleepy Eye
# http://www.wikidata.org/entity/Q969485 	 Merkel
# http://www.wikidata.org/entity/Q5917 	 Huntington Beach
# http://www.wikidata.org/entity/Q3308106 	 Petersburg
# http://www.wikidata.org/entity/Q1925824 	 Riverside
# http://www.wikidata.org/entity/Q514811 	 Rocklake
# http://www.wikidata.org/entity/Q2477847 	 Patterson
# http://www.wikidata.org/entity/Q138548 	 Cape May
# http://www.wikidata.org/entity/Q981465 	 Chico
# http://www.wikidata.org/entity/Q953684 	 Harris
# http://www.wikidata.org/entity/Q594249 	 Wyandotte
# http://www.wikidata.org/entity/Q982218 	 Shoreacres
# http://www.wikidata.org/entity/Q734974 	 Greensburg
# http://www.wikidata.org/entity/Q2230220 	 Lowry
# http://www.wikidata.org/entity/Q927443 	 Pinehurst
# http://www.wikidata.org/entity/Q1925181 	 Brownsville
# http://www.wikidata.org/entity/Q2432286 	 Ross
# http://www.wikidata.org/entity/Q79233 	 Altheimer
# http://www.wikidata.org/entity/Q2677564 	 Milner
# http://www.wikidata.org/entity/Q962411 	 New London
# http://www.wikidata.org/entity/Q994939 	 Wood Village
# http://www.wikidata.org/entity/Q2279962 	 Highmore
# http://www.wikidata.org/entity/Q965421 	 Milan
# http://www.wikidata.org/entity/Q2570981 	 Corinth
# http://www.wikidata.org/entity/Q1518217 	 Fruitland
# http://www.wikidata.org/entity/Q2315769 	 Rhame
# http://www.wikidata.org/entity/Q988065 	 Spokane Valley
# http://www.wikidata.org/entity/Q2227968 	 Thomson
# http://www.wikidata.org/entity/Q990621 	 Hoquiam
# http://www.wikidata.org/entity/Q1932538 	 Greene
# http://www.wikidata.org/entity/Q1966245 	 Leonard
# http://www.wikidata.org/entity/Q615655 	 Volga
# http://www.wikidata.org/entity/Q577853 	 Jacksonville
# http://www.wikidata.org/entity/Q977357 	 Waller
# http://www.wikidata.org/entity/Q1926474 	 Oto
# http://www.wikidata.org/entity/Q859290 	 Cloquet
# http://www.wikidata.org/entity/Q1004406 	 Miltona
# http://www.wikidata.org/entity/Q1927717 	 Moulton
# http://www.wikidata.org/entity/Q1380722 	 Tonawanda
# http://www.wikidata.org/entity/Q2042135 	 Hebron Estates
# http://www.wikidata.org/entity/Q2926372 	 Brownsville
# http://www.wikidata.org/entity/Q867503 	 Amory
# http://www.wikidata.org/entity/Q495353 	 Victorville
# http://www.wikidata.org/entity/Q385233 	 American Falls
# http://www.wikidata.org/entity/Q3180809 	 Berea
# http://www.wikidata.org/entity/Q980468 	 Wimberley
# http://www.wikidata.org/entity/Q127856 	 Beverly Hills
# http://www.wikidata.org/entity/Q79312 	 Harrell
# http://www.wikidata.org/entity/Q982843 	 Clifton
# http://www.wikidata.org/entity/Q681708 	 Center
# http://www.wikidata.org/entity/Q79303 	 Pinson
# http://www.wikidata.org/entity/Q2626739 	 Aurora
# http://www.wikidata.org/entity/Q973140 	 Brazos Bend
# http://www.wikidata.org/entity/Q1023014 	 Kiowa
# http://www.wikidata.org/entity/Q2310098 	 Balta
# http://www.wikidata.org/entity/Q2343129 	 Mosier
# http://www.wikidata.org/entity/Q973816 	 Hedley
# http://www.wikidata.org/entity/Q2805787 	 Linton
# http://www.wikidata.org/entity/Q1922047 	 Jasper
# http://www.wikidata.org/entity/Q1107962 	 Coldwater
# http://www.wikidata.org/entity/Q1928357 	 Milton
# http://www.wikidata.org/entity/Q39450 	 Anchorage
# http://www.wikidata.org/entity/Q483098 	 Bear River City
# http://www.wikidata.org/entity/Q2165375 	 Goodview
# http://www.wikidata.org/entity/Q981518 	 Fate
# http://www.wikidata.org/entity/Q2315752 	 Fredonia

# %% [markdown]
# ### Precision: 100/100 entities are actually cities.

# %% [markdown]
# # Sports

# %%
qnum = 'Q349' # qnum of sport
r = createRelation(qnum, label=True)
r.extend('P31', True, 'sport', label=True, subclass=True) # extend via property P279 = is subclass of
# r.changeFocus('sport_P31')
# r.extend('P17', False, 'Country',label=True, search="Q30")
r.query()
df_sports = r.df
df_sports
# Out:
#                                  Entity ID  \
# 0      http://www.wikidata.org/entity/Q349
# 1      http://www.wikidata.org/entity/Q349
# 2      http://www.wikidata.org/entity/Q349
# 3      http://www.wikidata.org/entity/Q349
# 4      http://www.wikidata.org/entity/Q349
# ...                                    ...
# 13735  http://www.wikidata.org/entity/Q349
# 13736  http://www.wikidata.org/entity/Q349
# 13737  http://www.wikidata.org/entity/Q349
# 13738  http://www.wikidata.org/entity/Q349
# 13739  http://www.wikidata.org/entity/Q349
#
#                                       sport_P31  \
# 0        http://www.wikidata.org/entity/Q280513
# 1       http://www.wikidata.org/entity/Q1414198
# 2       http://www.wikidata.org/entity/Q1415126
# 3       http://www.wikidata.org/entity/Q1486401
# 4       http://www.wikidata.org/entity/Q3418204
# ...                                         ...
# 13735   http://www.wikidata.org/entity/Q4583876
# 13736   http://www.wikidata.org/entity/Q4600642
# 13737   http://www.wikidata.org/entity/Q4601780
# 13738   http://www.wikidata.org/entity/Q4618095
# 13739  http://www.wikidata.org/entity/Q11458881
#
#                          sport_P31Label
# 0        Rallye International du Valais
# 1       2012 Catalunya GP2 Series round
# 2       2005 Catalunya GP2 Series round
# 3                        2011 GP2 Final
# 4                              Q3418204
# ...                                 ...
# 13735        1987 Rugby World Cup Final
# 13736  2002 Winter Olympics torch relay
# 13737        2003 Rugby World Cup Final
# 13738         2010 Olympics torch relay
# 13739               Kokura Nisai Stakes
#
# [13740 rows x 3 columns]

# %%
random.seed(100)
random_indices = random.sample(list(df_sports.index), 100)
for ind in random_indices:
    print(df_sports.sport_P31[ind], '\t', df_sports.sport_P31Label[ind])
# Out:
# http://www.wikidata.org/entity/Q7579428 	 sport in Chennai
# http://www.wikidata.org/entity/Q2937998 	 Q2937998
# http://www.wikidata.org/entity/Q2838442 	 Q2838442
# http://www.wikidata.org/entity/Q2748030 	 1985 London Marathon
# http://www.wikidata.org/entity/Q18433701 	 Rajd Wisły 2014
# http://www.wikidata.org/entity/Q33832436 	 Q33832436
# http://www.wikidata.org/entity/Q2327670 	 Q2327670
# http://www.wikidata.org/entity/Q56011146 	 Q56011146
# http://www.wikidata.org/entity/Q2065062 	 Q2065062
# http://www.wikidata.org/entity/Q2642519 	 Q2642519
# http://www.wikidata.org/entity/Q13758784 	 Q13758784
# http://www.wikidata.org/entity/Q3947239 	 Q3947239
# http://www.wikidata.org/entity/Q5089139 	 Checkless chess
# http://www.wikidata.org/entity/Q13761443 	 Q13761443
# http://www.wikidata.org/entity/Q5717479 	 basketball in Slovenia
# http://www.wikidata.org/entity/Q2397681 	 golf in France
# http://www.wikidata.org/entity/Q1341108 	 Rotterdam Marathon
# http://www.wikidata.org/entity/Q2860712 	 Q2860712
# http://www.wikidata.org/entity/Q65063144 	 2014 Tour de Suisse, Stage 1
# http://www.wikidata.org/entity/Q10600990 	 Swedish Nintendo Championship
# http://www.wikidata.org/entity/Q20055799 	 Q20055799
# http://www.wikidata.org/entity/Q19630798 	 Q19630798
# http://www.wikidata.org/entity/Q47499385 	 tennis in Malaysia
# http://www.wikidata.org/entity/Q1943002 	 Q1943002
# http://www.wikidata.org/entity/Q26157739 	 Q26157739
# http://www.wikidata.org/entity/Q18645150 	 Q18645150
# http://www.wikidata.org/entity/Q19838124 	 2013 Frankfurt Marathon
# http://www.wikidata.org/entity/Q47499405 	 tennis in Honduras
# http://www.wikidata.org/entity/Q16154225 	 netball in New Zealand
# http://www.wikidata.org/entity/Q7378372 	 rugby union in Cameroon
# http://www.wikidata.org/entity/Q16969578 	 mixed martial arts in Australia
# http://www.wikidata.org/entity/Q2049154 	 Q2049154
# http://www.wikidata.org/entity/Q2178063 	 Q2178063
# http://www.wikidata.org/entity/Q18002108 	 Q18002108
# http://www.wikidata.org/entity/Q2464321 	 Q2464321
# http://www.wikidata.org/entity/Q21585423 	 Q21585423
# http://www.wikidata.org/entity/Q48697916 	 sports in Sal, Cape Verde
# http://www.wikidata.org/entity/Q2412983 	 Q2412983
# http://www.wikidata.org/entity/Q3018241 	 Q3018241
# http://www.wikidata.org/entity/Q14638613 	 Q14638613
# http://www.wikidata.org/entity/Q48804728 	 1953 Tre Valli Varesine
# http://www.wikidata.org/entity/Q23662877 	 Q23662877
# http://www.wikidata.org/entity/Q21287640 	 1984 Houston Marathon
# http://www.wikidata.org/entity/Q2201401 	 Q2201401
# http://www.wikidata.org/entity/Q8192435 	 chess in Spain
# http://www.wikidata.org/entity/Q19692071 	 Q19692071
# http://www.wikidata.org/entity/Q18434158 	 Q18434158
# http://www.wikidata.org/entity/Q5900315 	 association football in Guadalajara
# http://www.wikidata.org/entity/Q12156922 	 sport in Ivano-Frankivsk
# http://www.wikidata.org/entity/Q16797174 	 2014 Catalunya GP2 Series round
# http://www.wikidata.org/entity/Q15878677 	 Q15878677
# http://www.wikidata.org/entity/Q2345025 	 Q2345025
# http://www.wikidata.org/entity/Q7378494 	 rugby union in Zambia
# http://www.wikidata.org/entity/Q21283157 	 1990 Madrid Marathon
# http://www.wikidata.org/entity/Q15616454 	 Q15616454
# http://www.wikidata.org/entity/Q8031180 	 women's football in Turkey
# http://www.wikidata.org/entity/Q17074459 	 sports in Tamil Nadu
# http://www.wikidata.org/entity/Q10500551 	 futsal in Finland
# http://www.wikidata.org/entity/Q5553273 	 Gertrude's Dream Waltz
# http://www.wikidata.org/entity/Q20820699 	 Q20820699
# http://www.wikidata.org/entity/Q3004103 	 2012 Giro d'Italia, Stage 1
# http://www.wikidata.org/entity/Q2753877 	 Q2753877
# http://www.wikidata.org/entity/Q2888200 	 Q2888200
# http://www.wikidata.org/entity/Q18434133 	 Q18434133
# http://www.wikidata.org/entity/Q2290232 	 Q2290232
# http://www.wikidata.org/entity/Q7361051 	 roller derby in the United Kingdom
# http://www.wikidata.org/entity/Q18002067 	 Q18002067
# http://www.wikidata.org/entity/Q14638582 	 Q14638582
# http://www.wikidata.org/entity/Q476976 	 Greifenseelauf
# http://www.wikidata.org/entity/Q12593955 	 Q12593955
# http://www.wikidata.org/entity/Q17048187 	 Q17048187
# http://www.wikidata.org/entity/Q33130981 	 Q33130981
# http://www.wikidata.org/entity/Q55204803 	 Q55204803
# http://www.wikidata.org/entity/Q17355756 	 Q17355756
# http://www.wikidata.org/entity/Q2191278 	 1982 New York City Marathon
# http://www.wikidata.org/entity/Q13758819 	 Q13758819
# http://www.wikidata.org/entity/Q51576638 	 Q51576638
# http://www.wikidata.org/entity/Q24468089 	 2016 World Matchplay
# http://www.wikidata.org/entity/Q27243402 	 Q27243402
# http://www.wikidata.org/entity/Q15878441 	 Q15878441
# http://www.wikidata.org/entity/Q1972510 	 Q1972510
# http://www.wikidata.org/entity/Q13760807 	 Q13760807
# http://www.wikidata.org/entity/Q23892369 	 Q23892369
# http://www.wikidata.org/entity/Q2013423 	 Q2013423
# http://www.wikidata.org/entity/Q14632149 	 Macedonia national football team results
# http://www.wikidata.org/entity/Q774247 	 1979 Paris–Dakar Rally
# http://www.wikidata.org/entity/Q4666523 	 list of Argentina vs Norway soccer matches
# http://www.wikidata.org/entity/Q2402806 	 Q2402806
# http://www.wikidata.org/entity/Q72971974 	 2019 New York City Marathon
# http://www.wikidata.org/entity/Q15872972 	 Q15872972
# http://www.wikidata.org/entity/Q2316402 	 1992 Nagoya Marathon
# http://www.wikidata.org/entity/Q4825176 	 Australian rules football in Canada
# http://www.wikidata.org/entity/Q3363010 	 Paquito el Chocolatero
# http://www.wikidata.org/entity/Q19818877 	 Q19818877
# http://www.wikidata.org/entity/Q2651870 	 Q2651870
# http://www.wikidata.org/entity/Q59820497 	 1956 Tour de Suisse, Stage 6
# http://www.wikidata.org/entity/Q23773274 	 Q23773274
# http://www.wikidata.org/entity/Q16986810 	 1923 Kentucky Derby
# http://www.wikidata.org/entity/Q42267590 	 Q42267590
# http://www.wikidata.org/entity/Q54414590 	 Q54414590

# %% [markdown]
# ### Precision: 13/100 entities are actually sports.

# %% [markdown]
# # Houses

# %%
qnum = 'Q3947' # qnum of house
r = createRelation(qnum, label=True)
r.extend('P31', True, 'house', label=True, subclass=True) # extend via property P279 = is subclass of
r.changeFocus('house_P31')
r.extend('P17', False, 'Country',label=True, search="Q30")
r.query()
df_houses = r.df
df_houses
# Out:
#                                  Entity ID  \
# 0     http://www.wikidata.org/entity/Q3947
# 1     http://www.wikidata.org/entity/Q3947
# 2     http://www.wikidata.org/entity/Q3947
# 3     http://www.wikidata.org/entity/Q3947
# 4     http://www.wikidata.org/entity/Q3947
# ...                                    ...
# 5293  http://www.wikidata.org/entity/Q3947
# 5294  http://www.wikidata.org/entity/Q3947
# 5295  http://www.wikidata.org/entity/Q3947
# 5296  http://www.wikidata.org/entity/Q3947
# 5297  http://www.wikidata.org/entity/Q3947
#
#                                      house_P31             house_P31Label  \
# 0      http://www.wikidata.org/entity/Q4165429            Hasbrouck House
# 1      http://www.wikidata.org/entity/Q4165373                   Plumbush
# 2      http://www.wikidata.org/entity/Q4668163      Abner Woodworth House
# 3       http://www.wikidata.org/entity/Q817711  Benjamin Ten Broeck House
# 4      http://www.wikidata.org/entity/Q1433592          Walter Hand House
# ...                                        ...                        ...
# 5293  http://www.wikidata.org/entity/Q85770685      James M. Fisher House
# 5294  http://www.wikidata.org/entity/Q68829356      Governor Seay Mansion
# 5295   http://www.wikidata.org/entity/Q7350903         Robert Waugh House
# 5296  http://www.wikidata.org/entity/Q47106956               Trube Castle
# 5297   http://www.wikidata.org/entity/Q7578287                Spite House
#
#                              Country_P17          Country_P17Label
# 0     http://www.wikidata.org/entity/Q30  United States of America
# 1     http://www.wikidata.org/entity/Q30  United States of America
# 2     http://www.wikidata.org/entity/Q30  United States of America
# 3     http://www.wikidata.org/entity/Q30  United States of America
# 4     http://www.wikidata.org/entity/Q30  United States of America
# ...                                  ...                       ...
# 5293  http://www.wikidata.org/entity/Q30  United States of America
# 5294  http://www.wikidata.org/entity/Q30  United States of America
# 5295  http://www.wikidata.org/entity/Q30  United States of America
# 5296  http://www.wikidata.org/entity/Q30  United States of America
# 5297  http://www.wikidata.org/entity/Q30  United States of America
#
# [5298 rows x 5 columns]

# %%
random.seed(100)
random_indices = random.sample(list(df_houses.index), 100)
for ind in random_indices:
    print(df_houses.house_P31[ind], '\t', df_houses.house_P31Label[ind])
# Out:
# http://www.wikidata.org/entity/Q6816445 	 Menands Manor
# http://www.wikidata.org/entity/Q5232715 	 David Cummins Octagon House
# http://www.wikidata.org/entity/Q5304363 	 Dr. Samuel Catlin House
# http://www.wikidata.org/entity/Q8006330 	 William C. Jayne House
# http://www.wikidata.org/entity/Q24041329 	 Aldridge H. Vann House
# http://www.wikidata.org/entity/Q23016860 	 Basil Doerhoefer House
# http://www.wikidata.org/entity/Q25203571 	 Hudson House
# http://www.wikidata.org/entity/Q7913732 	 Van Vleck House and Barn
# http://www.wikidata.org/entity/Q5914194 	 House at 285 Sea Cliff Avenue
# http://www.wikidata.org/entity/Q6140363 	 James Nicholson House
# http://www.wikidata.org/entity/Q5902266 	 Horace and Grace Bush House
# http://www.wikidata.org/entity/Q4887856 	 Benham House
# http://www.wikidata.org/entity/Q5322214 	 E. W. Marland Mansion
# http://www.wikidata.org/entity/Q34831176 	 Barbeau House
# http://www.wikidata.org/entity/Q7856928 	 Tuthill-Lapham House
# http://www.wikidata.org/entity/Q6206703 	 Job and Deborah Otis House
# http://www.wikidata.org/entity/Q6290603 	 Josiah Quincy House
# http://www.wikidata.org/entity/Q14709385 	 Charles H. Baldwin House
# http://www.wikidata.org/entity/Q59314902 	 Juan Matias Sanchez Adobe
# http://www.wikidata.org/entity/Q6119282 	 Jacob Sloat House
# http://www.wikidata.org/entity/Q7744079 	 The Kellogg House
# http://www.wikidata.org/entity/Q6708066 	 Lyman P. Akins House
# http://www.wikidata.org/entity/Q7615510 	 Stevenson-Frink Farm
# http://www.wikidata.org/entity/Q21016300 	 Jones P. Veazie House
# http://www.wikidata.org/entity/Q6792988 	 Maurice Crumpacker House
# http://www.wikidata.org/entity/Q5419842 	 Governor’s Mansion
# http://www.wikidata.org/entity/Q7076611 	 Oconee County Jail
# http://www.wikidata.org/entity/Q6161206 	 Jarvis-Fleet House
# http://www.wikidata.org/entity/Q25004724 	 Reeves-Melson House
# http://www.wikidata.org/entity/Q5293618 	 Don Tooley House
# http://www.wikidata.org/entity/Q64788598 	 Alva Fleharty House
# http://www.wikidata.org/entity/Q7930508 	 Villa St. Rose
# http://www.wikidata.org/entity/Q6720509 	 M L Ranch
# http://www.wikidata.org/entity/Q5540356 	 George Hays House
# http://www.wikidata.org/entity/Q100330606 	 Point Lobos Marine Exchange Lookout Station
# http://www.wikidata.org/entity/Q7490734 	 Shattuck House
# http://www.wikidata.org/entity/Q7795385 	 Thomas Youngs House
# http://www.wikidata.org/entity/Q797605 	 Babcock-Shattuck House
# http://www.wikidata.org/entity/Q55631681 	 Richland (Blaine, Tennessee)
# http://www.wikidata.org/entity/Q24041348 	 Churchill-Hilger House
# http://www.wikidata.org/entity/Q5448277 	 Filardi House
# http://www.wikidata.org/entity/Q14715425 	 Building at 10 Follen Street
# http://www.wikidata.org/entity/Q5540921 	 George I. Wilber House
# http://www.wikidata.org/entity/Q7107656 	 Osterhoudt Stone House
# http://www.wikidata.org/entity/Q8014277 	 William Lampman House
# http://www.wikidata.org/entity/Q7242437 	 Prevost Manor House
# http://www.wikidata.org/entity/Q43148492 	 Daniel Stein House
# http://www.wikidata.org/entity/Q7174886 	 Peter J. Paulsen House
# http://www.wikidata.org/entity/Q28124939 	 McGehee House
# http://www.wikidata.org/entity/Q4874574 	 Bayley House
# http://www.wikidata.org/entity/Q7412468 	 Samuel Rich House
# http://www.wikidata.org/entity/Q7189944 	 Pi Chapter House of Psi Upsilon Fraternity
# http://www.wikidata.org/entity/Q56562750 	 W. H. Lumsden House
# http://www.wikidata.org/entity/Q4819235 	 Auburn
# http://www.wikidata.org/entity/Q24061969 	 George Boxley Cabin
# http://www.wikidata.org/entity/Q23092118 	 Theta Xi Fraternity Chapter House
# http://www.wikidata.org/entity/Q4561713 	 F Street House
# http://www.wikidata.org/entity/Q7945191 	 W.E. Chilton II House
# http://www.wikidata.org/entity/Q7648883 	 Sushana River Ranger Cabin No. 17
# http://www.wikidata.org/entity/Q16896444 	 Parker House
# http://www.wikidata.org/entity/Q6237013 	 John H. Nichols House
# http://www.wikidata.org/entity/Q5733424 	 Herbert A. Sadler House
# http://www.wikidata.org/entity/Q6413180 	 Kingscote
# http://www.wikidata.org/entity/Q14707778 	 William Goadby Loew House
# http://www.wikidata.org/entity/Q4723289 	 Alfred Phillips House
# http://www.wikidata.org/entity/Q5344946 	 Edward R. Hills House
# http://www.wikidata.org/entity/Q25006812 	 Tolbert E. Gill House
# http://www.wikidata.org/entity/Q6665236 	 Lock Tender's House and Canal Store Ruin
# http://www.wikidata.org/entity/Q5243883 	 DeFerriere House
# http://www.wikidata.org/entity/Q7085605 	 Oldfields
# http://www.wikidata.org/entity/Q28124643 	 Michael D. Helfrich House
# http://www.wikidata.org/entity/Q3728690 	 Bishop's Palace
# http://www.wikidata.org/entity/Q47005654 	 Thomas Hockley House
# http://www.wikidata.org/entity/Q28006251 	 J. Herbert Moore House
# http://www.wikidata.org/entity/Q8020102 	 William Watts Sherman House
# http://www.wikidata.org/entity/Q38250945 	 James Daniel Derby House
# http://www.wikidata.org/entity/Q16899871 	 Schnull-Rauch House
# http://www.wikidata.org/entity/Q24197378 	 Ashantilly
# http://www.wikidata.org/entity/Q5382382 	 Ephriam DuPuy Stone House
# http://www.wikidata.org/entity/Q4723599 	 Alfred Webb Investment Properties
# http://www.wikidata.org/entity/Q16900147 	 Shriver House
# http://www.wikidata.org/entity/Q6471697 	 Lafitte Projects
# http://www.wikidata.org/entity/Q8033240 	 Woodruff House
# http://www.wikidata.org/entity/Q4733790 	 Almeron Durkee House
# http://www.wikidata.org/entity/Q85751539 	 Charles Baldwin House
# http://www.wikidata.org/entity/Q5015703 	 Cableland
# http://www.wikidata.org/entity/Q4859577 	 Barber-Mulligan Farm
# http://www.wikidata.org/entity/Q18205665 	 Bishop Brookes House
# http://www.wikidata.org/entity/Q14706952 	 Michael Salyer Stone House
# http://www.wikidata.org/entity/Q18151374 	 Mann-Simons Cottage
# http://www.wikidata.org/entity/Q5539223 	 George Fearn House
# http://www.wikidata.org/entity/Q20710410 	 Phi Mu Sorority House
# http://www.wikidata.org/entity/Q14706580 	 Israel Shear House
# http://www.wikidata.org/entity/Q14714930 	 Henry Whitfield House
# http://www.wikidata.org/entity/Q1542563 	 Hamilton Grange National Memorial
# http://www.wikidata.org/entity/Q6279608 	 Jose and Gertrude Anasola House
# http://www.wikidata.org/entity/Q5321597 	 E.E. Cummings House
# http://www.wikidata.org/entity/Q5592604 	 Graham-Brush Log House
# http://www.wikidata.org/entity/Q5913872 	 House at 112 Sea Cliff Avenue
# http://www.wikidata.org/entity/Q7712979 	 The Alan I W Frank House

# %% [markdown]
# ### Precision: 99/100 entities are actually houses.
